# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/(2)Workload_forecasting_of_cloud_%7C_Attention_based_BiLSTM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'cloud-computing-history-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4018029%2F6990719%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240205%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240205T135728Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading cloud-computing-history-data, 143815 bytes compressed
# [==================================================] 143815 bytes downloaded
# Downloaded and uncompressed: cloud-computing-history-data
# Data source import complete.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv("/kaggle/input/cloud-computing-history-data/43.csv")
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Attention

class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W_q = self.add_weight(name="W_q", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.W_k = self.add_weight(name="W_k", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.V = self.add_weight(name="V", shape=(input_shape[-1], 1), initializer="uniform", trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        q = tf.matmul(x, self.W_q)
        k = tf.matmul(x, self.W_k)
        scores = tf.matmul(tf.nn.tanh(q + k), self.V)
        attention_weights = tf.nn.softmax(scores, axis=-2)
        context_vector = attention_weights * x
        return context_vector

    def compute_output_shape(self, input_shape):
        return input_shape

seq_size = 30  # Replace with your sequence size

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, seq_size]),
    tf.keras.layers.Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
    tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
    tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
    tf.keras.layers.GRU(64, activation="relu", return_sequences=True),
    AttentionLayer(),  # Add Attention Layer
    tf.keras.layers.Bidirectional(LSTM(50, activation="relu")),  # Return sequences here
    tf.keras.layers.Dense(1, 'linear')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 64)          9664
#
#  bidirectional (Bidirectiona  (None, None, 128)        66048
#  l)
#
#  lstm_1 (LSTM)               (None, None, 64)          49408
#
#  lstm_2 (LSTM)               (None, None, 64)          33024
#
#  gru (GRU)                   (None, None, 64)          24960
#
#  attention_layer (AttentionL  (None, None, 64)         8256
#  ayer)
#
#  bidirectional_1 (Bidirectio  (None, 100)              46000
#  nal)
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 237,461
# Trainable params: 237,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae','mse'])

# %% [markdown]
# Define the Model checkpoint callback

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the ModelCheckpoint callback
checkpoint_path = "best_model.h5"
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_mae', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# # Model Fitting

# %%
history = model.fit(trainX, trainY, validation_data=(testX, testY),batch_size=64,
          verbose=2, epochs=300,callbacks=[checkpoint])
# Out:
# Epoch 1/300
#
# Epoch 1: val_mae improved from inf to 0.03296, saving model to best_model.h5
# 88/88 - 18s - loss: 0.0025 - mae: 0.0335 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0330 - val_mse: 0.0030 - 18s/epoch - 200ms/step
# Epoch 2/300
#
# Epoch 2: val_mae did not improve from 0.03296
# 88/88 - 2s - loss: 0.0025 - mae: 0.0339 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0356 - val_mse: 0.0030 - 2s/epoch - 17ms/step
# Epoch 3/300
#
# Epoch 3: val_mae did not improve from 0.03296
# 88/88 - 2s - loss: 0.0025 - mae: 0.0340 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0334 - val_mse: 0.0030 - 2s/epoch - 17ms/step
# Epoch 4/300
#
# Epoch 4: val_mae improved from 0.03296 to 0.01370, saving model to best_model.h5
# 88/88 - 1s - loss: 0.0017 - mae: 0.0249 - mse: 0.0017 - val_loss: 0.0010 - val_mae: 0.0137 - val_mse: 0.0010 - 1s/epoch - 17ms/step
# Epoch 5/300
#
# Epoch 5: val_mae improved from 0.01370 to 0.01137, saving model to best_model.h5
# 88/88 - 1s - loss: 7.8315e-04 - mae: 0.0128 - mse: 7.8315e-04 - val_loss: 9.4252e-04 - val_mae: 0.0114 - val_mse: 9.4252e-04 - 1s/epoch - 17ms/step
# Epoch 6/300
#
# Epoch 6: val_mae did not improve from 0.01137
# 88/88 - 1s - loss: 7.0306e-04 - mae: 0.0115 - mse: 7.0306e-04 - val_loss: 8.8578e-04 - val_mae: 0.0144 - val_mse: 8.8578e-04 - 1s/epoch - 16ms/step
# Epoch 7/300
#
# Epoch 7: val_mae did not improve from 0.01137
# 88/88 - 3s - loss: 6.9034e-04 - mae: 0.0118 - mse: 6.9034e-04 - val_loss: 8.4329e-04 - val_mae: 0.0120 - val_mse: 8.4329e-04 - 3s/epoch - 32ms/step
# Epoch 8/300
#
# Epoch 8: val_mae did not improve from 0.01137
# 88/88 - 2s - loss: 6.4533e-04 - mae: 0.0109 - mse: 6.4533e-04 - val_loss: 8.4348e-04 - val_mae: 0.0142 - val_mse: 8.4348e-04 - 2s/epoch - 26ms/step
# Epoch 9/300
#
# Epoch 9: val_mae did not improve from 0.01137
# 88/88 - 1s - loss: 6.2873e-04 - mae: 0.0109 - mse: 6.2873e-04 - val_loss: 8.1509e-04 - val_mae: 0.0119 - val_mse: 8.1509e-04 - 1s/epoch - 16ms/step
# Epoch 10/300
#
# Epoch 10: val_mae did not improve from 0.01137
# 88/88 - 2s - loss: 6.0949e-04 - mae: 0.0108 - mse: 6.0949e-04 - val_loss: 8.4657e-04 - val_mae: 0.0132 - val_mse: 8.4657e-04 - 2s/epoch - 17ms/step
# Epoch 11/300
#
# Epoch 11: val_mae improved from 0.01137 to 0.01131, saving model to best_model.h5
# 88/88 - 2s - loss: 5.5933e-04 - mae: 0.0102 - mse: 5.5933e-04 - val_loss: 8.0703e-04 - val_mae: 0.0113 - val_mse: 8.0703e-04 - 2s/epoch - 18ms/step
# Epoch 12/300
#
# Epoch 12: val_mae improved from 0.01131 to 0.01071, saving model to best_model.h5
# 88/88 - 1s - loss: 5.6218e-04 - mae: 0.0105 - mse: 5.6218e-04 - val_loss: 8.0618e-04 - val_mae: 0.0107 - val_mse: 8.0618e-04 - 1s/epoch - 17ms/step
# Epoch 13/300
#
# Epoch 13: val_mae improved from 0.01071 to 0.01023, saving model to best_model.h5
# 88/88 - 2s - loss: 5.2454e-04 - mae: 0.0100 - mse: 5.2454e-04 - val_loss: 7.8705e-04 - val_mae: 0.0102 - val_mse: 7.8705e-04 - 2s/epoch - 19ms/step
# Epoch 14/300
#
# Epoch 14: val_mae improved from 0.01023 to 0.00972, saving model to best_model.h5
# 88/88 - 3s - loss: 5.1213e-04 - mae: 0.0100 - mse: 5.1213e-04 - val_loss: 8.0191e-04 - val_mae: 0.0097 - val_mse: 8.0191e-04 - 3s/epoch - 33ms/step
# Epoch 15/300
#
# Epoch 15: val_mae did not improve from 0.00972
# 88/88 - 1s - loss: 4.9481e-04 - mae: 0.0093 - mse: 4.9481e-04 - val_loss: 8.7891e-04 - val_mae: 0.0152 - val_mse: 8.7891e-04 - 1s/epoch - 16ms/step
# Epoch 16/300
#
# Epoch 16: val_mae did not improve from 0.00972
# 88/88 - 2s - loss: 4.8185e-04 - mae: 0.0095 - mse: 4.8185e-04 - val_loss: 8.2782e-04 - val_mae: 0.0101 - val_mse: 8.2782e-04 - 2s/epoch - 17ms/step
# Epoch 17/300
#
# Epoch 17: val_mae did not improve from 0.00972
# 88/88 - 1s - loss: 4.6183e-04 - mae: 0.0093 - mse: 4.6183e-04 - val_loss: 7.8007e-04 - val_mae: 0.0104 - val_mse: 7.8007e-04 - 1s/epoch - 16ms/step
# Epoch 18/300
#
# Epoch 18: val_mae did not improve from 0.00972
# 88/88 - 2s - loss: 4.6290e-04 - mae: 0.0094 - mse: 4.6290e-04 - val_loss: 7.7480e-04 - val_mae: 0.0105 - val_mse: 7.7480e-04 - 2s/epoch - 17ms/step
# Epoch 19/300
#
# Epoch 19: val_mae did not improve from 0.00972
# 88/88 - 1s - loss: 4.4438e-04 - mae: 0.0089 - mse: 4.4438e-04 - val_loss: 8.2045e-04 - val_mae: 0.0101 - val_mse: 8.2045e-04 - 1s/epoch - 16ms/step
# Epoch 20/300
#
# Epoch 20: val_mae improved from 0.00972 to 0.00936, saving model to best_model.h5
# 88/88 - 1s - loss: 4.5326e-04 - mae: 0.0092 - mse: 4.5326e-04 - val_loss: 8.0130e-04 - val_mae: 0.0094 - val_mse: 8.0130e-04 - 1s/epoch - 17ms/step
# Epoch 21/300
#
# Epoch 21: val_mae did not improve from 0.00936
# 88/88 - 2s - loss: 4.0450e-04 - mae: 0.0084 - mse: 4.0450e-04 - val_loss: 8.6826e-04 - val_mae: 0.0113 - val_mse: 8.6826e-04 - 2s/epoch - 28ms/step
# Epoch 22/300
#
# Epoch 22: val_mae did not improve from 0.00936
# 88/88 - 2s - loss: 3.9814e-04 - mae: 0.0086 - mse: 3.9814e-04 - val_loss: 8.3138e-04 - val_mae: 0.0111 - val_mse: 8.3138e-04 - 2s/epoch - 24ms/step
# Epoch 23/300
#
# Epoch 23: val_mae did not improve from 0.00936
# 88/88 - 2s - loss: 4.0537e-04 - mae: 0.0087 - mse: 4.0537e-04 - val_loss: 9.2002e-04 - val_mae: 0.0100 - val_mse: 9.2002e-04 - 2s/epoch - 17ms/step
# Epoch 24/300
#
# Epoch 24: val_mae did not improve from 0.00936
# 88/88 - 2s - loss: 3.6968e-04 - mae: 0.0082 - mse: 3.6968e-04 - val_loss: 8.2919e-04 - val_mae: 0.0097 - val_mse: 8.2919e-04 - 2s/epoch - 17ms/step
# Epoch 25/300
#
# Epoch 25: val_mae did not improve from 0.00936
# 88/88 - 1s - loss: 3.5856e-04 - mae: 0.0078 - mse: 3.5856e-04 - val_loss: 0.0013 - val_mae: 0.0125 - val_mse: 0.0013 - 1s/epoch - 16ms/step
# Epoch 26/300
#
# Epoch 26: val_mae improved from 0.00936 to 0.00928, saving model to best_model.h5
# 88/88 - 1s - loss: 3.5195e-04 - mae: 0.0079 - mse: 3.5195e-04 - val_loss: 9.3808e-04 - val_mae: 0.0093 - val_mse: 9.3808e-04 - 1s/epoch - 17ms/step
# Epoch 27/300
#
# Epoch 27: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.4553e-04 - mae: 0.0077 - mse: 3.4553e-04 - val_loss: 8.3679e-04 - val_mae: 0.0105 - val_mse: 8.3679e-04 - 2s/epoch - 17ms/step
# Epoch 28/300
#
# Epoch 28: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.3686e-04 - mae: 0.0075 - mse: 3.3686e-04 - val_loss: 0.0011 - val_mae: 0.0102 - val_mse: 0.0011 - 2s/epoch - 24ms/step
# Epoch 29/300
#
# Epoch 29: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.2063e-04 - mae: 0.0075 - mse: 3.2063e-04 - val_loss: 9.7046e-04 - val_mae: 0.0104 - val_mse: 9.7046e-04 - 2s/epoch - 22ms/step
# Epoch 30/300
#
# Epoch 30: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.2994e-04 - mae: 0.0075 - mse: 3.2994e-04 - val_loss: 0.0012 - val_mae: 0.0104 - val_mse: 0.0012 - 2s/epoch - 18ms/step
# Epoch 31/300
#
# Epoch 31: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.1741e-04 - mae: 0.0074 - mse: 3.1741e-04 - val_loss: 0.0013 - val_mae: 0.0111 - val_mse: 0.0013 - 2s/epoch - 18ms/step
# Epoch 32/300
#
# Epoch 32: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 2.9802e-04 - mae: 0.0072 - mse: 2.9802e-04 - val_loss: 0.0016 - val_mae: 0.0116 - val_mse: 0.0016 - 2s/epoch - 18ms/step
# Epoch 33/300
#
# Epoch 33: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.0832e-04 - mae: 0.0072 - mse: 3.0832e-04 - val_loss: 8.4697e-04 - val_mae: 0.0098 - val_mse: 8.4697e-04 - 2s/epoch - 18ms/step
# Epoch 34/300
#
# Epoch 34: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.3400e-04 - mae: 0.0077 - mse: 3.3400e-04 - val_loss: 8.8843e-04 - val_mae: 0.0095 - val_mse: 8.8843e-04 - 2s/epoch - 18ms/step
# Epoch 35/300
#
# Epoch 35: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 3.0141e-04 - mae: 0.0071 - mse: 3.0141e-04 - val_loss: 0.0010 - val_mae: 0.0097 - val_mse: 0.0010 - 2s/epoch - 24ms/step
# Epoch 36/300
#
# Epoch 36: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 2.8494e-04 - mae: 0.0068 - mse: 2.8494e-04 - val_loss: 0.0010 - val_mae: 0.0101 - val_mse: 0.0010 - 2s/epoch - 23ms/step
# Epoch 37/300
#
# Epoch 37: val_mae did not improve from 0.00928
# 88/88 - 1s - loss: 2.8492e-04 - mae: 0.0068 - mse: 2.8492e-04 - val_loss: 9.7024e-04 - val_mae: 0.0097 - val_mse: 9.7024e-04 - 1s/epoch - 16ms/step
# Epoch 38/300
#
# Epoch 38: val_mae did not improve from 0.00928
# 88/88 - 2s - loss: 2.9304e-04 - mae: 0.0071 - mse: 2.9304e-04 - val_loss: 0.0017 - val_mae: 0.0105 - val_mse: 0.0017 - 2s/epoch - 17ms/step
# Epoch 39/300
#
# Epoch 39: val_mae improved from 0.00928 to 0.00867, saving model to best_model.h5
# 88/88 - 2s - loss: 2.7372e-04 - mae: 0.0068 - mse: 2.7372e-04 - val_loss: 0.0011 - val_mae: 0.0087 - val_mse: 0.0011 - 2s/epoch - 18ms/step
# Epoch 40/300
#
# Epoch 40: val_mae did not improve from 0.00867
# 88/88 - 1s - loss: 3.0696e-04 - mae: 0.0072 - mse: 3.0696e-04 - val_loss: 0.0014 - val_mae: 0.0100 - val_mse: 0.0014 - 1s/epoch - 16ms/step
# Epoch 41/300
#
# Epoch 41: val_mae improved from 0.00867 to 0.00849, saving model to best_model.h5
# 88/88 - 2s - loss: 2.8621e-04 - mae: 0.0069 - mse: 2.8621e-04 - val_loss: 0.0012 - val_mae: 0.0085 - val_mse: 0.0012 - 2s/epoch - 18ms/step
# Epoch 42/300
#
# Epoch 42: val_mae did not improve from 0.00849
# 88/88 - 1s - loss: 2.7548e-04 - mae: 0.0066 - mse: 2.7548e-04 - val_loss: 7.4468e-04 - val_mae: 0.0094 - val_mse: 7.4468e-04 - 1s/epoch - 16ms/step
# Epoch 43/300
#
# Epoch 43: val_mae did not improve from 0.00849
# 88/88 - 3s - loss: 2.9450e-04 - mae: 0.0070 - mse: 2.9450e-04 - val_loss: 0.0011 - val_mae: 0.0102 - val_mse: 0.0011 - 3s/epoch - 29ms/step
# Epoch 44/300
#
# Epoch 44: val_mae did not improve from 0.00849
# 88/88 - 2s - loss: 2.7737e-04 - mae: 0.0068 - mse: 2.7737e-04 - val_loss: 0.0011 - val_mae: 0.0106 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 45/300
#
# Epoch 45: val_mae did not improve from 0.00849
# 88/88 - 2s - loss: 2.7002e-04 - mae: 0.0067 - mse: 2.7002e-04 - val_loss: 9.4278e-04 - val_mae: 0.0088 - val_mse: 9.4278e-04 - 2s/epoch - 17ms/step
# Epoch 46/300
#
# Epoch 46: val_mae did not improve from 0.00849
# 88/88 - 2s - loss: 2.6985e-04 - mae: 0.0066 - mse: 2.6985e-04 - val_loss: 0.0012 - val_mae: 0.0092 - val_mse: 0.0012 - 2s/epoch - 17ms/step
# Epoch 47/300
#
# Epoch 47: val_mae did not improve from 0.00849
# 88/88 - 2s - loss: 2.7317e-04 - mae: 0.0070 - mse: 2.7317e-04 - val_loss: 0.0012 - val_mae: 0.0091 - val_mse: 0.0012 - 2s/epoch - 17ms/step
# Epoch 48/300
#
# Epoch 48: val_mae improved from 0.00849 to 0.00845, saving model to best_model.h5
# 88/88 - 1s - loss: 2.9481e-04 - mae: 0.0072 - mse: 2.9481e-04 - val_loss: 9.2787e-04 - val_mae: 0.0084 - val_mse: 9.2787e-04 - 1s/epoch - 17ms/step
# Epoch 49/300
#
# Epoch 49: val_mae did not improve from 0.00845
# 88/88 - 2s - loss: 2.6399e-04 - mae: 0.0065 - mse: 2.6399e-04 - val_loss: 9.6572e-04 - val_mae: 0.0096 - val_mse: 9.6572e-04 - 2s/epoch - 17ms/step
# Epoch 50/300
#
# Epoch 50: val_mae did not improve from 0.00845
# 88/88 - 2s - loss: 2.9463e-04 - mae: 0.0071 - mse: 2.9463e-04 - val_loss: 9.5680e-04 - val_mae: 0.0093 - val_mse: 9.5680e-04 - 2s/epoch - 25ms/step
# Epoch 51/300
#
# Epoch 51: val_mae did not improve from 0.00845
# 88/88 - 2s - loss: 2.4852e-04 - mae: 0.0063 - mse: 2.4852e-04 - val_loss: 0.0013 - val_mae: 0.0091 - val_mse: 0.0013 - 2s/epoch - 20ms/step
# Epoch 52/300
#
# Epoch 52: val_mae improved from 0.00845 to 0.00832, saving model to best_model.h5
# 88/88 - 1s - loss: 2.5218e-04 - mae: 0.0064 - mse: 2.5218e-04 - val_loss: 0.0013 - val_mae: 0.0083 - val_mse: 0.0013 - 1s/epoch - 16ms/step
# Epoch 53/300
#
# Epoch 53: val_mae did not improve from 0.00832
# 88/88 - 1s - loss: 2.6456e-04 - mae: 0.0064 - mse: 2.6456e-04 - val_loss: 0.0012 - val_mae: 0.0102 - val_mse: 0.0012 - 1s/epoch - 16ms/step
# Epoch 54/300
#
# Epoch 54: val_mae did not improve from 0.00832
# 88/88 - 1s - loss: 3.0538e-04 - mae: 0.0072 - mse: 3.0538e-04 - val_loss: 0.0013 - val_mae: 0.0093 - val_mse: 0.0013 - 1s/epoch - 16ms/step
# Epoch 55/300
#
# Epoch 55: val_mae did not improve from 0.00832
# 88/88 - 2s - loss: 2.9742e-04 - mae: 0.0072 - mse: 2.9742e-04 - val_loss: 7.6418e-04 - val_mae: 0.0087 - val_mse: 7.6418e-04 - 2s/epoch - 17ms/step
# Epoch 56/300
#
# Epoch 56: val_mae did not improve from 0.00832
# 88/88 - 1s - loss: 2.7492e-04 - mae: 0.0066 - mse: 2.7492e-04 - val_loss: 0.0013 - val_mae: 0.0101 - val_mse: 0.0013 - 1s/epoch - 16ms/step
# Epoch 57/300
#
# Epoch 57: val_mae did not improve from 0.00832
# 88/88 - 2s - loss: 2.4759e-04 - mae: 0.0061 - mse: 2.4759e-04 - val_loss: 8.7636e-04 - val_mae: 0.0090 - val_mse: 8.7636e-04 - 2s/epoch - 17ms/step
# Epoch 58/300
#
# Epoch 58: val_mae improved from 0.00832 to 0.00804, saving model to best_model.h5
# 88/88 - 2s - loss: 2.3982e-04 - mae: 0.0063 - mse: 2.3982e-04 - val_loss: 9.0895e-04 - val_mae: 0.0080 - val_mse: 9.0895e-04 - 2s/epoch - 26ms/step
# Epoch 59/300
#
# Epoch 59: val_mae did not improve from 0.00804
# 88/88 - 2s - loss: 2.3856e-04 - mae: 0.0061 - mse: 2.3856e-04 - val_loss: 0.0011 - val_mae: 0.0097 - val_mse: 0.0011 - 2s/epoch - 20ms/step
# Epoch 60/300
#
# Epoch 60: val_mae did not improve from 0.00804
# 88/88 - 1s - loss: 2.4561e-04 - mae: 0.0063 - mse: 2.4561e-04 - val_loss: 0.0011 - val_mae: 0.0093 - val_mse: 0.0011 - 1s/epoch - 16ms/step
# Epoch 61/300
#
# Epoch 61: val_mae did not improve from 0.00804
# 88/88 - 1s - loss: 2.4654e-04 - mae: 0.0061 - mse: 2.4654e-04 - val_loss: 0.0013 - val_mae: 0.0099 - val_mse: 0.0013 - 1s/epoch - 16ms/step
# Epoch 62/300
#
# Epoch 62: val_mae did not improve from 0.00804
# 88/88 - 1s - loss: 2.4627e-04 - mae: 0.0063 - mse: 2.4627e-04 - val_loss: 0.0010 - val_mae: 0.0089 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 63/300
#
# Epoch 63: val_mae did not improve from 0.00804
# 88/88 - 1s - loss: 2.3707e-04 - mae: 0.0061 - mse: 2.3707e-04 - val_loss: 0.0010 - val_mae: 0.0087 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 64/300
#
# Epoch 64: val_mae did not improve from 0.00804
# 88/88 - 2s - loss: 2.3723e-04 - mae: 0.0063 - mse: 2.3723e-04 - val_loss: 0.0011 - val_mae: 0.0093 - val_mse: 0.0011 - 2s/epoch - 18ms/step
# Epoch 65/300
#
# Epoch 65: val_mae did not improve from 0.00804
# 88/88 - 2s - loss: 2.7013e-04 - mae: 0.0068 - mse: 2.7013e-04 - val_loss: 9.5863e-04 - val_mae: 0.0091 - val_mse: 9.5863e-04 - 2s/epoch - 18ms/step
# Epoch 66/300
#
# Epoch 66: val_mae did not improve from 0.00804
# 88/88 - 2s - loss: 2.3555e-04 - mae: 0.0061 - mse: 2.3555e-04 - val_loss: 9.8536e-04 - val_mae: 0.0084 - val_mse: 9.8536e-04 - 2s/epoch - 28ms/step
# Epoch 67/300
#
# Epoch 67: val_mae did not improve from 0.00804
# 88/88 - 2s - loss: 2.5536e-04 - mae: 0.0065 - mse: 2.5536e-04 - val_loss: 0.0011 - val_mae: 0.0085 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 68/300
#
# Epoch 68: val_mae did not improve from 0.00804
# 88/88 - 2s - loss: 2.6707e-04 - mae: 0.0066 - mse: 2.6707e-04 - val_loss: 0.0011 - val_mae: 0.0102 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 69/300
#
# Epoch 69: val_mae improved from 0.00804 to 0.00784, saving model to best_model.h5
# 88/88 - 2s - loss: 2.4440e-04 - mae: 0.0063 - mse: 2.4440e-04 - val_loss: 0.0014 - val_mae: 0.0078 - val_mse: 0.0014 - 2s/epoch - 18ms/step
# Epoch 70/300
#
# Epoch 70: val_mae did not improve from 0.00784
# 88/88 - 1s - loss: 2.5320e-04 - mae: 0.0064 - mse: 2.5320e-04 - val_loss: 0.0011 - val_mae: 0.0102 - val_mse: 0.0011 - 1s/epoch - 16ms/step
# Epoch 71/300
#
# Epoch 71: val_mae did not improve from 0.00784
# 88/88 - 2s - loss: 2.4353e-04 - mae: 0.0064 - mse: 2.4353e-04 - val_loss: 0.0011 - val_mae: 0.0081 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 72/300
#
# Epoch 72: val_mae did not improve from 0.00784
# 88/88 - 1s - loss: 2.5043e-04 - mae: 0.0063 - mse: 2.5043e-04 - val_loss: 9.6094e-04 - val_mae: 0.0093 - val_mse: 9.6094e-04 - 1s/epoch - 16ms/step
# Epoch 73/300
#
# Epoch 73: val_mae did not improve from 0.00784
# 88/88 - 2s - loss: 2.3695e-04 - mae: 0.0060 - mse: 2.3695e-04 - val_loss: 0.0011 - val_mae: 0.0087 - val_mse: 0.0011 - 2s/epoch - 21ms/step
# Epoch 74/300
#
# Epoch 74: val_mae did not improve from 0.00784
# 88/88 - 2s - loss: 2.4738e-04 - mae: 0.0065 - mse: 2.4738e-04 - val_loss: 0.0012 - val_mae: 0.0091 - val_mse: 0.0012 - 2s/epoch - 24ms/step
# Epoch 75/300
#
# Epoch 75: val_mae did not improve from 0.00784
# 88/88 - 2s - loss: 2.4001e-04 - mae: 0.0062 - mse: 2.4001e-04 - val_loss: 0.0013 - val_mae: 0.0098 - val_mse: 0.0013 - 2s/epoch - 18ms/step
# Epoch 76/300
#
# Epoch 76: val_mae did not improve from 0.00784
# 88/88 - 2s - loss: 2.4594e-04 - mae: 0.0064 - mse: 2.4594e-04 - val_loss: 0.0012 - val_mae: 0.0088 - val_mse: 0.0012 - 2s/epoch - 17ms/step
# Epoch 77/300
#
# Epoch 77: val_mae did not improve from 0.00784
# 88/88 - 1s - loss: 2.3312e-04 - mae: 0.0062 - mse: 2.3312e-04 - val_loss: 0.0010 - val_mae: 0.0083 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 78/300
#
# Epoch 78: val_mae did not improve from 0.00784
# 88/88 - 1s - loss: 2.4278e-04 - mae: 0.0061 - mse: 2.4278e-04 - val_loss: 0.0014 - val_mae: 0.0086 - val_mse: 0.0014 - 1s/epoch - 16ms/step
# Epoch 79/300
#
# Epoch 79: val_mae did not improve from 0.00784
# 88/88 - 2s - loss: 2.5531e-04 - mae: 0.0065 - mse: 2.5531e-04 - val_loss: 0.0013 - val_mae: 0.0080 - val_mse: 0.0013 - 2s/epoch - 17ms/step
# Epoch 80/300
#
# Epoch 80: val_mae improved from 0.00784 to 0.00772, saving model to best_model.h5
# 88/88 - 2s - loss: 2.4813e-04 - mae: 0.0065 - mse: 2.4813e-04 - val_loss: 8.6015e-04 - val_mae: 0.0077 - val_mse: 8.6015e-04 - 2s/epoch - 18ms/step
# Epoch 81/300
#
# Epoch 81: val_mae improved from 0.00772 to 0.00761, saving model to best_model.h5
# 88/88 - 3s - loss: 2.4139e-04 - mae: 0.0063 - mse: 2.4139e-04 - val_loss: 7.5663e-04 - val_mae: 0.0076 - val_mse: 7.5663e-04 - 3s/epoch - 31ms/step
# Epoch 82/300
#
# Epoch 82: val_mae did not improve from 0.00761
# 88/88 - 1s - loss: 2.2867e-04 - mae: 0.0059 - mse: 2.2867e-04 - val_loss: 0.0011 - val_mae: 0.0084 - val_mse: 0.0011 - 1s/epoch - 16ms/step
# Epoch 83/300
#
# Epoch 83: val_mae did not improve from 0.00761
# 88/88 - 2s - loss: 2.4685e-04 - mae: 0.0062 - mse: 2.4685e-04 - val_loss: 0.0011 - val_mae: 0.0090 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 84/300
#
# Epoch 84: val_mae did not improve from 0.00761
# 88/88 - 2s - loss: 2.3051e-04 - mae: 0.0061 - mse: 2.3051e-04 - val_loss: 8.7076e-04 - val_mae: 0.0097 - val_mse: 8.7076e-04 - 2s/epoch - 18ms/step
# Epoch 85/300
#
# Epoch 85: val_mae did not improve from 0.00761
# 88/88 - 2s - loss: 2.2804e-04 - mae: 0.0058 - mse: 2.2804e-04 - val_loss: 9.6510e-04 - val_mae: 0.0087 - val_mse: 9.6510e-04 - 2s/epoch - 17ms/step
# Epoch 86/300
#
# Epoch 86: val_mae did not improve from 0.00761
# 88/88 - 1s - loss: 2.2376e-04 - mae: 0.0060 - mse: 2.2376e-04 - val_loss: 9.5573e-04 - val_mae: 0.0076 - val_mse: 9.5573e-04 - 1s/epoch - 16ms/step
# Epoch 87/300
#
# Epoch 87: val_mae did not improve from 0.00761
# 88/88 - 1s - loss: 2.2663e-04 - mae: 0.0060 - mse: 2.2663e-04 - val_loss: 0.0014 - val_mae: 0.0084 - val_mse: 0.0014 - 1s/epoch - 16ms/step
# Epoch 88/300
#
# Epoch 88: val_mae did not improve from 0.00761
# 88/88 - 2s - loss: 2.1247e-04 - mae: 0.0058 - mse: 2.1247e-04 - val_loss: 0.0011 - val_mae: 0.0092 - val_mse: 0.0011 - 2s/epoch - 20ms/step
# Epoch 89/300
#
# Epoch 89: val_mae did not improve from 0.00761
# 88/88 - 2s - loss: 2.3303e-04 - mae: 0.0063 - mse: 2.3303e-04 - val_loss: 0.0012 - val_mae: 0.0099 - val_mse: 0.0012 - 2s/epoch - 25ms/step
# Epoch 90/300
#
# Epoch 90: val_mae improved from 0.00761 to 0.00752, saving model to best_model.h5
# 88/88 - 2s - loss: 2.1437e-04 - mae: 0.0058 - mse: 2.1437e-04 - val_loss: 9.2643e-04 - val_mae: 0.0075 - val_mse: 9.2643e-04 - 2s/epoch - 17ms/step
# Epoch 91/300
#
# Epoch 91: val_mae did not improve from 0.00752
# 88/88 - 2s - loss: 2.0791e-04 - mae: 0.0056 - mse: 2.0791e-04 - val_loss: 0.0011 - val_mae: 0.0078 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 92/300
#
# Epoch 92: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.1469e-04 - mae: 0.0058 - mse: 2.1469e-04 - val_loss: 8.9924e-04 - val_mae: 0.0087 - val_mse: 8.9924e-04 - 1s/epoch - 16ms/step
# Epoch 93/300
#
# Epoch 93: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.2852e-04 - mae: 0.0059 - mse: 2.2852e-04 - val_loss: 0.0012 - val_mae: 0.0082 - val_mse: 0.0012 - 1s/epoch - 16ms/step
# Epoch 94/300
#
# Epoch 94: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.1183e-04 - mae: 0.0057 - mse: 2.1183e-04 - val_loss: 0.0011 - val_mae: 0.0078 - val_mse: 0.0011 - 1s/epoch - 16ms/step
# Epoch 95/300
#
# Epoch 95: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.1027e-04 - mae: 0.0056 - mse: 2.1027e-04 - val_loss: 8.4590e-04 - val_mae: 0.0083 - val_mse: 8.4590e-04 - 1s/epoch - 16ms/step
# Epoch 96/300
#
# Epoch 96: val_mae did not improve from 0.00752
# 88/88 - 2s - loss: 2.1532e-04 - mae: 0.0058 - mse: 2.1532e-04 - val_loss: 0.0012 - val_mae: 0.0105 - val_mse: 0.0012 - 2s/epoch - 21ms/step
# Epoch 97/300
#
# Epoch 97: val_mae did not improve from 0.00752
# 88/88 - 2s - loss: 2.1110e-04 - mae: 0.0059 - mse: 2.1110e-04 - val_loss: 9.6266e-04 - val_mae: 0.0096 - val_mse: 9.6266e-04 - 2s/epoch - 23ms/step
# Epoch 98/300
#
# Epoch 98: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.0723e-04 - mae: 0.0057 - mse: 2.0723e-04 - val_loss: 9.2405e-04 - val_mae: 0.0079 - val_mse: 9.2405e-04 - 1s/epoch - 16ms/step
# Epoch 99/300
#
# Epoch 99: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.1082e-04 - mae: 0.0057 - mse: 2.1082e-04 - val_loss: 0.0010 - val_mae: 0.0080 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 100/300
#
# Epoch 100: val_mae did not improve from 0.00752
# 88/88 - 2s - loss: 2.2357e-04 - mae: 0.0061 - mse: 2.2357e-04 - val_loss: 0.0012 - val_mae: 0.0083 - val_mse: 0.0012 - 2s/epoch - 17ms/step
# Epoch 101/300
#
# Epoch 101: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.2626e-04 - mae: 0.0061 - mse: 2.2626e-04 - val_loss: 8.5457e-04 - val_mae: 0.0094 - val_mse: 8.5457e-04 - 1s/epoch - 16ms/step
# Epoch 102/300
#
# Epoch 102: val_mae did not improve from 0.00752
# 88/88 - 2s - loss: 2.1800e-04 - mae: 0.0060 - mse: 2.1800e-04 - val_loss: 9.2950e-04 - val_mae: 0.0098 - val_mse: 9.2950e-04 - 2s/epoch - 17ms/step
# Epoch 103/300
#
# Epoch 103: val_mae did not improve from 0.00752
# 88/88 - 1s - loss: 2.1261e-04 - mae: 0.0058 - mse: 2.1261e-04 - val_loss: 9.6614e-04 - val_mae: 0.0078 - val_mse: 9.6614e-04 - 1s/epoch - 16ms/step
# Epoch 104/300
#
# Epoch 104: val_mae did not improve from 0.00752
# 88/88 - 2s - loss: 2.1783e-04 - mae: 0.0057 - mse: 2.1783e-04 - val_loss: 0.0016 - val_mae: 0.0079 - val_mse: 0.0016 - 2s/epoch - 21ms/step
# Epoch 105/300
#
# Epoch 105: val_mae improved from 0.00752 to 0.00744, saving model to best_model.h5
# 88/88 - 2s - loss: 2.2014e-04 - mae: 0.0057 - mse: 2.2014e-04 - val_loss: 8.2608e-04 - val_mae: 0.0074 - val_mse: 8.2608e-04 - 2s/epoch - 24ms/step
# Epoch 106/300
#
# Epoch 106: val_mae did not improve from 0.00744
# 88/88 - 1s - loss: 2.1149e-04 - mae: 0.0057 - mse: 2.1149e-04 - val_loss: 9.2440e-04 - val_mae: 0.0103 - val_mse: 9.2440e-04 - 1s/epoch - 16ms/step
# Epoch 107/300
#
# Epoch 107: val_mae did not improve from 0.00744
# 88/88 - 2s - loss: 2.0616e-04 - mae: 0.0056 - mse: 2.0616e-04 - val_loss: 0.0011 - val_mae: 0.0081 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 108/300
#
# Epoch 108: val_mae did not improve from 0.00744
# 88/88 - 1s - loss: 1.9884e-04 - mae: 0.0053 - mse: 1.9884e-04 - val_loss: 0.0010 - val_mae: 0.0093 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 109/300
#
# Epoch 109: val_mae improved from 0.00744 to 0.00736, saving model to best_model.h5
# 88/88 - 2s - loss: 2.0240e-04 - mae: 0.0057 - mse: 2.0240e-04 - val_loss: 7.6200e-04 - val_mae: 0.0074 - val_mse: 7.6200e-04 - 2s/epoch - 18ms/step
# Epoch 110/300
#
# Epoch 110: val_mae did not improve from 0.00736
# 88/88 - 2s - loss: 1.9631e-04 - mae: 0.0055 - mse: 1.9631e-04 - val_loss: 0.0012 - val_mae: 0.0081 - val_mse: 0.0012 - 2s/epoch - 17ms/step
# Epoch 111/300
#
# Epoch 111: val_mae did not improve from 0.00736
# 88/88 - 1s - loss: 2.2213e-04 - mae: 0.0060 - mse: 2.2213e-04 - val_loss: 6.6868e-04 - val_mae: 0.0086 - val_mse: 6.6868e-04 - 1s/epoch - 16ms/step
# Epoch 112/300
#
# Epoch 112: val_mae did not improve from 0.00736
# 88/88 - 2s - loss: 2.0702e-04 - mae: 0.0053 - mse: 2.0702e-04 - val_loss: 0.0012 - val_mae: 0.0088 - val_mse: 0.0012 - 2s/epoch - 24ms/step
# Epoch 113/300
#
# Epoch 113: val_mae did not improve from 0.00736
# 88/88 - 2s - loss: 2.0845e-04 - mae: 0.0056 - mse: 2.0845e-04 - val_loss: 8.9993e-04 - val_mae: 0.0101 - val_mse: 8.9993e-04 - 2s/epoch - 22ms/step
# Epoch 114/300
#
# Epoch 114: val_mae did not improve from 0.00736
# 88/88 - 1s - loss: 2.1853e-04 - mae: 0.0060 - mse: 2.1853e-04 - val_loss: 0.0012 - val_mae: 0.0084 - val_mse: 0.0012 - 1s/epoch - 16ms/step
# Epoch 115/300
#
# Epoch 115: val_mae did not improve from 0.00736
# 88/88 - 2s - loss: 1.9129e-04 - mae: 0.0054 - mse: 1.9129e-04 - val_loss: 0.0010 - val_mae: 0.0084 - val_mse: 0.0010 - 2s/epoch - 17ms/step
# Epoch 116/300
#
# Epoch 116: val_mae did not improve from 0.00736
# 88/88 - 1s - loss: 2.1306e-04 - mae: 0.0058 - mse: 2.1306e-04 - val_loss: 8.4820e-04 - val_mae: 0.0087 - val_mse: 8.4820e-04 - 1s/epoch - 16ms/step
# Epoch 117/300
#
# Epoch 117: val_mae did not improve from 0.00736
# 88/88 - 2s - loss: 2.1457e-04 - mae: 0.0057 - mse: 2.1457e-04 - val_loss: 9.1021e-04 - val_mae: 0.0080 - val_mse: 9.1021e-04 - 2s/epoch - 17ms/step
# Epoch 118/300
#
# Epoch 118: val_mae improved from 0.00736 to 0.00717, saving model to best_model.h5
# 88/88 - 2s - loss: 2.0382e-04 - mae: 0.0056 - mse: 2.0382e-04 - val_loss: 9.7489e-04 - val_mae: 0.0072 - val_mse: 9.7489e-04 - 2s/epoch - 18ms/step
# Epoch 119/300
#
# Epoch 119: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 2.1695e-04 - mae: 0.0058 - mse: 2.1695e-04 - val_loss: 9.4985e-04 - val_mae: 0.0092 - val_mse: 9.4985e-04 - 1s/epoch - 16ms/step
# Epoch 120/300
#
# Epoch 120: val_mae did not improve from 0.00717
# 88/88 - 3s - loss: 2.0113e-04 - mae: 0.0054 - mse: 2.0113e-04 - val_loss: 8.6614e-04 - val_mae: 0.0073 - val_mse: 8.6614e-04 - 3s/epoch - 31ms/step
# Epoch 121/300
#
# Epoch 121: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 2.0629e-04 - mae: 0.0056 - mse: 2.0629e-04 - val_loss: 7.6888e-04 - val_mae: 0.0082 - val_mse: 7.6888e-04 - 2s/epoch - 17ms/step
# Epoch 122/300
#
# Epoch 122: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 2.1129e-04 - mae: 0.0055 - mse: 2.1129e-04 - val_loss: 0.0011 - val_mae: 0.0084 - val_mse: 0.0011 - 1s/epoch - 16ms/step
# Epoch 123/300
#
# Epoch 123: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 1.9410e-04 - mae: 0.0054 - mse: 1.9410e-04 - val_loss: 9.1003e-04 - val_mae: 0.0074 - val_mse: 9.1003e-04 - 1s/epoch - 16ms/step
# Epoch 124/300
#
# Epoch 124: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 1.9479e-04 - mae: 0.0054 - mse: 1.9479e-04 - val_loss: 8.1725e-04 - val_mae: 0.0082 - val_mse: 8.1725e-04 - 1s/epoch - 16ms/step
# Epoch 125/300
#
# Epoch 125: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 2.0197e-04 - mae: 0.0053 - mse: 2.0197e-04 - val_loss: 0.0011 - val_mae: 0.0082 - val_mse: 0.0011 - 1s/epoch - 17ms/step
# Epoch 126/300
#
# Epoch 126: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 1.9899e-04 - mae: 0.0056 - mse: 1.9899e-04 - val_loss: 9.8600e-04 - val_mae: 0.0094 - val_mse: 9.8600e-04 - 1s/epoch - 16ms/step
# Epoch 127/300
#
# Epoch 127: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.9228e-04 - mae: 0.0053 - mse: 1.9228e-04 - val_loss: 0.0014 - val_mae: 0.0097 - val_mse: 0.0014 - 2s/epoch - 18ms/step
# Epoch 128/300
#
# Epoch 128: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 2.0261e-04 - mae: 0.0056 - mse: 2.0261e-04 - val_loss: 8.5331e-04 - val_mae: 0.0079 - val_mse: 8.5331e-04 - 2s/epoch - 26ms/step
# Epoch 129/300
#
# Epoch 129: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 1.9192e-04 - mae: 0.0053 - mse: 1.9192e-04 - val_loss: 8.3336e-04 - val_mae: 0.0085 - val_mse: 8.3336e-04 - 1s/epoch - 16ms/step
# Epoch 130/300
#
# Epoch 130: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 2.3831e-04 - mae: 0.0061 - mse: 2.3831e-04 - val_loss: 0.0011 - val_mae: 0.0080 - val_mse: 0.0011 - 1s/epoch - 16ms/step
# Epoch 131/300
#
# Epoch 131: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 2.0777e-04 - mae: 0.0060 - mse: 2.0777e-04 - val_loss: 7.5229e-04 - val_mae: 0.0075 - val_mse: 7.5229e-04 - 1s/epoch - 16ms/step
# Epoch 132/300
#
# Epoch 132: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 2.0975e-04 - mae: 0.0055 - mse: 2.0975e-04 - val_loss: 0.0013 - val_mae: 0.0075 - val_mse: 0.0013 - 1s/epoch - 16ms/step
# Epoch 133/300
#
# Epoch 133: val_mae did not improve from 0.00717
# 88/88 - 1s - loss: 1.9569e-04 - mae: 0.0055 - mse: 1.9569e-04 - val_loss: 8.3790e-04 - val_mae: 0.0079 - val_mse: 8.3790e-04 - 1s/epoch - 16ms/step
# Epoch 134/300
#
# Epoch 134: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.9212e-04 - mae: 0.0054 - mse: 1.9212e-04 - val_loss: 8.9882e-04 - val_mae: 0.0082 - val_mse: 8.9882e-04 - 2s/epoch - 17ms/step
# Epoch 135/300
#
# Epoch 135: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.9761e-04 - mae: 0.0053 - mse: 1.9761e-04 - val_loss: 0.0010 - val_mae: 0.0076 - val_mse: 0.0010 - 2s/epoch - 18ms/step
# Epoch 136/300
#
# Epoch 136: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.8505e-04 - mae: 0.0051 - mse: 1.8505e-04 - val_loss: 8.9958e-04 - val_mae: 0.0078 - val_mse: 8.9958e-04 - 2s/epoch - 26ms/step
# Epoch 137/300
#
# Epoch 137: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.8765e-04 - mae: 0.0051 - mse: 1.8765e-04 - val_loss: 9.4782e-04 - val_mae: 0.0079 - val_mse: 9.4782e-04 - 2s/epoch - 17ms/step
# Epoch 138/300
#
# Epoch 138: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.8965e-04 - mae: 0.0054 - mse: 1.8965e-04 - val_loss: 7.9118e-04 - val_mae: 0.0073 - val_mse: 7.9118e-04 - 2s/epoch - 17ms/step
# Epoch 139/300
#
# Epoch 139: val_mae did not improve from 0.00717
# 88/88 - 2s - loss: 1.9059e-04 - mae: 0.0053 - mse: 1.9059e-04 - val_loss: 9.7665e-04 - val_mae: 0.0088 - val_mse: 9.7665e-04 - 2s/epoch - 17ms/step
# Epoch 140/300
#
# Epoch 140: val_mae improved from 0.00717 to 0.00716, saving model to best_model.h5
# 88/88 - 1s - loss: 1.9803e-04 - mae: 0.0054 - mse: 1.9803e-04 - val_loss: 6.9784e-04 - val_mae: 0.0072 - val_mse: 6.9784e-04 - 1s/epoch - 17ms/step
# Epoch 141/300
#
# Epoch 141: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.9066e-04 - mae: 0.0053 - mse: 1.9066e-04 - val_loss: 7.6240e-04 - val_mae: 0.0078 - val_mse: 7.6240e-04 - 1s/epoch - 16ms/step
# Epoch 142/300
#
# Epoch 142: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 2.0007e-04 - mae: 0.0054 - mse: 2.0007e-04 - val_loss: 0.0014 - val_mae: 0.0082 - val_mse: 0.0014 - 1s/epoch - 16ms/step
# Epoch 143/300
#
# Epoch 143: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.8893e-04 - mae: 0.0053 - mse: 1.8893e-04 - val_loss: 8.0761e-04 - val_mae: 0.0075 - val_mse: 8.0761e-04 - 2s/epoch - 20ms/step
# Epoch 144/300
#
# Epoch 144: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.9107e-04 - mae: 0.0054 - mse: 1.9107e-04 - val_loss: 9.9475e-04 - val_mae: 0.0093 - val_mse: 9.9475e-04 - 2s/epoch - 25ms/step
# Epoch 145/300
#
# Epoch 145: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.8941e-04 - mae: 0.0051 - mse: 1.8941e-04 - val_loss: 0.0010 - val_mae: 0.0093 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 146/300
#
# Epoch 146: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 2.0466e-04 - mae: 0.0055 - mse: 2.0466e-04 - val_loss: 8.8312e-04 - val_mae: 0.0075 - val_mse: 8.8312e-04 - 2s/epoch - 17ms/step
# Epoch 147/300
#
# Epoch 147: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.8489e-04 - mae: 0.0051 - mse: 1.8489e-04 - val_loss: 8.4276e-04 - val_mae: 0.0074 - val_mse: 8.4276e-04 - 1s/epoch - 16ms/step
# Epoch 148/300
#
# Epoch 148: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.8910e-04 - mae: 0.0051 - mse: 1.8910e-04 - val_loss: 0.0011 - val_mae: 0.0079 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 149/300
#
# Epoch 149: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.7849e-04 - mae: 0.0050 - mse: 1.7849e-04 - val_loss: 7.8154e-04 - val_mae: 0.0075 - val_mse: 7.8154e-04 - 2s/epoch - 17ms/step
# Epoch 150/300
#
# Epoch 150: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.8731e-04 - mae: 0.0053 - mse: 1.8731e-04 - val_loss: 9.4916e-04 - val_mae: 0.0079 - val_mse: 9.4916e-04 - 1s/epoch - 17ms/step
# Epoch 151/300
#
# Epoch 151: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.8717e-04 - mae: 0.0052 - mse: 1.8717e-04 - val_loss: 9.8042e-04 - val_mae: 0.0074 - val_mse: 9.8042e-04 - 2s/epoch - 25ms/step
# Epoch 152/300
#
# Epoch 152: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.7757e-04 - mae: 0.0051 - mse: 1.7757e-04 - val_loss: 9.6643e-04 - val_mae: 0.0079 - val_mse: 9.6643e-04 - 2s/epoch - 21ms/step
# Epoch 153/300
#
# Epoch 153: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.8649e-04 - mae: 0.0053 - mse: 1.8649e-04 - val_loss: 8.6228e-04 - val_mae: 0.0083 - val_mse: 8.6228e-04 - 2s/epoch - 17ms/step
# Epoch 154/300
#
# Epoch 154: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.7899e-04 - mae: 0.0049 - mse: 1.7899e-04 - val_loss: 8.7354e-04 - val_mae: 0.0080 - val_mse: 8.7354e-04 - 1s/epoch - 16ms/step
# Epoch 155/300
#
# Epoch 155: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.7717e-04 - mae: 0.0051 - mse: 1.7717e-04 - val_loss: 9.2935e-04 - val_mae: 0.0085 - val_mse: 9.2935e-04 - 1s/epoch - 16ms/step
# Epoch 156/300
#
# Epoch 156: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.7530e-04 - mae: 0.0051 - mse: 1.7530e-04 - val_loss: 8.6200e-04 - val_mae: 0.0080 - val_mse: 8.6200e-04 - 1s/epoch - 16ms/step
# Epoch 157/300
#
# Epoch 157: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.7879e-04 - mae: 0.0049 - mse: 1.7879e-04 - val_loss: 0.0011 - val_mae: 0.0083 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 158/300
#
# Epoch 158: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.8525e-04 - mae: 0.0053 - mse: 1.8525e-04 - val_loss: 8.1752e-04 - val_mae: 0.0085 - val_mse: 8.1752e-04 - 1s/epoch - 16ms/step
# Epoch 159/300
#
# Epoch 159: val_mae did not improve from 0.00716
# 88/88 - 3s - loss: 2.1763e-04 - mae: 0.0062 - mse: 2.1763e-04 - val_loss: 0.0010 - val_mae: 0.0077 - val_mse: 0.0010 - 3s/epoch - 30ms/step
# Epoch 160/300
#
# Epoch 160: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 1.9997e-04 - mae: 0.0055 - mse: 1.9997e-04 - val_loss: 7.9537e-04 - val_mae: 0.0074 - val_mse: 7.9537e-04 - 1s/epoch - 16ms/step
# Epoch 161/300
#
# Epoch 161: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 2.0407e-04 - mae: 0.0054 - mse: 2.0407e-04 - val_loss: 9.8899e-04 - val_mae: 0.0087 - val_mse: 9.8899e-04 - 1s/epoch - 16ms/step
# Epoch 162/300
#
# Epoch 162: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.9049e-04 - mae: 0.0054 - mse: 1.9049e-04 - val_loss: 7.5888e-04 - val_mae: 0.0076 - val_mse: 7.5888e-04 - 2s/epoch - 17ms/step
# Epoch 163/300
#
# Epoch 163: val_mae did not improve from 0.00716
# 88/88 - 1s - loss: 2.0173e-04 - mae: 0.0054 - mse: 2.0173e-04 - val_loss: 8.3224e-04 - val_mae: 0.0085 - val_mse: 8.3224e-04 - 1s/epoch - 16ms/step
# Epoch 164/300
#
# Epoch 164: val_mae did not improve from 0.00716
# 88/88 - 2s - loss: 1.8795e-04 - mae: 0.0052 - mse: 1.8795e-04 - val_loss: 9.2865e-04 - val_mae: 0.0082 - val_mse: 9.2865e-04 - 2s/epoch - 17ms/step
# Epoch 165/300
#
# Epoch 165: val_mae improved from 0.00716 to 0.00696, saving model to best_model.h5
# 88/88 - 2s - loss: 1.9049e-04 - mae: 0.0052 - mse: 1.9049e-04 - val_loss: 8.2449e-04 - val_mae: 0.0070 - val_mse: 8.2449e-04 - 2s/epoch - 28ms/step
# Epoch 166/300
#
# Epoch 166: val_mae did not improve from 0.00696
# 88/88 - 6s - loss: 2.0562e-04 - mae: 0.0055 - mse: 2.0562e-04 - val_loss: 9.5877e-04 - val_mae: 0.0103 - val_mse: 9.5877e-04 - 6s/epoch - 65ms/step
# Epoch 167/300
#
# Epoch 167: val_mae did not improve from 0.00696
# 88/88 - 2s - loss: 1.8526e-04 - mae: 0.0049 - mse: 1.8526e-04 - val_loss: 0.0011 - val_mae: 0.0079 - val_mse: 0.0011 - 2s/epoch - 27ms/step
# Epoch 168/300
#
# Epoch 168: val_mae did not improve from 0.00696
# 88/88 - 2s - loss: 1.7944e-04 - mae: 0.0051 - mse: 1.7944e-04 - val_loss: 8.3510e-04 - val_mae: 0.0086 - val_mse: 8.3510e-04 - 2s/epoch - 17ms/step
# Epoch 169/300
#
# Epoch 169: val_mae did not improve from 0.00696
# 88/88 - 1s - loss: 1.7543e-04 - mae: 0.0050 - mse: 1.7543e-04 - val_loss: 8.6241e-04 - val_mae: 0.0091 - val_mse: 8.6241e-04 - 1s/epoch - 16ms/step
# Epoch 170/300
#
# Epoch 170: val_mae did not improve from 0.00696
# 88/88 - 1s - loss: 1.7773e-04 - mae: 0.0049 - mse: 1.7773e-04 - val_loss: 8.6381e-04 - val_mae: 0.0079 - val_mse: 8.6381e-04 - 1s/epoch - 16ms/step
# Epoch 171/300
#
# Epoch 171: val_mae did not improve from 0.00696
# 88/88 - 1s - loss: 1.7782e-04 - mae: 0.0050 - mse: 1.7782e-04 - val_loss: 9.1948e-04 - val_mae: 0.0072 - val_mse: 9.1948e-04 - 1s/epoch - 16ms/step
# Epoch 172/300
#
# Epoch 172: val_mae improved from 0.00696 to 0.00695, saving model to best_model.h5
# 88/88 - 2s - loss: 1.7763e-04 - mae: 0.0049 - mse: 1.7763e-04 - val_loss: 9.1383e-04 - val_mae: 0.0070 - val_mse: 9.1383e-04 - 2s/epoch - 18ms/step
# Epoch 173/300
#
# Epoch 173: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7657e-04 - mae: 0.0049 - mse: 1.7657e-04 - val_loss: 7.5608e-04 - val_mae: 0.0079 - val_mse: 7.5608e-04 - 2s/epoch - 27ms/step
# Epoch 174/300
#
# Epoch 174: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.8556e-04 - mae: 0.0053 - mse: 1.8556e-04 - val_loss: 0.0011 - val_mae: 0.0081 - val_mse: 0.0011 - 2s/epoch - 18ms/step
# Epoch 175/300
#
# Epoch 175: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7868e-04 - mae: 0.0051 - mse: 1.7868e-04 - val_loss: 9.5129e-04 - val_mae: 0.0082 - val_mse: 9.5129e-04 - 2s/epoch - 17ms/step
# Epoch 176/300
#
# Epoch 176: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.7163e-04 - mae: 0.0048 - mse: 1.7163e-04 - val_loss: 9.6141e-04 - val_mae: 0.0077 - val_mse: 9.6141e-04 - 1s/epoch - 16ms/step
# Epoch 177/300
#
# Epoch 177: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.6887e-04 - mae: 0.0046 - mse: 1.6887e-04 - val_loss: 9.2661e-04 - val_mae: 0.0079 - val_mse: 9.2661e-04 - 1s/epoch - 16ms/step
# Epoch 178/300
#
# Epoch 178: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 2.0559e-04 - mae: 0.0057 - mse: 2.0559e-04 - val_loss: 9.4711e-04 - val_mae: 0.0074 - val_mse: 9.4711e-04 - 1s/epoch - 16ms/step
# Epoch 179/300
#
# Epoch 179: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.8398e-04 - mae: 0.0053 - mse: 1.8398e-04 - val_loss: 0.0010 - val_mae: 0.0078 - val_mse: 0.0010 - 1s/epoch - 16ms/step
# Epoch 180/300
#
# Epoch 180: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7977e-04 - mae: 0.0051 - mse: 1.7977e-04 - val_loss: 9.3296e-04 - val_mae: 0.0071 - val_mse: 9.3296e-04 - 2s/epoch - 17ms/step
# Epoch 181/300
#
# Epoch 181: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.8525e-04 - mae: 0.0053 - mse: 1.8525e-04 - val_loss: 0.0011 - val_mae: 0.0087 - val_mse: 0.0011 - 2s/epoch - 28ms/step
# Epoch 182/300
#
# Epoch 182: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.7788e-04 - mae: 0.0050 - mse: 1.7788e-04 - val_loss: 8.0197e-04 - val_mae: 0.0078 - val_mse: 8.0197e-04 - 1s/epoch - 16ms/step
# Epoch 183/300
#
# Epoch 183: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7177e-04 - mae: 0.0047 - mse: 1.7177e-04 - val_loss: 0.0011 - val_mae: 0.0081 - val_mse: 0.0011 - 2s/epoch - 17ms/step
# Epoch 184/300
#
# Epoch 184: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.8680e-04 - mae: 0.0055 - mse: 1.8680e-04 - val_loss: 9.2387e-04 - val_mae: 0.0082 - val_mse: 9.2387e-04 - 1s/epoch - 16ms/step
# Epoch 185/300
#
# Epoch 185: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.8291e-04 - mae: 0.0051 - mse: 1.8291e-04 - val_loss: 7.7723e-04 - val_mae: 0.0079 - val_mse: 7.7723e-04 - 2s/epoch - 17ms/step
# Epoch 186/300
#
# Epoch 186: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.8095e-04 - mae: 0.0050 - mse: 1.8095e-04 - val_loss: 0.0010 - val_mae: 0.0078 - val_mse: 0.0010 - 2s/epoch - 17ms/step
# Epoch 187/300
#
# Epoch 187: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.8084e-04 - mae: 0.0053 - mse: 1.8084e-04 - val_loss: 8.3337e-04 - val_mae: 0.0079 - val_mse: 8.3337e-04 - 1s/epoch - 16ms/step
# Epoch 188/300
#
# Epoch 188: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7644e-04 - mae: 0.0049 - mse: 1.7644e-04 - val_loss: 8.4296e-04 - val_mae: 0.0082 - val_mse: 8.4296e-04 - 2s/epoch - 19ms/step
# Epoch 189/300
#
# Epoch 189: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7048e-04 - mae: 0.0049 - mse: 1.7048e-04 - val_loss: 8.6084e-04 - val_mae: 0.0077 - val_mse: 8.6084e-04 - 2s/epoch - 25ms/step
# Epoch 190/300
#
# Epoch 190: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.7321e-04 - mae: 0.0050 - mse: 1.7321e-04 - val_loss: 8.6193e-04 - val_mae: 0.0078 - val_mse: 8.6193e-04 - 1s/epoch - 16ms/step
# Epoch 191/300
#
# Epoch 191: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7668e-04 - mae: 0.0052 - mse: 1.7668e-04 - val_loss: 8.5625e-04 - val_mae: 0.0091 - val_mse: 8.5625e-04 - 2s/epoch - 17ms/step
# Epoch 192/300
#
# Epoch 192: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.7096e-04 - mae: 0.0048 - mse: 1.7096e-04 - val_loss: 8.4748e-04 - val_mae: 0.0082 - val_mse: 8.4748e-04 - 1s/epoch - 16ms/step
# Epoch 193/300
#
# Epoch 193: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7719e-04 - mae: 0.0050 - mse: 1.7719e-04 - val_loss: 8.0224e-04 - val_mae: 0.0078 - val_mse: 8.0224e-04 - 2s/epoch - 18ms/step
# Epoch 194/300
#
# Epoch 194: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.7275e-04 - mae: 0.0050 - mse: 1.7275e-04 - val_loss: 8.3282e-04 - val_mae: 0.0077 - val_mse: 8.3282e-04 - 1s/epoch - 17ms/step
# Epoch 195/300
#
# Epoch 195: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.8014e-04 - mae: 0.0050 - mse: 1.8014e-04 - val_loss: 7.7017e-04 - val_mae: 0.0077 - val_mse: 7.7017e-04 - 1s/epoch - 16ms/step
# Epoch 196/300
#
# Epoch 196: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.7212e-04 - mae: 0.0046 - mse: 1.7212e-04 - val_loss: 7.9367e-04 - val_mae: 0.0072 - val_mse: 7.9367e-04 - 2s/epoch - 21ms/step
# Epoch 197/300
#
# Epoch 197: val_mae did not improve from 0.00695
# 88/88 - 2s - loss: 1.8025e-04 - mae: 0.0051 - mse: 1.8025e-04 - val_loss: 8.2306e-04 - val_mae: 0.0080 - val_mse: 8.2306e-04 - 2s/epoch - 24ms/step
# Epoch 198/300
#
# Epoch 198: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.8221e-04 - mae: 0.0053 - mse: 1.8221e-04 - val_loss: 8.5350e-04 - val_mae: 0.0085 - val_mse: 8.5350e-04 - 1s/epoch - 16ms/step
# Epoch 199/300
#
# Epoch 199: val_mae did not improve from 0.00695
# 88/88 - 1s - loss: 1.6928e-04 - mae: 0.0049 - mse: 1.6928e-04 - val_loss: 8.3045e-04 - val_mae: 0.0080 - val_mse: 8.3045e-04 - 1s/epoch - 16ms/step
# Epoch 200/300
#
# Epoch 200: val_mae improved from 0.00695 to 0.00688, saving model to best_model.h5
# 88/88 - 2s - loss: 1.6737e-04 - mae: 0.0046 - mse: 1.6737e-04 - val_loss: 7.8141e-04 - val_mae: 0.0069 - val_mse: 7.8141e-04 - 2s/epoch - 18ms/step
# Epoch 201/300
#
# Epoch 201: val_mae did not improve from 0.00688
# 88/88 - 1s - loss: 1.7153e-04 - mae: 0.0047 - mse: 1.7153e-04 - val_loss: 7.6801e-04 - val_mae: 0.0080 - val_mse: 7.6801e-04 - 1s/epoch - 16ms/step
# Epoch 202/300
#
# Epoch 202: val_mae did not improve from 0.00688
# 88/88 - 1s - loss: 1.6608e-04 - mae: 0.0046 - mse: 1.6608e-04 - val_loss: 8.6298e-04 - val_mae: 0.0074 - val_mse: 8.6298e-04 - 1s/epoch - 16ms/step
# Epoch 203/300
#
# Epoch 203: val_mae did not improve from 0.00688
# 88/88 - 2s - loss: 1.7506e-04 - mae: 0.0052 - mse: 1.7506e-04 - val_loss: 7.6645e-04 - val_mae: 0.0075 - val_mse: 7.6645e-04 - 2s/epoch - 17ms/step
# Epoch 204/300
#
# Epoch 204: val_mae did not improve from 0.00688
# 88/88 - 2s - loss: 1.7827e-04 - mae: 0.0049 - mse: 1.7827e-04 - val_loss: 8.4781e-04 - val_mae: 0.0083 - val_mse: 8.4781e-04 - 2s/epoch - 24ms/step
# Epoch 205/300
#
# Epoch 205: val_mae did not improve from 0.00688
# 88/88 - 2s - loss: 1.7774e-04 - mae: 0.0050 - mse: 1.7774e-04 - val_loss: 7.6006e-04 - val_mae: 0.0079 - val_mse: 7.6006e-04 - 2s/epoch - 21ms/step
# Epoch 206/300
#
# Epoch 206: val_mae did not improve from 0.00688
# 88/88 - 1s - loss: 1.7346e-04 - mae: 0.0049 - mse: 1.7346e-04 - val_loss: 7.8217e-04 - val_mae: 0.0083 - val_mse: 7.8217e-04 - 1s/epoch - 16ms/step
# Epoch 207/300
#
# Epoch 207: val_mae did not improve from 0.00688
# 88/88 - 1s - loss: 1.7506e-04 - mae: 0.0051 - mse: 1.7506e-04 - val_loss: 9.3077e-04 - val_mae: 0.0091 - val_mse: 9.3077e-04 - 1s/epoch - 16ms/step
# Epoch 208/300
#
# Epoch 208: val_mae did not improve from 0.00688
# 88/88 - 2s - loss: 1.8814e-04 - mae: 0.0053 - mse: 1.8814e-04 - val_loss: 8.0689e-04 - val_mae: 0.0070 - val_mse: 8.0689e-04 - 2s/epoch - 18ms/step
# Epoch 209/300
#
# Epoch 209: val_mae did not improve from 0.00688
# 88/88 - 2s - loss: 1.7162e-04 - mae: 0.0049 - mse: 1.7162e-04 - val_loss: 7.4306e-04 - val_mae: 0.0073 - val_mse: 7.4306e-04 - 2s/epoch - 17ms/step
# Epoch 210/300
#
# Epoch 210: val_mae did not improve from 0.00688
# 88/88 - 2s - loss: 1.7473e-04 - mae: 0.0049 - mse: 1.7473e-04 - val_loss: 7.8327e-04 - val_mae: 0.0073 - val_mse: 7.8327e-04 - 2s/epoch - 17ms/step
# Epoch 211/300
#
# Epoch 211: val_mae improved from 0.00688 to 0.00680, saving model to best_model.h5
# 88/88 - 1s - loss: 1.6616e-04 - mae: 0.0048 - mse: 1.6616e-04 - val_loss: 7.4104e-04 - val_mae: 0.0068 - val_mse: 7.4104e-04 - 1s/epoch - 17ms/step
# Epoch 212/300
#
# Epoch 212: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6584e-04 - mae: 0.0046 - mse: 1.6584e-04 - val_loss: 8.1080e-04 - val_mae: 0.0086 - val_mse: 8.1080e-04 - 2s/epoch - 28ms/step
# Epoch 213/300
#
# Epoch 213: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.8118e-04 - mae: 0.0051 - mse: 1.8118e-04 - val_loss: 7.9540e-04 - val_mae: 0.0078 - val_mse: 7.9540e-04 - 2s/epoch - 18ms/step
# Epoch 214/300
#
# Epoch 214: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6969e-04 - mae: 0.0046 - mse: 1.6969e-04 - val_loss: 7.5402e-04 - val_mae: 0.0075 - val_mse: 7.5402e-04 - 2s/epoch - 18ms/step
# Epoch 215/300
#
# Epoch 215: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.6792e-04 - mae: 0.0047 - mse: 1.6792e-04 - val_loss: 7.8618e-04 - val_mae: 0.0072 - val_mse: 7.8618e-04 - 1s/epoch - 16ms/step
# Epoch 216/300
#
# Epoch 216: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6790e-04 - mae: 0.0048 - mse: 1.6790e-04 - val_loss: 7.3585e-04 - val_mae: 0.0091 - val_mse: 7.3585e-04 - 2s/epoch - 17ms/step
# Epoch 217/300
#
# Epoch 217: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.7267e-04 - mae: 0.0051 - mse: 1.7267e-04 - val_loss: 7.3791e-04 - val_mae: 0.0069 - val_mse: 7.3791e-04 - 1s/epoch - 16ms/step
# Epoch 218/300
#
# Epoch 218: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6810e-04 - mae: 0.0045 - mse: 1.6810e-04 - val_loss: 8.6891e-04 - val_mae: 0.0085 - val_mse: 8.6891e-04 - 2s/epoch - 18ms/step
# Epoch 219/300
#
# Epoch 219: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.7000e-04 - mae: 0.0048 - mse: 1.7000e-04 - val_loss: 7.3567e-04 - val_mae: 0.0074 - val_mse: 7.3567e-04 - 2s/epoch - 20ms/step
# Epoch 220/300
#
# Epoch 220: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6984e-04 - mae: 0.0048 - mse: 1.6984e-04 - val_loss: 7.4667e-04 - val_mae: 0.0075 - val_mse: 7.4667e-04 - 2s/epoch - 24ms/step
# Epoch 221/300
#
# Epoch 221: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.8304e-04 - mae: 0.0051 - mse: 1.8304e-04 - val_loss: 7.1396e-04 - val_mae: 0.0085 - val_mse: 7.1396e-04 - 2s/epoch - 17ms/step
# Epoch 222/300
#
# Epoch 222: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.7141e-04 - mae: 0.0049 - mse: 1.7141e-04 - val_loss: 7.6640e-04 - val_mae: 0.0074 - val_mse: 7.6640e-04 - 1s/epoch - 16ms/step
# Epoch 223/300
#
# Epoch 223: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6827e-04 - mae: 0.0046 - mse: 1.6827e-04 - val_loss: 8.7749e-04 - val_mae: 0.0084 - val_mse: 8.7749e-04 - 2s/epoch - 17ms/step
# Epoch 224/300
#
# Epoch 224: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.6887e-04 - mae: 0.0048 - mse: 1.6887e-04 - val_loss: 6.7560e-04 - val_mae: 0.0080 - val_mse: 6.7560e-04 - 1s/epoch - 16ms/step
# Epoch 225/300
#
# Epoch 225: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.7113e-04 - mae: 0.0048 - mse: 1.7113e-04 - val_loss: 8.1790e-04 - val_mae: 0.0079 - val_mse: 8.1790e-04 - 1s/epoch - 16ms/step
# Epoch 226/300
#
# Epoch 226: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.7183e-04 - mae: 0.0050 - mse: 1.7183e-04 - val_loss: 7.0501e-04 - val_mae: 0.0070 - val_mse: 7.0501e-04 - 1s/epoch - 16ms/step
# Epoch 227/300
#
# Epoch 227: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.7428e-04 - mae: 0.0051 - mse: 1.7428e-04 - val_loss: 7.7224e-04 - val_mae: 0.0070 - val_mse: 7.7224e-04 - 2s/epoch - 22ms/step
# Epoch 228/300
#
# Epoch 228: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6714e-04 - mae: 0.0047 - mse: 1.6714e-04 - val_loss: 7.5004e-04 - val_mae: 0.0074 - val_mse: 7.5004e-04 - 2s/epoch - 23ms/step
# Epoch 229/300
#
# Epoch 229: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6318e-04 - mae: 0.0047 - mse: 1.6318e-04 - val_loss: 7.4346e-04 - val_mae: 0.0073 - val_mse: 7.4346e-04 - 2s/epoch - 17ms/step
# Epoch 230/300
#
# Epoch 230: val_mae did not improve from 0.00680
# 88/88 - 1s - loss: 1.6172e-04 - mae: 0.0046 - mse: 1.6172e-04 - val_loss: 7.7060e-04 - val_mae: 0.0079 - val_mse: 7.7060e-04 - 1s/epoch - 16ms/step
# Epoch 231/300
#
# Epoch 231: val_mae did not improve from 0.00680
# 88/88 - 2s - loss: 1.6266e-04 - mae: 0.0047 - mse: 1.6266e-04 - val_loss: 7.4701e-04 - val_mae: 0.0072 - val_mse: 7.4701e-04 - 2s/epoch - 17ms/step
# Epoch 232/300
#
# Epoch 232: val_mae improved from 0.00680 to 0.00679, saving model to best_model.h5
# 88/88 - 2s - loss: 1.6107e-04 - mae: 0.0047 - mse: 1.6107e-04 - val_loss: 7.3434e-04 - val_mae: 0.0068 - val_mse: 7.3434e-04 - 2s/epoch - 18ms/step
# Epoch 233/300
#
# Epoch 233: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.5856e-04 - mae: 0.0044 - mse: 1.5856e-04 - val_loss: 7.1546e-04 - val_mae: 0.0073 - val_mse: 7.1546e-04 - 1s/epoch - 16ms/step
# Epoch 234/300
#
# Epoch 234: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.7715e-04 - mae: 0.0050 - mse: 1.7715e-04 - val_loss: 8.2588e-04 - val_mae: 0.0079 - val_mse: 8.2588e-04 - 1s/epoch - 16ms/step
# Epoch 235/300
#
# Epoch 235: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6383e-04 - mae: 0.0046 - mse: 1.6383e-04 - val_loss: 7.3831e-04 - val_mae: 0.0071 - val_mse: 7.3831e-04 - 2s/epoch - 24ms/step
# Epoch 236/300
#
# Epoch 236: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.7312e-04 - mae: 0.0048 - mse: 1.7312e-04 - val_loss: 7.3799e-04 - val_mae: 0.0081 - val_mse: 7.3799e-04 - 2s/epoch - 20ms/step
# Epoch 237/300
#
# Epoch 237: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.8663e-04 - mae: 0.0050 - mse: 1.8663e-04 - val_loss: 6.9359e-04 - val_mae: 0.0077 - val_mse: 6.9359e-04 - 1s/epoch - 16ms/step
# Epoch 238/300
#
# Epoch 238: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.7279e-04 - mae: 0.0050 - mse: 1.7279e-04 - val_loss: 7.0230e-04 - val_mae: 0.0072 - val_mse: 7.0230e-04 - 2s/epoch - 17ms/step
# Epoch 239/300
#
# Epoch 239: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6150e-04 - mae: 0.0047 - mse: 1.6150e-04 - val_loss: 7.4089e-04 - val_mae: 0.0070 - val_mse: 7.4089e-04 - 1s/epoch - 17ms/step
# Epoch 240/300
#
# Epoch 240: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.5614e-04 - mae: 0.0045 - mse: 1.5614e-04 - val_loss: 8.0888e-04 - val_mae: 0.0077 - val_mse: 8.0888e-04 - 1s/epoch - 17ms/step
# Epoch 241/300
#
# Epoch 241: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6508e-04 - mae: 0.0047 - mse: 1.6508e-04 - val_loss: 7.4943e-04 - val_mae: 0.0080 - val_mse: 7.4943e-04 - 1s/epoch - 16ms/step
# Epoch 242/300
#
# Epoch 242: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5955e-04 - mae: 0.0046 - mse: 1.5955e-04 - val_loss: 7.1963e-04 - val_mae: 0.0078 - val_mse: 7.1963e-04 - 2s/epoch - 18ms/step
# Epoch 243/300
#
# Epoch 243: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6000e-04 - mae: 0.0046 - mse: 1.6000e-04 - val_loss: 7.3654e-04 - val_mae: 0.0069 - val_mse: 7.3654e-04 - 2s/epoch - 28ms/step
# Epoch 244/300
#
# Epoch 244: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5931e-04 - mae: 0.0046 - mse: 1.5931e-04 - val_loss: 7.3058e-04 - val_mae: 0.0072 - val_mse: 7.3058e-04 - 2s/epoch - 17ms/step
# Epoch 245/300
#
# Epoch 245: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6322e-04 - mae: 0.0048 - mse: 1.6322e-04 - val_loss: 7.7937e-04 - val_mae: 0.0090 - val_mse: 7.7937e-04 - 2s/epoch - 18ms/step
# Epoch 246/300
#
# Epoch 246: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6805e-04 - mae: 0.0048 - mse: 1.6805e-04 - val_loss: 6.5563e-04 - val_mae: 0.0069 - val_mse: 6.5563e-04 - 2s/epoch - 18ms/step
# Epoch 247/300
#
# Epoch 247: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.7908e-04 - mae: 0.0051 - mse: 1.7908e-04 - val_loss: 7.8649e-04 - val_mae: 0.0080 - val_mse: 7.8649e-04 - 1s/epoch - 16ms/step
# Epoch 248/300
#
# Epoch 248: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.7208e-04 - mae: 0.0048 - mse: 1.7208e-04 - val_loss: 7.0493e-04 - val_mae: 0.0086 - val_mse: 7.0493e-04 - 1s/epoch - 16ms/step
# Epoch 249/300
#
# Epoch 249: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6487e-04 - mae: 0.0047 - mse: 1.6487e-04 - val_loss: 7.0519e-04 - val_mae: 0.0075 - val_mse: 7.0519e-04 - 1s/epoch - 16ms/step
# Epoch 250/300
#
# Epoch 250: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6452e-04 - mae: 0.0046 - mse: 1.6452e-04 - val_loss: 7.6300e-04 - val_mae: 0.0097 - val_mse: 7.6300e-04 - 2s/epoch - 18ms/step
# Epoch 251/300
#
# Epoch 251: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6505e-04 - mae: 0.0048 - mse: 1.6505e-04 - val_loss: 7.2196e-04 - val_mae: 0.0077 - val_mse: 7.2196e-04 - 2s/epoch - 28ms/step
# Epoch 252/300
#
# Epoch 252: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.5683e-04 - mae: 0.0044 - mse: 1.5683e-04 - val_loss: 7.3808e-04 - val_mae: 0.0072 - val_mse: 7.3808e-04 - 1s/epoch - 16ms/step
# Epoch 253/300
#
# Epoch 253: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5613e-04 - mae: 0.0043 - mse: 1.5613e-04 - val_loss: 6.9878e-04 - val_mae: 0.0078 - val_mse: 6.9878e-04 - 2s/epoch - 18ms/step
# Epoch 254/300
#
# Epoch 254: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.5737e-04 - mae: 0.0044 - mse: 1.5737e-04 - val_loss: 7.3714e-04 - val_mae: 0.0078 - val_mse: 7.3714e-04 - 1s/epoch - 17ms/step
# Epoch 255/300
#
# Epoch 255: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.5976e-04 - mae: 0.0047 - mse: 1.5976e-04 - val_loss: 7.4460e-04 - val_mae: 0.0068 - val_mse: 7.4460e-04 - 1s/epoch - 16ms/step
# Epoch 256/300
#
# Epoch 256: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6192e-04 - mae: 0.0045 - mse: 1.6192e-04 - val_loss: 6.6255e-04 - val_mae: 0.0076 - val_mse: 6.6255e-04 - 2s/epoch - 18ms/step
# Epoch 257/300
#
# Epoch 257: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6512e-04 - mae: 0.0048 - mse: 1.6512e-04 - val_loss: 7.0747e-04 - val_mae: 0.0071 - val_mse: 7.0747e-04 - 1s/epoch - 16ms/step
# Epoch 258/300
#
# Epoch 258: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5959e-04 - mae: 0.0045 - mse: 1.5959e-04 - val_loss: 7.3189e-04 - val_mae: 0.0071 - val_mse: 7.3189e-04 - 2s/epoch - 25ms/step
# Epoch 259/300
#
# Epoch 259: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5829e-04 - mae: 0.0044 - mse: 1.5829e-04 - val_loss: 6.9044e-04 - val_mae: 0.0073 - val_mse: 6.9044e-04 - 2s/epoch - 20ms/step
# Epoch 260/300
#
# Epoch 260: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6591e-04 - mae: 0.0048 - mse: 1.6591e-04 - val_loss: 6.7441e-04 - val_mae: 0.0070 - val_mse: 6.7441e-04 - 1s/epoch - 16ms/step
# Epoch 261/300
#
# Epoch 261: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6071e-04 - mae: 0.0045 - mse: 1.6071e-04 - val_loss: 6.7445e-04 - val_mae: 0.0072 - val_mse: 6.7445e-04 - 2s/epoch - 17ms/step
# Epoch 262/300
#
# Epoch 262: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.5174e-04 - mae: 0.0045 - mse: 1.5174e-04 - val_loss: 7.6178e-04 - val_mae: 0.0077 - val_mse: 7.6178e-04 - 1s/epoch - 16ms/step
# Epoch 263/300
#
# Epoch 263: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.6101e-04 - mae: 0.0045 - mse: 1.6101e-04 - val_loss: 6.5948e-04 - val_mae: 0.0072 - val_mse: 6.5948e-04 - 2s/epoch - 18ms/step
# Epoch 264/300
#
# Epoch 264: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6076e-04 - mae: 0.0045 - mse: 1.6076e-04 - val_loss: 7.3375e-04 - val_mae: 0.0076 - val_mse: 7.3375e-04 - 1s/epoch - 16ms/step
# Epoch 265/300
#
# Epoch 265: val_mae did not improve from 0.00679
# 88/88 - 1s - loss: 1.6104e-04 - mae: 0.0045 - mse: 1.6104e-04 - val_loss: 6.9468e-04 - val_mae: 0.0080 - val_mse: 6.9468e-04 - 1s/epoch - 16ms/step
# Epoch 266/300
#
# Epoch 266: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5891e-04 - mae: 0.0047 - mse: 1.5891e-04 - val_loss: 6.4286e-04 - val_mae: 0.0068 - val_mse: 6.4286e-04 - 2s/epoch - 27ms/step
# Epoch 267/300
#
# Epoch 267: val_mae did not improve from 0.00679
# 88/88 - 2s - loss: 1.5632e-04 - mae: 0.0045 - mse: 1.5632e-04 - val_loss: 6.9815e-04 - val_mae: 0.0071 - val_mse: 6.9815e-04 - 2s/epoch - 19ms/step
# Epoch 268/300
#
# Epoch 268: val_mae improved from 0.00679 to 0.00641, saving model to best_model.h5
# 88/88 - 2s - loss: 1.5735e-04 - mae: 0.0045 - mse: 1.5735e-04 - val_loss: 6.3029e-04 - val_mae: 0.0064 - val_mse: 6.3029e-04 - 2s/epoch - 17ms/step
# Epoch 269/300
#
# Epoch 269: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.9280e-04 - mae: 0.0054 - mse: 1.9280e-04 - val_loss: 7.1860e-04 - val_mae: 0.0075 - val_mse: 7.1860e-04 - 1s/epoch - 16ms/step
# Epoch 270/300
#
# Epoch 270: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.6565e-04 - mae: 0.0047 - mse: 1.6565e-04 - val_loss: 6.5310e-04 - val_mae: 0.0081 - val_mse: 6.5310e-04 - 2s/epoch - 17ms/step
# Epoch 271/300
#
# Epoch 271: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.6830e-04 - mae: 0.0053 - mse: 1.6830e-04 - val_loss: 6.7096e-04 - val_mae: 0.0070 - val_mse: 6.7096e-04 - 1s/epoch - 16ms/step
# Epoch 272/300
#
# Epoch 272: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5414e-04 - mae: 0.0045 - mse: 1.5414e-04 - val_loss: 6.6388e-04 - val_mae: 0.0072 - val_mse: 6.6388e-04 - 1s/epoch - 16ms/step
# Epoch 273/300
#
# Epoch 273: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.7798e-04 - mae: 0.0051 - mse: 1.7798e-04 - val_loss: 6.5432e-04 - val_mae: 0.0082 - val_mse: 6.5432e-04 - 2s/epoch - 17ms/step
# Epoch 274/300
#
# Epoch 274: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5871e-04 - mae: 0.0048 - mse: 1.5871e-04 - val_loss: 6.5383e-04 - val_mae: 0.0076 - val_mse: 6.5383e-04 - 2s/epoch - 28ms/step
# Epoch 275/300
#
# Epoch 275: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5750e-04 - mae: 0.0045 - mse: 1.5750e-04 - val_loss: 7.0549e-04 - val_mae: 0.0079 - val_mse: 7.0549e-04 - 2s/epoch - 17ms/step
# Epoch 276/300
#
# Epoch 276: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5254e-04 - mae: 0.0043 - mse: 1.5254e-04 - val_loss: 6.7609e-04 - val_mae: 0.0076 - val_mse: 6.7609e-04 - 1s/epoch - 16ms/step
# Epoch 277/300
#
# Epoch 277: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5324e-04 - mae: 0.0045 - mse: 1.5324e-04 - val_loss: 6.6076e-04 - val_mae: 0.0070 - val_mse: 6.6076e-04 - 1s/epoch - 16ms/step
# Epoch 278/300
#
# Epoch 278: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5562e-04 - mae: 0.0044 - mse: 1.5562e-04 - val_loss: 6.4384e-04 - val_mae: 0.0067 - val_mse: 6.4384e-04 - 2s/epoch - 18ms/step
# Epoch 279/300
#
# Epoch 279: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.6074e-04 - mae: 0.0047 - mse: 1.6074e-04 - val_loss: 6.9311e-04 - val_mae: 0.0077 - val_mse: 6.9311e-04 - 2s/epoch - 17ms/step
# Epoch 280/300
#
# Epoch 280: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.6129e-04 - mae: 0.0047 - mse: 1.6129e-04 - val_loss: 6.6869e-04 - val_mae: 0.0076 - val_mse: 6.6869e-04 - 1s/epoch - 16ms/step
# Epoch 281/300
#
# Epoch 281: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.6832e-04 - mae: 0.0048 - mse: 1.6832e-04 - val_loss: 6.9845e-04 - val_mae: 0.0074 - val_mse: 6.9845e-04 - 2s/epoch - 21ms/step
# Epoch 282/300
#
# Epoch 282: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5816e-04 - mae: 0.0045 - mse: 1.5816e-04 - val_loss: 6.9099e-04 - val_mae: 0.0077 - val_mse: 6.9099e-04 - 2s/epoch - 23ms/step
# Epoch 283/300
#
# Epoch 283: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5799e-04 - mae: 0.0046 - mse: 1.5799e-04 - val_loss: 6.2106e-04 - val_mae: 0.0073 - val_mse: 6.2106e-04 - 1s/epoch - 16ms/step
# Epoch 284/300
#
# Epoch 284: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5567e-04 - mae: 0.0045 - mse: 1.5567e-04 - val_loss: 7.0599e-04 - val_mae: 0.0073 - val_mse: 7.0599e-04 - 1s/epoch - 17ms/step
# Epoch 285/300
#
# Epoch 285: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5304e-04 - mae: 0.0043 - mse: 1.5304e-04 - val_loss: 6.2356e-04 - val_mae: 0.0065 - val_mse: 6.2356e-04 - 1s/epoch - 17ms/step
# Epoch 286/300
#
# Epoch 286: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.6644e-04 - mae: 0.0046 - mse: 1.6644e-04 - val_loss: 6.8665e-04 - val_mae: 0.0077 - val_mse: 6.8665e-04 - 1s/epoch - 16ms/step
# Epoch 287/300
#
# Epoch 287: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5333e-04 - mae: 0.0044 - mse: 1.5333e-04 - val_loss: 6.5466e-04 - val_mae: 0.0073 - val_mse: 6.5466e-04 - 2s/epoch - 18ms/step
# Epoch 288/300
#
# Epoch 288: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.4953e-04 - mae: 0.0043 - mse: 1.4953e-04 - val_loss: 6.9859e-04 - val_mae: 0.0070 - val_mse: 6.9859e-04 - 1s/epoch - 17ms/step
# Epoch 289/300
#
# Epoch 289: val_mae did not improve from 0.00641
# 88/88 - 3s - loss: 1.5254e-04 - mae: 0.0044 - mse: 1.5254e-04 - val_loss: 6.1103e-04 - val_mae: 0.0069 - val_mse: 6.1103e-04 - 3s/epoch - 28ms/step
# Epoch 290/300
#
# Epoch 290: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5357e-04 - mae: 0.0044 - mse: 1.5357e-04 - val_loss: 6.9440e-04 - val_mae: 0.0068 - val_mse: 6.9440e-04 - 2s/epoch - 18ms/step
# Epoch 291/300
#
# Epoch 291: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.4989e-04 - mae: 0.0044 - mse: 1.4989e-04 - val_loss: 6.5967e-04 - val_mae: 0.0077 - val_mse: 6.5967e-04 - 2s/epoch - 17ms/step
# Epoch 292/300
#
# Epoch 292: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.4620e-04 - mae: 0.0043 - mse: 1.4620e-04 - val_loss: 6.9558e-04 - val_mae: 0.0071 - val_mse: 6.9558e-04 - 1s/epoch - 16ms/step
# Epoch 293/300
#
# Epoch 293: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.6898e-04 - mae: 0.0047 - mse: 1.6898e-04 - val_loss: 6.7759e-04 - val_mae: 0.0074 - val_mse: 6.7759e-04 - 1s/epoch - 17ms/step
# Epoch 294/300
#
# Epoch 294: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.5872e-04 - mae: 0.0048 - mse: 1.5872e-04 - val_loss: 6.9821e-04 - val_mae: 0.0069 - val_mse: 6.9821e-04 - 1s/epoch - 16ms/step
# Epoch 295/300
#
# Epoch 295: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.5443e-04 - mae: 0.0044 - mse: 1.5443e-04 - val_loss: 6.5680e-04 - val_mae: 0.0068 - val_mse: 6.5680e-04 - 2s/epoch - 18ms/step
# Epoch 296/300
#
# Epoch 296: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.4820e-04 - mae: 0.0042 - mse: 1.4820e-04 - val_loss: 6.4440e-04 - val_mae: 0.0070 - val_mse: 6.4440e-04 - 2s/epoch - 18ms/step
# Epoch 297/300
#
# Epoch 297: val_mae did not improve from 0.00641
# 88/88 - 2s - loss: 1.4907e-04 - mae: 0.0042 - mse: 1.4907e-04 - val_loss: 6.4509e-04 - val_mae: 0.0070 - val_mse: 6.4509e-04 - 2s/epoch - 28ms/step
# Epoch 298/300
#
# Epoch 298: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.4851e-04 - mae: 0.0043 - mse: 1.4851e-04 - val_loss: 6.7059e-04 - val_mae: 0.0071 - val_mse: 6.7059e-04 - 1s/epoch - 17ms/step
# Epoch 299/300
#
# Epoch 299: val_mae did not improve from 0.00641
# 88/88 - 1s - loss: 1.4973e-04 - mae: 0.0042 - mse: 1.4973e-04 - val_loss: 6.4668e-04 - val_mae: 0.0067 - val_mse: 6.4668e-04 - 1s/epoch - 16ms/step
# Epoch 300/300
#
# Epoch 300: val_mae improved from 0.00641 to 0.00635, saving model to best_model.h5
# 88/88 - 2s - loss: 1.5961e-04 - mae: 0.0045 - mse: 1.5961e-04 - val_loss: 6.1358e-04 - val_mae: 0.0063 - val_mse: 6.1358e-04 - 2s/epoch - 17ms/step

# %% [markdown]
# Load the best model

# %%
# Load the best model
# Load the best model using keras.utils.custom_object_scope
from tensorflow.keras.models import load_model
custom_objects = {"AttentionLayer": AttentionLayer}
with tf.keras.utils.custom_object_scope(custom_objects):
    best_model = load_model(checkpoint_path,compile=False)

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.006345553323626518
# Minimum Validation MAE at epoch 299
# Minimum Validation loss 0.00014620274305343628
# Minimum Validation loss at epoch 288

# %%
trainPredict = best_model.predict(trainX)
testPredict = best_model.predict(testX)
# Out:
# 175/175 [==============================] - 3s 4ms/step
# 94/94 [==============================] - 0s 4ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.24 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.50 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.07365000088580942
# Mean Absolute Error on test data: 0.1269110509111697

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.05859713255803569
# Mean Squared Error (MSE) of test: 0.24543382618287907

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         0      1376314846          2                     5851.998636
# 1         1      1376315146          2                     5851.998636
# 2         2      1376315446          2                     5851.998636
# 3         3      1376315746          2                     5851.998636
# 4         4      1376316046          2                     5851.998636
# ...     ...             ...        ...                             ...
# 8627   8627      1378905598          2                     5851.998944
# 8628   8628      1378905898          2                     5851.998944
# 8629   8629      1378906198          2                     5851.998944
# 8630   8630      1378906498          2                     5851.998944
# 8631   8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 13 columns]

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[30:530],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+30:6198+30],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
