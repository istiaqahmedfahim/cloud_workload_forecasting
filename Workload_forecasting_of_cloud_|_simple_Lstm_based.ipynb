# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/Workload_forecasting_of_cloud_%7C_simple_Lstm_based.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'cloud-computing-history-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4018029%2F6990719%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240205%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240205T135728Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading cloud-computing-history-data, 143815 bytes compressed
# [==================================================] 143815 bytes downloaded
# Downloaded and uncompressed: cloud-computing-history-data
# Data source import complete.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv("/kaggle/input/cloud-computing-history-data/43.csv")
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
# model = Sequential()
# model.add(LSTM(50,return_sequences=True, input_shape=(None, seq_size)))
# model.add(LSTM(units=50))
# model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
# model2 = tf.keras.models.Sequential([
#   tf.keras.layers.Conv1D(filters=64,kernel_size=5,
#                       strides=1, padding="causal",
#                       activation="relu",
#                       input_shape=[None, seq_size]),
#   tf.keras.layers.BatchNormalization(),
#   tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
#   tf.keras.layers.BatchNormalization(),
#   tf.keras.layers.GRU(64,activation="relu"),
#   tf.keras.layers.Dense(30, activation="relu"),
#   tf.keras.layers.Dense(15, activation="relu"),
#   tf.keras.layers.Dense(1,'linear')
# ])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model3 = tf.keras.models.Sequential([
  tf.keras.layers.LSTM(64,activation="relu", input_shape=[None, seq_size]),
  tf.keras.layers.Dense(1,'linear')
])

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import Layer, Attention

# class AttentionLayer(Layer):
#     def __init__(self, **kwargs):
#         super(AttentionLayer, self).__init__(**kwargs)

#     def build(self, input_shape):
#         self.W_q = self.add_weight(name="W_q", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
#         self.W_k = self.add_weight(name="W_k", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
#         self.V = self.add_weight(name="V", shape=(input_shape[-1], 1), initializer="uniform", trainable=True)
#         super(AttentionLayer, self).build(input_shape)

#     def call(self, x):
#         q = tf.matmul(x, self.W_q)
#         k = tf.matmul(x, self.W_k)
#         scores = tf.matmul(tf.nn.tanh(q + k), self.V)
#         attention_weights = tf.nn.softmax(scores, axis=-2)
#         context_vector = attention_weights * x
#         return context_vector

#     def compute_output_shape(self, input_shape):
#         return input_shape

# seq_size = 30  # Replace with your sequence size

# model = tf.keras.models.Sequential([
#     tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, seq_size]),
#     tf.keras.layers.Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
#     tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
#     tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
#     tf.keras.layers.GRU(64, activation="relu", return_sequences=True),
#     AttentionLayer(),  # Add Attention Layer
#     tf.keras.layers.Bidirectional(LSTM(50, activation="relu")),  # Return sequences here
#     tf.keras.layers.Dense(1, 'linear')
# ])

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                24320
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 24,385
# Trainable params: 24,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model3.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae','mse'])

# %% [markdown]
# # Model Fitting

# %%
history = model3.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 175/175 - 8s - loss: 0.0014 - mae: 0.0235 - mse: 0.0014 - val_loss: 0.0013 - val_mae: 0.0181 - val_mse: 0.0013 - 8s/epoch - 44ms/step
# Epoch 2/100
# 175/175 - 2s - loss: 8.3409e-04 - mae: 0.0163 - mse: 8.3409e-04 - val_loss: 0.0011 - val_mae: 0.0167 - val_mse: 0.0011 - 2s/epoch - 13ms/step
# Epoch 3/100
# 175/175 - 1s - loss: 7.1165e-04 - mae: 0.0140 - mse: 7.1165e-04 - val_loss: 9.9128e-04 - val_mae: 0.0139 - val_mse: 9.9128e-04 - 1s/epoch - 7ms/step
# Epoch 4/100
# 175/175 - 1s - loss: 6.5789e-04 - mae: 0.0130 - mse: 6.5789e-04 - val_loss: 9.4514e-04 - val_mae: 0.0147 - val_mse: 9.4514e-04 - 1s/epoch - 8ms/step
# Epoch 5/100
# 175/175 - 1s - loss: 6.2324e-04 - mae: 0.0125 - mse: 6.2324e-04 - val_loss: 9.3981e-04 - val_mae: 0.0162 - val_mse: 9.3981e-04 - 820ms/epoch - 5ms/step
# Epoch 6/100
# 175/175 - 1s - loss: 6.0321e-04 - mae: 0.0126 - mse: 6.0321e-04 - val_loss: 9.1729e-04 - val_mae: 0.0159 - val_mse: 9.1729e-04 - 769ms/epoch - 4ms/step
# Epoch 7/100
# 175/175 - 1s - loss: 5.7480e-04 - mae: 0.0123 - mse: 5.7480e-04 - val_loss: 9.3027e-04 - val_mae: 0.0126 - val_mse: 9.3027e-04 - 1s/epoch - 6ms/step
# Epoch 8/100
# 175/175 - 1s - loss: 5.6023e-04 - mae: 0.0120 - mse: 5.6023e-04 - val_loss: 8.7961e-04 - val_mae: 0.0126 - val_mse: 8.7961e-04 - 1s/epoch - 7ms/step
# Epoch 9/100
# 175/175 - 1s - loss: 5.4811e-04 - mae: 0.0120 - mse: 5.4811e-04 - val_loss: 8.6157e-04 - val_mae: 0.0133 - val_mse: 8.6157e-04 - 707ms/epoch - 4ms/step
# Epoch 10/100
# 175/175 - 1s - loss: 5.3147e-04 - mae: 0.0117 - mse: 5.3147e-04 - val_loss: 8.6811e-04 - val_mae: 0.0134 - val_mse: 8.6811e-04 - 875ms/epoch - 5ms/step
# Epoch 11/100
# 175/175 - 1s - loss: 5.2386e-04 - mae: 0.0121 - mse: 5.2386e-04 - val_loss: 8.7184e-04 - val_mae: 0.0130 - val_mse: 8.7184e-04 - 873ms/epoch - 5ms/step
# Epoch 12/100
# 175/175 - 1s - loss: 5.0401e-04 - mae: 0.0113 - mse: 5.0401e-04 - val_loss: 8.3797e-04 - val_mae: 0.0128 - val_mse: 8.3797e-04 - 766ms/epoch - 4ms/step
# Epoch 13/100
# 175/175 - 1s - loss: 4.9419e-04 - mae: 0.0114 - mse: 4.9419e-04 - val_loss: 8.3603e-04 - val_mae: 0.0142 - val_mse: 8.3603e-04 - 721ms/epoch - 4ms/step
# Epoch 14/100
# 175/175 - 1s - loss: 4.7565e-04 - mae: 0.0111 - mse: 4.7565e-04 - val_loss: 8.3153e-04 - val_mae: 0.0141 - val_mse: 8.3153e-04 - 867ms/epoch - 5ms/step
# Epoch 15/100
# 175/175 - 1s - loss: 4.6678e-04 - mae: 0.0109 - mse: 4.6678e-04 - val_loss: 8.2219e-04 - val_mae: 0.0145 - val_mse: 8.2219e-04 - 847ms/epoch - 5ms/step
# Epoch 16/100
# 175/175 - 1s - loss: 4.6016e-04 - mae: 0.0112 - mse: 4.6016e-04 - val_loss: 8.1335e-04 - val_mae: 0.0122 - val_mse: 8.1335e-04 - 869ms/epoch - 5ms/step
# Epoch 17/100
# 175/175 - 1s - loss: 4.4392e-04 - mae: 0.0108 - mse: 4.4392e-04 - val_loss: 8.2815e-04 - val_mae: 0.0130 - val_mse: 8.2815e-04 - 827ms/epoch - 5ms/step
# Epoch 18/100
# 175/175 - 1s - loss: 4.3635e-04 - mae: 0.0106 - mse: 4.3635e-04 - val_loss: 8.1142e-04 - val_mae: 0.0138 - val_mse: 8.1142e-04 - 719ms/epoch - 4ms/step
# Epoch 19/100
# 175/175 - 1s - loss: 4.2943e-04 - mae: 0.0107 - mse: 4.2943e-04 - val_loss: 7.8716e-04 - val_mae: 0.0124 - val_mse: 7.8716e-04 - 742ms/epoch - 4ms/step
# Epoch 20/100
# 175/175 - 1s - loss: 4.0969e-04 - mae: 0.0103 - mse: 4.0969e-04 - val_loss: 8.1479e-04 - val_mae: 0.0150 - val_mse: 8.1479e-04 - 870ms/epoch - 5ms/step
# Epoch 21/100
# 175/175 - 1s - loss: 4.0358e-04 - mae: 0.0103 - mse: 4.0358e-04 - val_loss: 7.9595e-04 - val_mae: 0.0126 - val_mse: 7.9595e-04 - 1s/epoch - 6ms/step
# Epoch 22/100
# 175/175 - 1s - loss: 3.9494e-04 - mae: 0.0102 - mse: 3.9494e-04 - val_loss: 7.8492e-04 - val_mae: 0.0133 - val_mse: 7.8492e-04 - 1s/epoch - 7ms/step
# Epoch 23/100
# 175/175 - 1s - loss: 3.9027e-04 - mae: 0.0102 - mse: 3.9027e-04 - val_loss: 7.7518e-04 - val_mae: 0.0129 - val_mse: 7.7518e-04 - 1s/epoch - 6ms/step
# Epoch 24/100
# 175/175 - 1s - loss: 3.8532e-04 - mae: 0.0102 - mse: 3.8532e-04 - val_loss: 7.9020e-04 - val_mae: 0.0132 - val_mse: 7.9020e-04 - 864ms/epoch - 5ms/step
# Epoch 25/100
# 175/175 - 1s - loss: 3.7690e-04 - mae: 0.0102 - mse: 3.7690e-04 - val_loss: 7.8009e-04 - val_mae: 0.0127 - val_mse: 7.8009e-04 - 735ms/epoch - 4ms/step
# Epoch 26/100
# 175/175 - 1s - loss: 3.6467e-04 - mae: 0.0098 - mse: 3.6467e-04 - val_loss: 7.9349e-04 - val_mae: 0.0123 - val_mse: 7.9349e-04 - 880ms/epoch - 5ms/step
# Epoch 27/100
# 175/175 - 1s - loss: 3.5713e-04 - mae: 0.0097 - mse: 3.5713e-04 - val_loss: 7.7979e-04 - val_mae: 0.0134 - val_mse: 7.7979e-04 - 889ms/epoch - 5ms/step
# Epoch 28/100
# 175/175 - 1s - loss: 3.6019e-04 - mae: 0.0100 - mse: 3.6019e-04 - val_loss: 8.2965e-04 - val_mae: 0.0131 - val_mse: 8.2965e-04 - 787ms/epoch - 4ms/step
# Epoch 29/100
# 175/175 - 1s - loss: 3.5556e-04 - mae: 0.0099 - mse: 3.5556e-04 - val_loss: 8.0058e-04 - val_mae: 0.0124 - val_mse: 8.0058e-04 - 802ms/epoch - 5ms/step
# Epoch 30/100
# 175/175 - 1s - loss: 3.5158e-04 - mae: 0.0099 - mse: 3.5158e-04 - val_loss: 8.0826e-04 - val_mae: 0.0133 - val_mse: 8.0826e-04 - 746ms/epoch - 4ms/step
# Epoch 31/100
# 175/175 - 1s - loss: 3.4609e-04 - mae: 0.0097 - mse: 3.4609e-04 - val_loss: 7.9506e-04 - val_mae: 0.0125 - val_mse: 7.9506e-04 - 864ms/epoch - 5ms/step
# Epoch 32/100
# 175/175 - 1s - loss: 3.4316e-04 - mae: 0.0098 - mse: 3.4316e-04 - val_loss: 7.9781e-04 - val_mae: 0.0127 - val_mse: 7.9781e-04 - 745ms/epoch - 4ms/step
# Epoch 33/100
# 175/175 - 1s - loss: 3.3636e-04 - mae: 0.0095 - mse: 3.3636e-04 - val_loss: 7.8263e-04 - val_mae: 0.0132 - val_mse: 7.8263e-04 - 793ms/epoch - 5ms/step
# Epoch 34/100
# 175/175 - 1s - loss: 3.3294e-04 - mae: 0.0095 - mse: 3.3294e-04 - val_loss: 7.9940e-04 - val_mae: 0.0128 - val_mse: 7.9940e-04 - 858ms/epoch - 5ms/step
# Epoch 35/100
# 175/175 - 1s - loss: 3.2614e-04 - mae: 0.0092 - mse: 3.2614e-04 - val_loss: 7.7700e-04 - val_mae: 0.0123 - val_mse: 7.7700e-04 - 1s/epoch - 6ms/step
# Epoch 36/100
# 175/175 - 1s - loss: 3.2228e-04 - mae: 0.0093 - mse: 3.2228e-04 - val_loss: 7.8231e-04 - val_mae: 0.0132 - val_mse: 7.8231e-04 - 1s/epoch - 7ms/step
# Epoch 37/100
# 175/175 - 1s - loss: 3.2275e-04 - mae: 0.0094 - mse: 3.2275e-04 - val_loss: 8.2551e-04 - val_mae: 0.0128 - val_mse: 8.2551e-04 - 1s/epoch - 6ms/step
# Epoch 38/100
# 175/175 - 1s - loss: 3.1719e-04 - mae: 0.0091 - mse: 3.1719e-04 - val_loss: 7.9616e-04 - val_mae: 0.0128 - val_mse: 7.9616e-04 - 868ms/epoch - 5ms/step
# Epoch 39/100
# 175/175 - 1s - loss: 3.1582e-04 - mae: 0.0092 - mse: 3.1582e-04 - val_loss: 7.7421e-04 - val_mae: 0.0125 - val_mse: 7.7421e-04 - 822ms/epoch - 5ms/step
# Epoch 40/100
# 175/175 - 1s - loss: 3.1824e-04 - mae: 0.0095 - mse: 3.1824e-04 - val_loss: 7.9619e-04 - val_mae: 0.0138 - val_mse: 7.9619e-04 - 810ms/epoch - 5ms/step
# Epoch 41/100
# 175/175 - 1s - loss: 3.0659e-04 - mae: 0.0090 - mse: 3.0659e-04 - val_loss: 8.0769e-04 - val_mae: 0.0122 - val_mse: 8.0769e-04 - 812ms/epoch - 5ms/step
# Epoch 42/100
# 175/175 - 1s - loss: 3.0691e-04 - mae: 0.0090 - mse: 3.0691e-04 - val_loss: 7.9449e-04 - val_mae: 0.0134 - val_mse: 7.9449e-04 - 740ms/epoch - 4ms/step
# Epoch 43/100
# 175/175 - 1s - loss: 3.0893e-04 - mae: 0.0092 - mse: 3.0893e-04 - val_loss: 8.0932e-04 - val_mae: 0.0122 - val_mse: 8.0932e-04 - 740ms/epoch - 4ms/step
# Epoch 44/100
# 175/175 - 1s - loss: 3.0629e-04 - mae: 0.0091 - mse: 3.0629e-04 - val_loss: 8.4338e-04 - val_mae: 0.0132 - val_mse: 8.4338e-04 - 726ms/epoch - 4ms/step
# Epoch 45/100
# 175/175 - 1s - loss: 3.0112e-04 - mae: 0.0090 - mse: 3.0112e-04 - val_loss: 8.1471e-04 - val_mae: 0.0141 - val_mse: 8.1471e-04 - 866ms/epoch - 5ms/step
# Epoch 46/100
# 175/175 - 1s - loss: 2.9784e-04 - mae: 0.0091 - mse: 2.9784e-04 - val_loss: 8.0488e-04 - val_mae: 0.0135 - val_mse: 8.0488e-04 - 878ms/epoch - 5ms/step
# Epoch 47/100
# 175/175 - 1s - loss: 3.0359e-04 - mae: 0.0092 - mse: 3.0359e-04 - val_loss: 7.8136e-04 - val_mae: 0.0122 - val_mse: 7.8136e-04 - 914ms/epoch - 5ms/step
# Epoch 48/100
# 175/175 - 1s - loss: 2.9754e-04 - mae: 0.0090 - mse: 2.9754e-04 - val_loss: 8.7263e-04 - val_mae: 0.0142 - val_mse: 8.7263e-04 - 870ms/epoch - 5ms/step
# Epoch 49/100
# 175/175 - 1s - loss: 2.9571e-04 - mae: 0.0090 - mse: 2.9571e-04 - val_loss: 7.8927e-04 - val_mae: 0.0125 - val_mse: 7.8927e-04 - 1s/epoch - 6ms/step
# Epoch 50/100
# 175/175 - 1s - loss: 2.9333e-04 - mae: 0.0090 - mse: 2.9333e-04 - val_loss: 8.4954e-04 - val_mae: 0.0135 - val_mse: 8.4954e-04 - 1s/epoch - 7ms/step
# Epoch 51/100
# 175/175 - 1s - loss: 2.8899e-04 - mae: 0.0088 - mse: 2.8899e-04 - val_loss: 7.9932e-04 - val_mae: 0.0121 - val_mse: 7.9932e-04 - 961ms/epoch - 5ms/step
# Epoch 52/100
# 175/175 - 1s - loss: 2.8843e-04 - mae: 0.0087 - mse: 2.8843e-04 - val_loss: 7.7217e-04 - val_mae: 0.0122 - val_mse: 7.7217e-04 - 832ms/epoch - 5ms/step
# Epoch 53/100
# 175/175 - 1s - loss: 2.9003e-04 - mae: 0.0090 - mse: 2.9003e-04 - val_loss: 7.8514e-04 - val_mae: 0.0120 - val_mse: 7.8514e-04 - 842ms/epoch - 5ms/step
# Epoch 54/100
# 175/175 - 1s - loss: 2.7867e-04 - mae: 0.0084 - mse: 2.7867e-04 - val_loss: 7.8304e-04 - val_mae: 0.0121 - val_mse: 7.8304e-04 - 854ms/epoch - 5ms/step
# Epoch 55/100
# 175/175 - 1s - loss: 2.8239e-04 - mae: 0.0087 - mse: 2.8239e-04 - val_loss: 8.0095e-04 - val_mae: 0.0126 - val_mse: 8.0095e-04 - 697ms/epoch - 4ms/step
# Epoch 56/100
# 175/175 - 1s - loss: 2.8309e-04 - mae: 0.0087 - mse: 2.8309e-04 - val_loss: 7.8312e-04 - val_mae: 0.0123 - val_mse: 7.8312e-04 - 680ms/epoch - 4ms/step
# Epoch 57/100
# 175/175 - 1s - loss: 2.8010e-04 - mae: 0.0086 - mse: 2.8010e-04 - val_loss: 8.1292e-04 - val_mae: 0.0121 - val_mse: 8.1292e-04 - 807ms/epoch - 5ms/step
# Epoch 58/100
# 175/175 - 1s - loss: 2.7833e-04 - mae: 0.0087 - mse: 2.7833e-04 - val_loss: 7.8803e-04 - val_mae: 0.0128 - val_mse: 7.8803e-04 - 688ms/epoch - 4ms/step
# Epoch 59/100
# 175/175 - 1s - loss: 2.8149e-04 - mae: 0.0089 - mse: 2.8149e-04 - val_loss: 8.0322e-04 - val_mae: 0.0133 - val_mse: 8.0322e-04 - 869ms/epoch - 5ms/step
# Epoch 60/100
# 175/175 - 1s - loss: 2.7328e-04 - mae: 0.0084 - mse: 2.7328e-04 - val_loss: 8.7363e-04 - val_mae: 0.0142 - val_mse: 8.7363e-04 - 724ms/epoch - 4ms/step
# Epoch 61/100
# 175/175 - 1s - loss: 2.7434e-04 - mae: 0.0086 - mse: 2.7434e-04 - val_loss: 7.9262e-04 - val_mae: 0.0125 - val_mse: 7.9262e-04 - 715ms/epoch - 4ms/step
# Epoch 62/100
# 175/175 - 1s - loss: 2.6910e-04 - mae: 0.0084 - mse: 2.6910e-04 - val_loss: 8.0966e-04 - val_mae: 0.0124 - val_mse: 8.0966e-04 - 875ms/epoch - 5ms/step
# Epoch 63/100
# 175/175 - 1s - loss: 2.7575e-04 - mae: 0.0086 - mse: 2.7575e-04 - val_loss: 8.5334e-04 - val_mae: 0.0127 - val_mse: 8.5334e-04 - 872ms/epoch - 5ms/step
# Epoch 64/100
# 175/175 - 1s - loss: 2.7102e-04 - mae: 0.0085 - mse: 2.7102e-04 - val_loss: 7.9153e-04 - val_mae: 0.0131 - val_mse: 7.9153e-04 - 1s/epoch - 7ms/step
# Epoch 65/100
# 175/175 - 1s - loss: 2.6965e-04 - mae: 0.0085 - mse: 2.6965e-04 - val_loss: 8.1904e-04 - val_mae: 0.0123 - val_mse: 8.1904e-04 - 1s/epoch - 7ms/step
# Epoch 66/100
# 175/175 - 1s - loss: 2.7111e-04 - mae: 0.0086 - mse: 2.7111e-04 - val_loss: 7.9042e-04 - val_mae: 0.0120 - val_mse: 7.9042e-04 - 754ms/epoch - 4ms/step
# Epoch 67/100
# 175/175 - 1s - loss: 2.6663e-04 - mae: 0.0084 - mse: 2.6663e-04 - val_loss: 8.1108e-04 - val_mae: 0.0124 - val_mse: 8.1108e-04 - 901ms/epoch - 5ms/step
# Epoch 68/100
# 175/175 - 1s - loss: 2.6305e-04 - mae: 0.0084 - mse: 2.6305e-04 - val_loss: 8.7209e-04 - val_mae: 0.0137 - val_mse: 8.7209e-04 - 913ms/epoch - 5ms/step
# Epoch 69/100
# 175/175 - 1s - loss: 2.6410e-04 - mae: 0.0084 - mse: 2.6410e-04 - val_loss: 8.0475e-04 - val_mae: 0.0126 - val_mse: 8.0475e-04 - 936ms/epoch - 5ms/step
# Epoch 70/100
# 175/175 - 1s - loss: 2.6493e-04 - mae: 0.0084 - mse: 2.6493e-04 - val_loss: 8.0363e-04 - val_mae: 0.0124 - val_mse: 8.0363e-04 - 772ms/epoch - 4ms/step
# Epoch 71/100
# 175/175 - 1s - loss: 2.6080e-04 - mae: 0.0082 - mse: 2.6080e-04 - val_loss: 8.4390e-04 - val_mae: 0.0143 - val_mse: 8.4390e-04 - 713ms/epoch - 4ms/step
# Epoch 72/100
# 175/175 - 1s - loss: 2.6676e-04 - mae: 0.0088 - mse: 2.6676e-04 - val_loss: 7.9040e-04 - val_mae: 0.0119 - val_mse: 7.9040e-04 - 722ms/epoch - 4ms/step
# Epoch 73/100
# 175/175 - 1s - loss: 2.5902e-04 - mae: 0.0084 - mse: 2.5902e-04 - val_loss: 8.2752e-04 - val_mae: 0.0144 - val_mse: 8.2752e-04 - 871ms/epoch - 5ms/step
# Epoch 74/100
# 175/175 - 1s - loss: 2.6757e-04 - mae: 0.0087 - mse: 2.6757e-04 - val_loss: 7.8951e-04 - val_mae: 0.0121 - val_mse: 7.8951e-04 - 743ms/epoch - 4ms/step
# Epoch 75/100
# 175/175 - 1s - loss: 2.6444e-04 - mae: 0.0085 - mse: 2.6444e-04 - val_loss: 8.2349e-04 - val_mae: 0.0148 - val_mse: 8.2349e-04 - 722ms/epoch - 4ms/step
# Epoch 76/100
# 175/175 - 1s - loss: 2.5930e-04 - mae: 0.0084 - mse: 2.5930e-04 - val_loss: 7.8650e-04 - val_mae: 0.0122 - val_mse: 7.8650e-04 - 884ms/epoch - 5ms/step
# Epoch 77/100
# 175/175 - 1s - loss: 2.5479e-04 - mae: 0.0082 - mse: 2.5479e-04 - val_loss: 8.1320e-04 - val_mae: 0.0126 - val_mse: 8.1320e-04 - 747ms/epoch - 4ms/step
# Epoch 78/100
# 175/175 - 3s - loss: 2.5849e-04 - mae: 0.0085 - mse: 2.5849e-04 - val_loss: 8.0582e-04 - val_mae: 0.0120 - val_mse: 8.0582e-04 - 3s/epoch - 19ms/step
# Epoch 79/100
# 175/175 - 1s - loss: 2.6245e-04 - mae: 0.0086 - mse: 2.6245e-04 - val_loss: 7.9149e-04 - val_mae: 0.0119 - val_mse: 7.9149e-04 - 847ms/epoch - 5ms/step
# Epoch 80/100
# 175/175 - 1s - loss: 2.5769e-04 - mae: 0.0084 - mse: 2.5769e-04 - val_loss: 8.5806e-04 - val_mae: 0.0122 - val_mse: 8.5806e-04 - 867ms/epoch - 5ms/step
# Epoch 81/100
# 175/175 - 1s - loss: 2.5966e-04 - mae: 0.0084 - mse: 2.5966e-04 - val_loss: 8.0929e-04 - val_mae: 0.0124 - val_mse: 8.0929e-04 - 849ms/epoch - 5ms/step
# Epoch 82/100
# 175/175 - 1s - loss: 2.5254e-04 - mae: 0.0082 - mse: 2.5254e-04 - val_loss: 8.5927e-04 - val_mae: 0.0146 - val_mse: 8.5927e-04 - 858ms/epoch - 5ms/step
# Epoch 83/100
# 175/175 - 1s - loss: 2.5431e-04 - mae: 0.0083 - mse: 2.5431e-04 - val_loss: 8.1320e-04 - val_mae: 0.0120 - val_mse: 8.1320e-04 - 843ms/epoch - 5ms/step
# Epoch 84/100
# 175/175 - 1s - loss: 2.5151e-04 - mae: 0.0083 - mse: 2.5151e-04 - val_loss: 8.0480e-04 - val_mae: 0.0120 - val_mse: 8.0480e-04 - 844ms/epoch - 5ms/step
# Epoch 85/100
# 175/175 - 1s - loss: 2.5015e-04 - mae: 0.0080 - mse: 2.5015e-04 - val_loss: 8.1952e-04 - val_mae: 0.0121 - val_mse: 8.1952e-04 - 723ms/epoch - 4ms/step
# Epoch 86/100
# 175/175 - 1s - loss: 2.5447e-04 - mae: 0.0083 - mse: 2.5447e-04 - val_loss: 8.0603e-04 - val_mae: 0.0115 - val_mse: 8.0603e-04 - 748ms/epoch - 4ms/step
# Epoch 87/100
# 175/175 - 1s - loss: 2.5827e-04 - mae: 0.0085 - mse: 2.5827e-04 - val_loss: 7.9620e-04 - val_mae: 0.0118 - val_mse: 7.9620e-04 - 842ms/epoch - 5ms/step
# Epoch 88/100
# 175/175 - 1s - loss: 2.4446e-04 - mae: 0.0078 - mse: 2.4446e-04 - val_loss: 8.0929e-04 - val_mae: 0.0119 - val_mse: 8.0929e-04 - 887ms/epoch - 5ms/step
# Epoch 89/100
# 175/175 - 1s - loss: 2.4565e-04 - mae: 0.0078 - mse: 2.4565e-04 - val_loss: 8.6326e-04 - val_mae: 0.0154 - val_mse: 8.6326e-04 - 851ms/epoch - 5ms/step
# Epoch 90/100
# 175/175 - 1s - loss: 2.5273e-04 - mae: 0.0082 - mse: 2.5273e-04 - val_loss: 8.2344e-04 - val_mae: 0.0132 - val_mse: 8.2344e-04 - 1s/epoch - 6ms/step
# Epoch 91/100
# 175/175 - 1s - loss: 2.4767e-04 - mae: 0.0081 - mse: 2.4767e-04 - val_loss: 8.2498e-04 - val_mae: 0.0122 - val_mse: 8.2498e-04 - 1s/epoch - 7ms/step
# Epoch 92/100
# 175/175 - 1s - loss: 2.4610e-04 - mae: 0.0080 - mse: 2.4610e-04 - val_loss: 7.9429e-04 - val_mae: 0.0117 - val_mse: 7.9429e-04 - 1s/epoch - 6ms/step
# Epoch 93/100
# 175/175 - 1s - loss: 2.4368e-04 - mae: 0.0079 - mse: 2.4368e-04 - val_loss: 8.2568e-04 - val_mae: 0.0116 - val_mse: 8.2568e-04 - 872ms/epoch - 5ms/step
# Epoch 94/100
# 175/175 - 1s - loss: 2.4950e-04 - mae: 0.0082 - mse: 2.4950e-04 - val_loss: 8.3146e-04 - val_mae: 0.0119 - val_mse: 8.3146e-04 - 667ms/epoch - 4ms/step
# Epoch 95/100
# 175/175 - 1s - loss: 2.4175e-04 - mae: 0.0078 - mse: 2.4175e-04 - val_loss: 8.4237e-04 - val_mae: 0.0130 - val_mse: 8.4237e-04 - 876ms/epoch - 5ms/step
# Epoch 96/100
# 175/175 - 1s - loss: 2.4616e-04 - mae: 0.0082 - mse: 2.4616e-04 - val_loss: 8.2579e-04 - val_mae: 0.0122 - val_mse: 8.2579e-04 - 681ms/epoch - 4ms/step
# Epoch 97/100
# 175/175 - 1s - loss: 2.4292e-04 - mae: 0.0081 - mse: 2.4292e-04 - val_loss: 8.6682e-04 - val_mae: 0.0137 - val_mse: 8.6682e-04 - 867ms/epoch - 5ms/step
# Epoch 98/100
# 175/175 - 1s - loss: 2.4941e-04 - mae: 0.0083 - mse: 2.4941e-04 - val_loss: 8.4150e-04 - val_mae: 0.0120 - val_mse: 8.4150e-04 - 886ms/epoch - 5ms/step
# Epoch 99/100
# 175/175 - 1s - loss: 2.4016e-04 - mae: 0.0078 - mse: 2.4016e-04 - val_loss: 8.3236e-04 - val_mae: 0.0135 - val_mse: 8.3236e-04 - 888ms/epoch - 5ms/step
# Epoch 100/100
# 175/175 - 1s - loss: 2.4009e-04 - mae: 0.0081 - mse: 2.4009e-04 - val_loss: 8.4831e-04 - val_mae: 0.0127 - val_mse: 8.4831e-04 - 738ms/epoch - 4ms/step

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.011490990407764912
# Minimum Validation MAE at epoch 85
# Minimum Validation loss 0.00024009321350604296
# Minimum Validation loss at epoch 51

# %%
trainPredict = model3.predict(trainX)
testPredict = model3.predict(testX)
# Out:
# 175/175 [==============================] - 2s 7ms/step
# 94/94 [==============================] - 1s 8ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.31 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.58 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.16252267862499772
# Mean Absolute Error on test data: 0.25382098239400186

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.0981168042729473
# Mean Squared Error (MSE) of test: 0.3393237119647527

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         0      1376314846          2                     5851.998636
# 1         1      1376315146          2                     5851.998636
# 2         2      1376315446          2                     5851.998636
# 3         3      1376315746          2                     5851.998636
# 4         4      1376316046          2                     5851.998636
# ...     ...             ...        ...                             ...
# 8627   8627      1378905598          2                     5851.998944
# 8628   8628      1378905898          2                     5851.998944
# 8629   8629      1378906198          2                     5851.998944
# 8630   8630      1378906498          2                     5851.998944
# 8631   8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 13 columns]

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[30:530],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+30:6198+30],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
