# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/Final%20Workload_forecasting_of_cloud_%7C_Attention_based_Hybrid%20network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv('/content/43.csv')
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %%
desired_value = 0.0

# Find all indices where the desired value occurs in the specified column
indices_of_value = df[df['Disk I/O'] == desired_value].index

if not indices_of_value.empty:
    print(f"The value '{desired_value}' was found in the column '' at indices: {indices_of_value.tolist()}")
else:
    print(f"The value '{desired_value}' was not found in the column ''")
print(len(indices_of_value.tolist()))
# Out:
# The value '0.0' was found in the column '' at indices: [5, 9, 10, 11, 13, 17, 23, 24, 27, 33, 34, 46, 47, 53, 55, 61, 63, 65, 67, 69, 70, 73, 79, 81, 82, 93, 94, 95, 97, 98, 103, 115, 116, 118, 119, 120, 127, 128, 131, 132, 142, 143, 144, 145, 146, 149, 151, 157, 158, 160, 163, 164, 166, 167, 168, 169, 170, 178, 188, 191, 192, 193, 197, 199, 202, 203, 204, 205, 206, 211, 212, 213, 215, 216, 217, 218, 223, 224, 226, 227, 236, 239, 243, 245, 250, 252, 255, 256, 260, 263, 264, 265, 266, 271, 273, 284, 285, 286, 287, 288, 291, 293, 300, 302, 303, 305, 308, 309, 311, 312, 313, 315, 319, 320, 322, 332, 334, 336, 337, 338, 339, 340, 343, 350, 360, 361, 362, 370, 380, 382, 384, 386, 391, 404, 405, 406, 408, 415, 417, 422, 440, 463, 467, 475, 479, 486, 491, 493, 495, 498, 499, 504, 505, 524, 529, 530, 533, 534, 539, 541, 542, 547, 551, 553, 554, 555, 559, 578, 579, 581, 583, 586, 587, 589, 590]
# 175

# %%
# Drop rows with null values based on indices
df.drop(indices_of_value, inplace=True)

# Alternatively, you can create a new DataFrame without modifying the original one:
# new_df = df.drop(null_indices)

# If you want to reset the index after dropping rows:
df.reset_index(drop=True, inplace=True)

# Verify that null values have been dropped
print("DataFrame after dropping rows with null values:")
print(df)
# Out:
# DataFrame after dropping rows with null values:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8452      1378905598          2                     5851.998944
# 8453      1378905898          2                     5851.998944
# 8454      1378906198          2                     5851.998944
# 8455      1378906498          2                     5851.998944
# 8456      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8452        76.075986       1.300000                         2097152.0
# 8453        54.618657       0.933333                         2097152.0
# 8454        58.519989       1.000000                         2097152.0
# 8455       325.761275       5.566667                         2097152.0
# 8456        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8452      329950.133333                     0.333333
# 8453      244665.333333                     1.800000
# 8454      139808.800000                     0.200000
# 8455      325755.733333                  1029.666667
# 8456      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8452                    561.866667                          581.800000
# 8453                      1.133333                            2.466667
# 8454                      0.866667                            2.400000
# 8455                     55.466667                            2.466667
# 8456                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8452                              18.400000  1.409906
# 8453                               1.066667  0.007356
# 8454                               1.066667  0.002675
# 8455                               1.533333  2.721338
# 8456                               1.000000  0.002173
#
# [8457 rows x 12 columns]

# %%
desired_value = 0.0

# Find all indices where the desired value occurs in the specified column
indices_of_value = df[df['Disk I/O'] == desired_value].index

if not indices_of_value.empty:
    print(f"The value '{desired_value}' was found in the column '' at indices: {indices_of_value.tolist()}")
else:
    print(f"The value '{desired_value}' was not found in the column ''")
print(len(indices_of_value.tolist()))
# Out:
# The value '0.0' was not found in the column ''
# 0

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from tensorflow.keras.layers import Layer, Attention

class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W_q = self.add_weight(name="W_q", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.W_k = self.add_weight(name="W_k", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.V = self.add_weight(name="V", shape=(input_shape[-1], 1), initializer="uniform", trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        q = tf.matmul(x, self.W_q)
        k = tf.matmul(x, self.W_k)
        scores = tf.matmul(tf.nn.tanh(q + k), self.V)
        attention_weights = tf.nn.softmax(scores, axis=-2)
        context_vector = attention_weights * x
        return context_vector

    def compute_output_shape(self, input_shape):
        return input_shape

 # My best model
def create_model(seq_size):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, seq_size]),
        tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
        tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
        AttentionLayer(),  # Add Attention Layer
        tf.keras.layers.Bidirectional(LSTM(50, activation="relu",return_sequences=True)),
        tf.keras.layers.GRU(64,activation="relu"),# Return sequences here
        tf.keras.layers.Dense(1, 'linear')
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])
    return model

# %% [markdown]
# Define the Model checkpoint callback

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the ModelCheckpoint callback
checkpoint_path = "best_model.h5"
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_mse', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# # Model Fitting

# %%
#call the model creation function
model1= create_model(seq_size)
history = model1.fit(trainX, trainY, validation_data=(testX, testY),batch_size=64,
      verbose=2, epochs=300,callbacks=[checkpoint])
# Out:
# Epoch 1/300
#
# Epoch 1: val_mse improved from inf to 0.00288, saving model to best_model.h5
# 88/88 - 12s - loss: 0.0025 - mae: 0.0339 - mse: 0.0025 - val_loss: 0.0029 - val_mae: 0.0307 - val_mse: 0.0029 - 12s/epoch - 141ms/step
# Epoch 2/300
#
# Epoch 2: val_mse improved from 0.00288 to 0.00097, saving model to best_model.h5
# 88/88 - 1s - loss: 0.0012 - mae: 0.0190 - mse: 0.0012 - val_loss: 9.7458e-04 - val_mae: 0.0123 - val_mse: 9.7458e-04 - 1s/epoch - 15ms/step
# Epoch 3/300
#
# Epoch 3: val_mse improved from 0.00097 to 0.00087, saving model to best_model.h5
# 88/88 - 2s - loss: 7.1116e-04 - mae: 0.0122 - mse: 7.1116e-04 - val_loss: 8.7268e-04 - val_mae: 0.0115 - val_mse: 8.7268e-04 - 2s/epoch - 23ms/step
# Epoch 4/300
#
# Epoch 4: val_mse did not improve from 0.00087
# 88/88 - 1s - loss: 6.6874e-04 - mae: 0.0118 - mse: 6.6874e-04 - val_loss: 8.9987e-04 - val_mae: 0.0096 - val_mse: 8.9987e-04 - 1s/epoch - 16ms/step
# Epoch 5/300
#
# Epoch 5: val_mse did not improve from 0.00087
# 88/88 - 1s - loss: 6.1607e-04 - mae: 0.0112 - mse: 6.1607e-04 - val_loss: 8.9992e-04 - val_mae: 0.0096 - val_mse: 8.9992e-04 - 1s/epoch - 13ms/step
# Epoch 6/300
#
# Epoch 6: val_mse improved from 0.00087 to 0.00085, saving model to best_model.h5
# 88/88 - 1s - loss: 5.8930e-04 - mae: 0.0107 - mse: 5.8930e-04 - val_loss: 8.5109e-04 - val_mae: 0.0101 - val_mse: 8.5109e-04 - 1s/epoch - 15ms/step
# Epoch 7/300
#
# Epoch 7: val_mse improved from 0.00085 to 0.00080, saving model to best_model.h5
# 88/88 - 1s - loss: 5.8226e-04 - mae: 0.0106 - mse: 5.8226e-04 - val_loss: 8.0134e-04 - val_mae: 0.0115 - val_mse: 8.0134e-04 - 1s/epoch - 14ms/step
# Epoch 8/300
#
# Epoch 8: val_mse did not improve from 0.00080
# 88/88 - 1s - loss: 5.5938e-04 - mae: 0.0105 - mse: 5.5938e-04 - val_loss: 8.3526e-04 - val_mae: 0.0134 - val_mse: 8.3526e-04 - 1s/epoch - 12ms/step
# Epoch 9/300
#
# Epoch 9: val_mse did not improve from 0.00080
# 88/88 - 1s - loss: 5.2976e-04 - mae: 0.0103 - mse: 5.2976e-04 - val_loss: 8.3063e-04 - val_mae: 0.0116 - val_mse: 8.3063e-04 - 1s/epoch - 13ms/step
# Epoch 10/300
#
# Epoch 10: val_mse improved from 0.00080 to 0.00080, saving model to best_model.h5
# 88/88 - 1s - loss: 5.0876e-04 - mae: 0.0096 - mse: 5.0876e-04 - val_loss: 7.9757e-04 - val_mae: 0.0100 - val_mse: 7.9757e-04 - 1s/epoch - 13ms/step
# Epoch 11/300
#
# Epoch 11: val_mse did not improve from 0.00080
# 88/88 - 1s - loss: 4.9370e-04 - mae: 0.0097 - mse: 4.9370e-04 - val_loss: 8.0136e-04 - val_mae: 0.0122 - val_mse: 8.0136e-04 - 1s/epoch - 14ms/step
# Epoch 12/300
#
# Epoch 12: val_mse did not improve from 0.00080
# 88/88 - 1s - loss: 4.8170e-04 - mae: 0.0097 - mse: 4.8170e-04 - val_loss: 8.0161e-04 - val_mae: 0.0095 - val_mse: 8.0161e-04 - 1s/epoch - 14ms/step
# Epoch 13/300
#
# Epoch 13: val_mse improved from 0.00080 to 0.00077, saving model to best_model.h5
# 88/88 - 2s - loss: 4.6558e-04 - mae: 0.0092 - mse: 4.6558e-04 - val_loss: 7.7264e-04 - val_mae: 0.0112 - val_mse: 7.7264e-04 - 2s/epoch - 22ms/step
# Epoch 14/300
#
# Epoch 14: val_mse did not improve from 0.00077
# 88/88 - 1s - loss: 4.4293e-04 - mae: 0.0090 - mse: 4.4293e-04 - val_loss: 7.8611e-04 - val_mae: 0.0099 - val_mse: 7.8611e-04 - 1s/epoch - 15ms/step
# Epoch 15/300
#
# Epoch 15: val_mse improved from 0.00077 to 0.00076, saving model to best_model.h5
# 88/88 - 1s - loss: 4.2116e-04 - mae: 0.0086 - mse: 4.2116e-04 - val_loss: 7.6106e-04 - val_mae: 0.0095 - val_mse: 7.6106e-04 - 1s/epoch - 14ms/step
# Epoch 16/300
#
# Epoch 16: val_mse improved from 0.00076 to 0.00074, saving model to best_model.h5
# 88/88 - 1s - loss: 3.9726e-04 - mae: 0.0084 - mse: 3.9726e-04 - val_loss: 7.4394e-04 - val_mae: 0.0093 - val_mse: 7.4394e-04 - 1s/epoch - 13ms/step
# Epoch 17/300
#
# Epoch 17: val_mse did not improve from 0.00074
# 88/88 - 1s - loss: 3.9110e-04 - mae: 0.0081 - mse: 3.9110e-04 - val_loss: 7.6652e-04 - val_mae: 0.0097 - val_mse: 7.6652e-04 - 1s/epoch - 14ms/step
# Epoch 18/300
#
# Epoch 18: val_mse did not improve from 0.00074
# 88/88 - 1s - loss: 3.8957e-04 - mae: 0.0082 - mse: 3.8957e-04 - val_loss: 8.6927e-04 - val_mae: 0.0130 - val_mse: 8.6927e-04 - 1s/epoch - 14ms/step
# Epoch 19/300
#
# Epoch 19: val_mse improved from 0.00074 to 0.00073, saving model to best_model.h5
# 88/88 - 1s - loss: 4.0416e-04 - mae: 0.0085 - mse: 4.0416e-04 - val_loss: 7.2614e-04 - val_mae: 0.0112 - val_mse: 7.2614e-04 - 1s/epoch - 15ms/step
# Epoch 20/300
#
# Epoch 20: val_mse did not improve from 0.00073
# 88/88 - 1s - loss: 3.7304e-04 - mae: 0.0081 - mse: 3.7304e-04 - val_loss: 7.4241e-04 - val_mae: 0.0088 - val_mse: 7.4241e-04 - 1s/epoch - 14ms/step
# Epoch 21/300
#
# Epoch 21: val_mse did not improve from 0.00073
# 88/88 - 1s - loss: 3.5662e-04 - mae: 0.0078 - mse: 3.5662e-04 - val_loss: 7.4308e-04 - val_mae: 0.0113 - val_mse: 7.4308e-04 - 1s/epoch - 14ms/step
# Epoch 22/300
#
# Epoch 22: val_mse did not improve from 0.00073
# 88/88 - 2s - loss: 3.5682e-04 - mae: 0.0077 - mse: 3.5682e-04 - val_loss: 8.5472e-04 - val_mae: 0.0127 - val_mse: 8.5472e-04 - 2s/epoch - 20ms/step
# Epoch 23/300
#
# Epoch 23: val_mse improved from 0.00073 to 0.00071, saving model to best_model.h5
# 88/88 - 2s - loss: 3.7911e-04 - mae: 0.0084 - mse: 3.7911e-04 - val_loss: 7.0696e-04 - val_mae: 0.0101 - val_mse: 7.0696e-04 - 2s/epoch - 20ms/step
# Epoch 24/300
#
# Epoch 24: val_mse improved from 0.00071 to 0.00070, saving model to best_model.h5
# 88/88 - 1s - loss: 3.4055e-04 - mae: 0.0076 - mse: 3.4055e-04 - val_loss: 7.0496e-04 - val_mae: 0.0096 - val_mse: 7.0496e-04 - 1s/epoch - 15ms/step
# Epoch 25/300
#
# Epoch 25: val_mse improved from 0.00070 to 0.00069, saving model to best_model.h5
# 88/88 - 1s - loss: 3.2014e-04 - mae: 0.0073 - mse: 3.2014e-04 - val_loss: 6.9374e-04 - val_mae: 0.0098 - val_mse: 6.9374e-04 - 1s/epoch - 15ms/step
# Epoch 26/300
#
# Epoch 26: val_mse improved from 0.00069 to 0.00065, saving model to best_model.h5
# 88/88 - 1s - loss: 3.4567e-04 - mae: 0.0079 - mse: 3.4567e-04 - val_loss: 6.5320e-04 - val_mae: 0.0092 - val_mse: 6.5320e-04 - 1s/epoch - 13ms/step
# Epoch 27/300
#
# Epoch 27: val_mse did not improve from 0.00065
# 88/88 - 1s - loss: 3.2575e-04 - mae: 0.0074 - mse: 3.2575e-04 - val_loss: 7.9518e-04 - val_mae: 0.0088 - val_mse: 7.9518e-04 - 1s/epoch - 14ms/step
# Epoch 28/300
#
# Epoch 28: val_mse did not improve from 0.00065
# 88/88 - 1s - loss: 3.2725e-04 - mae: 0.0074 - mse: 3.2725e-04 - val_loss: 7.3572e-04 - val_mae: 0.0100 - val_mse: 7.3572e-04 - 1s/epoch - 14ms/step
# Epoch 29/300
#
# Epoch 29: val_mse did not improve from 0.00065
# 88/88 - 1s - loss: 3.5060e-04 - mae: 0.0078 - mse: 3.5060e-04 - val_loss: 7.2350e-04 - val_mae: 0.0084 - val_mse: 7.2350e-04 - 1s/epoch - 14ms/step
# Epoch 30/300
#
# Epoch 30: val_mse did not improve from 0.00065
# 88/88 - 1s - loss: 3.2074e-04 - mae: 0.0072 - mse: 3.2074e-04 - val_loss: 6.8882e-04 - val_mae: 0.0108 - val_mse: 6.8882e-04 - 1s/epoch - 14ms/step
# Epoch 31/300
#
# Epoch 31: val_mse did not improve from 0.00065
# 88/88 - 2s - loss: 2.9435e-04 - mae: 0.0070 - mse: 2.9435e-04 - val_loss: 6.6141e-04 - val_mae: 0.0095 - val_mse: 6.6141e-04 - 2s/epoch - 20ms/step
# Epoch 32/300
#
# Epoch 32: val_mse did not improve from 0.00065
# 88/88 - 2s - loss: 2.9061e-04 - mae: 0.0071 - mse: 2.9061e-04 - val_loss: 7.1617e-04 - val_mae: 0.0088 - val_mse: 7.1617e-04 - 2s/epoch - 20ms/step
# Epoch 33/300
#
# Epoch 33: val_mse did not improve from 0.00065
# 88/88 - 1s - loss: 2.9644e-04 - mae: 0.0070 - mse: 2.9644e-04 - val_loss: 7.8040e-04 - val_mae: 0.0090 - val_mse: 7.8040e-04 - 1s/epoch - 14ms/step
# Epoch 34/300
#
# Epoch 34: val_mse improved from 0.00065 to 0.00064, saving model to best_model.h5
# 88/88 - 1s - loss: 2.9752e-04 - mae: 0.0069 - mse: 2.9752e-04 - val_loss: 6.3850e-04 - val_mae: 0.0084 - val_mse: 6.3850e-04 - 1s/epoch - 14ms/step
# Epoch 35/300
#
# Epoch 35: val_mse did not improve from 0.00064
# 88/88 - 1s - loss: 2.9437e-04 - mae: 0.0072 - mse: 2.9437e-04 - val_loss: 6.7550e-04 - val_mae: 0.0078 - val_mse: 6.7550e-04 - 1s/epoch - 12ms/step
# Epoch 36/300
#
# Epoch 36: val_mse did not improve from 0.00064
# 88/88 - 1s - loss: 3.1209e-04 - mae: 0.0074 - mse: 3.1209e-04 - val_loss: 6.5312e-04 - val_mae: 0.0095 - val_mse: 6.5312e-04 - 1s/epoch - 12ms/step
# Epoch 37/300
#
# Epoch 37: val_mse improved from 0.00064 to 0.00060, saving model to best_model.h5
# 88/88 - 1s - loss: 3.3233e-04 - mae: 0.0075 - mse: 3.3233e-04 - val_loss: 6.0085e-04 - val_mae: 0.0081 - val_mse: 6.0085e-04 - 1s/epoch - 13ms/step
# Epoch 38/300
#
# Epoch 38: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.8401e-04 - mae: 0.0069 - mse: 2.8401e-04 - val_loss: 7.3191e-04 - val_mae: 0.0101 - val_mse: 7.3191e-04 - 1s/epoch - 13ms/step
# Epoch 39/300
#
# Epoch 39: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 3.0225e-04 - mae: 0.0071 - mse: 3.0225e-04 - val_loss: 7.0360e-04 - val_mae: 0.0087 - val_mse: 7.0360e-04 - 1s/epoch - 14ms/step
# Epoch 40/300
#
# Epoch 40: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.8163e-04 - mae: 0.0068 - mse: 2.8163e-04 - val_loss: 6.7000e-04 - val_mae: 0.0081 - val_mse: 6.7000e-04 - 1s/epoch - 15ms/step
# Epoch 41/300
#
# Epoch 41: val_mse did not improve from 0.00060
# 88/88 - 2s - loss: 2.6592e-04 - mae: 0.0065 - mse: 2.6592e-04 - val_loss: 6.5891e-04 - val_mae: 0.0084 - val_mse: 6.5891e-04 - 2s/epoch - 22ms/step
# Epoch 42/300
#
# Epoch 42: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.5428e-04 - mae: 0.0063 - mse: 2.5428e-04 - val_loss: 6.6698e-04 - val_mae: 0.0088 - val_mse: 6.6698e-04 - 1s/epoch - 17ms/step
# Epoch 43/300
#
# Epoch 43: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.7269e-04 - mae: 0.0067 - mse: 2.7269e-04 - val_loss: 6.3640e-04 - val_mae: 0.0090 - val_mse: 6.3640e-04 - 1s/epoch - 12ms/step
# Epoch 44/300
#
# Epoch 44: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.6535e-04 - mae: 0.0066 - mse: 2.6535e-04 - val_loss: 6.7842e-04 - val_mae: 0.0088 - val_mse: 6.7842e-04 - 1s/epoch - 12ms/step
# Epoch 45/300
#
# Epoch 45: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.6745e-04 - mae: 0.0065 - mse: 2.6745e-04 - val_loss: 7.1877e-04 - val_mae: 0.0105 - val_mse: 7.1877e-04 - 1s/epoch - 12ms/step
# Epoch 46/300
#
# Epoch 46: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.5484e-04 - mae: 0.0065 - mse: 2.5484e-04 - val_loss: 7.2355e-04 - val_mae: 0.0087 - val_mse: 7.2355e-04 - 1s/epoch - 14ms/step
# Epoch 47/300
#
# Epoch 47: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.4671e-04 - mae: 0.0062 - mse: 2.4671e-04 - val_loss: 6.1138e-04 - val_mae: 0.0081 - val_mse: 6.1138e-04 - 1s/epoch - 13ms/step
# Epoch 48/300
#
# Epoch 48: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.4415e-04 - mae: 0.0062 - mse: 2.4415e-04 - val_loss: 6.6968e-04 - val_mae: 0.0091 - val_mse: 6.6968e-04 - 1s/epoch - 14ms/step
# Epoch 49/300
#
# Epoch 49: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.5194e-04 - mae: 0.0063 - mse: 2.5194e-04 - val_loss: 6.1454e-04 - val_mae: 0.0084 - val_mse: 6.1454e-04 - 1s/epoch - 14ms/step
# Epoch 50/300
#
# Epoch 50: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.6564e-04 - mae: 0.0067 - mse: 2.6564e-04 - val_loss: 7.0333e-04 - val_mae: 0.0087 - val_mse: 7.0333e-04 - 1s/epoch - 14ms/step
# Epoch 51/300
#
# Epoch 51: val_mse did not improve from 0.00060
# 88/88 - 2s - loss: 2.5488e-04 - mae: 0.0064 - mse: 2.5488e-04 - val_loss: 6.5019e-04 - val_mae: 0.0082 - val_mse: 6.5019e-04 - 2s/epoch - 22ms/step
# Epoch 52/300
#
# Epoch 52: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.5499e-04 - mae: 0.0064 - mse: 2.5499e-04 - val_loss: 6.6592e-04 - val_mae: 0.0090 - val_mse: 6.6592e-04 - 1s/epoch - 15ms/step
# Epoch 53/300
#
# Epoch 53: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.4841e-04 - mae: 0.0064 - mse: 2.4841e-04 - val_loss: 6.3903e-04 - val_mae: 0.0083 - val_mse: 6.3903e-04 - 1s/epoch - 12ms/step
# Epoch 54/300
#
# Epoch 54: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.4202e-04 - mae: 0.0062 - mse: 2.4202e-04 - val_loss: 8.9494e-04 - val_mae: 0.0125 - val_mse: 8.9494e-04 - 1s/epoch - 12ms/step
# Epoch 55/300
#
# Epoch 55: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.7155e-04 - mae: 0.0068 - mse: 2.7155e-04 - val_loss: 7.1428e-04 - val_mae: 0.0096 - val_mse: 7.1428e-04 - 1s/epoch - 12ms/step
# Epoch 56/300
#
# Epoch 56: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.3448e-04 - mae: 0.0062 - mse: 2.3448e-04 - val_loss: 6.3216e-04 - val_mae: 0.0073 - val_mse: 6.3216e-04 - 1s/epoch - 12ms/step
# Epoch 57/300
#
# Epoch 57: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.5393e-04 - mae: 0.0065 - mse: 2.5393e-04 - val_loss: 6.3967e-04 - val_mae: 0.0086 - val_mse: 6.3967e-04 - 1s/epoch - 14ms/step
# Epoch 58/300
#
# Epoch 58: val_mse improved from 0.00060 to 0.00060, saving model to best_model.h5
# 88/88 - 1s - loss: 2.4573e-04 - mae: 0.0061 - mse: 2.4573e-04 - val_loss: 6.0073e-04 - val_mae: 0.0082 - val_mse: 6.0073e-04 - 1s/epoch - 15ms/step
# Epoch 59/300
#
# Epoch 59: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.4690e-04 - mae: 0.0064 - mse: 2.4690e-04 - val_loss: 7.9035e-04 - val_mae: 0.0089 - val_mse: 7.9035e-04 - 1s/epoch - 12ms/step
# Epoch 60/300
#
# Epoch 60: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.5009e-04 - mae: 0.0064 - mse: 2.5009e-04 - val_loss: 6.7503e-04 - val_mae: 0.0082 - val_mse: 6.7503e-04 - 1s/epoch - 15ms/step
# Epoch 61/300
#
# Epoch 61: val_mse did not improve from 0.00060
# 88/88 - 2s - loss: 2.3387e-04 - mae: 0.0061 - mse: 2.3387e-04 - val_loss: 6.2438e-04 - val_mae: 0.0110 - val_mse: 6.2438e-04 - 2s/epoch - 22ms/step
# Epoch 62/300
#
# Epoch 62: val_mse did not improve from 0.00060
# 88/88 - 1s - loss: 2.7809e-04 - mae: 0.0070 - mse: 2.7809e-04 - val_loss: 6.4427e-04 - val_mae: 0.0080 - val_mse: 6.4427e-04 - 1s/epoch - 13ms/step
# Epoch 63/300
#
# Epoch 63: val_mse improved from 0.00060 to 0.00057, saving model to best_model.h5
# 88/88 - 1s - loss: 2.5567e-04 - mae: 0.0062 - mse: 2.5567e-04 - val_loss: 5.6869e-04 - val_mae: 0.0085 - val_mse: 5.6869e-04 - 1s/epoch - 15ms/step
# Epoch 64/300
#
# Epoch 64: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2500e-04 - mae: 0.0060 - mse: 2.2500e-04 - val_loss: 6.3590e-04 - val_mae: 0.0075 - val_mse: 6.3590e-04 - 1s/epoch - 12ms/step
# Epoch 65/300
#
# Epoch 65: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.5712e-04 - mae: 0.0064 - mse: 2.5712e-04 - val_loss: 6.5958e-04 - val_mae: 0.0081 - val_mse: 6.5958e-04 - 2s/epoch - 22ms/step
# Epoch 66/300
#
# Epoch 66: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.3400e-04 - mae: 0.0062 - mse: 2.3400e-04 - val_loss: 6.3719e-04 - val_mae: 0.0079 - val_mse: 6.3719e-04 - 2s/epoch - 19ms/step
# Epoch 67/300
#
# Epoch 67: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.2820e-04 - mae: 0.0059 - mse: 2.2820e-04 - val_loss: 6.3337e-04 - val_mae: 0.0090 - val_mse: 6.3337e-04 - 2s/epoch - 20ms/step
# Epoch 68/300
#
# Epoch 68: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.6212e-04 - mae: 0.0067 - mse: 2.6212e-04 - val_loss: 6.8704e-04 - val_mae: 0.0082 - val_mse: 6.8704e-04 - 1s/epoch - 14ms/step
# Epoch 69/300
#
# Epoch 69: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.3307e-04 - mae: 0.0059 - mse: 2.3307e-04 - val_loss: 6.4256e-04 - val_mae: 0.0074 - val_mse: 6.4256e-04 - 2s/epoch - 22ms/step
# Epoch 70/300
#
# Epoch 70: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2141e-04 - mae: 0.0057 - mse: 2.2141e-04 - val_loss: 6.2411e-04 - val_mae: 0.0081 - val_mse: 6.2411e-04 - 1s/epoch - 16ms/step
# Epoch 71/300
#
# Epoch 71: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.2006e-04 - mae: 0.0058 - mse: 2.2006e-04 - val_loss: 6.1281e-04 - val_mae: 0.0072 - val_mse: 6.1281e-04 - 2s/epoch - 21ms/step
# Epoch 72/300
#
# Epoch 72: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2093e-04 - mae: 0.0056 - mse: 2.2093e-04 - val_loss: 6.7481e-04 - val_mae: 0.0087 - val_mse: 6.7481e-04 - 1s/epoch - 12ms/step
# Epoch 73/300
#
# Epoch 73: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.8551e-04 - mae: 0.0068 - mse: 2.8551e-04 - val_loss: 6.3798e-04 - val_mae: 0.0075 - val_mse: 6.3798e-04 - 1s/epoch - 12ms/step
# Epoch 74/300
#
# Epoch 74: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.3347e-04 - mae: 0.0060 - mse: 2.3347e-04 - val_loss: 6.4946e-04 - val_mae: 0.0086 - val_mse: 6.4946e-04 - 1s/epoch - 14ms/step
# Epoch 75/300
#
# Epoch 75: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2797e-04 - mae: 0.0061 - mse: 2.2797e-04 - val_loss: 6.6428e-04 - val_mae: 0.0079 - val_mse: 6.6428e-04 - 1s/epoch - 12ms/step
# Epoch 76/300
#
# Epoch 76: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2172e-04 - mae: 0.0057 - mse: 2.2172e-04 - val_loss: 6.5253e-04 - val_mae: 0.0080 - val_mse: 6.5253e-04 - 1s/epoch - 12ms/step
# Epoch 77/300
#
# Epoch 77: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1738e-04 - mae: 0.0058 - mse: 2.1738e-04 - val_loss: 6.3076e-04 - val_mae: 0.0079 - val_mse: 6.3076e-04 - 1s/epoch - 14ms/step
# Epoch 78/300
#
# Epoch 78: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.3421e-04 - mae: 0.0061 - mse: 2.3421e-04 - val_loss: 6.2167e-04 - val_mae: 0.0074 - val_mse: 6.2167e-04 - 2s/epoch - 20ms/step
# Epoch 79/300
#
# Epoch 79: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1901e-04 - mae: 0.0056 - mse: 2.1901e-04 - val_loss: 6.5510e-04 - val_mae: 0.0078 - val_mse: 6.5510e-04 - 1s/epoch - 17ms/step
# Epoch 80/300
#
# Epoch 80: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1858e-04 - mae: 0.0060 - mse: 2.1858e-04 - val_loss: 6.6417e-04 - val_mae: 0.0075 - val_mse: 6.6417e-04 - 1s/epoch - 14ms/step
# Epoch 81/300
#
# Epoch 81: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2518e-04 - mae: 0.0056 - mse: 2.2518e-04 - val_loss: 6.4898e-04 - val_mae: 0.0088 - val_mse: 6.4898e-04 - 1s/epoch - 14ms/step
# Epoch 82/300
#
# Epoch 82: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1867e-04 - mae: 0.0059 - mse: 2.1867e-04 - val_loss: 6.6872e-04 - val_mae: 0.0078 - val_mse: 6.6872e-04 - 1s/epoch - 14ms/step
# Epoch 83/300
#
# Epoch 83: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2359e-04 - mae: 0.0059 - mse: 2.2359e-04 - val_loss: 8.1181e-04 - val_mae: 0.0120 - val_mse: 8.1181e-04 - 1s/epoch - 14ms/step
# Epoch 84/300
#
# Epoch 84: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.4132e-04 - mae: 0.0063 - mse: 2.4132e-04 - val_loss: 6.8625e-04 - val_mae: 0.0087 - val_mse: 6.8625e-04 - 1s/epoch - 14ms/step
# Epoch 85/300
#
# Epoch 85: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1528e-04 - mae: 0.0057 - mse: 2.1528e-04 - val_loss: 6.3007e-04 - val_mae: 0.0075 - val_mse: 6.3007e-04 - 1s/epoch - 12ms/step
# Epoch 86/300
#
# Epoch 86: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.3299e-04 - mae: 0.0061 - mse: 2.3299e-04 - val_loss: 6.9396e-04 - val_mae: 0.0076 - val_mse: 6.9396e-04 - 1s/epoch - 14ms/step
# Epoch 87/300
#
# Epoch 87: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1435e-04 - mae: 0.0057 - mse: 2.1435e-04 - val_loss: 6.4692e-04 - val_mae: 0.0072 - val_mse: 6.4692e-04 - 1s/epoch - 15ms/step
# Epoch 88/300
#
# Epoch 88: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.1993e-04 - mae: 0.0056 - mse: 2.1993e-04 - val_loss: 6.0377e-04 - val_mae: 0.0084 - val_mse: 6.0377e-04 - 2s/epoch - 22ms/step
# Epoch 89/300
#
# Epoch 89: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1875e-04 - mae: 0.0059 - mse: 2.1875e-04 - val_loss: 6.1147e-04 - val_mae: 0.0090 - val_mse: 6.1147e-04 - 1s/epoch - 12ms/step
# Epoch 90/300
#
# Epoch 90: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1840e-04 - mae: 0.0058 - mse: 2.1840e-04 - val_loss: 6.6528e-04 - val_mae: 0.0079 - val_mse: 6.6528e-04 - 1s/epoch - 13ms/step
# Epoch 91/300
#
# Epoch 91: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0590e-04 - mae: 0.0056 - mse: 2.0590e-04 - val_loss: 7.2645e-04 - val_mae: 0.0080 - val_mse: 7.2645e-04 - 1s/epoch - 13ms/step
# Epoch 92/300
#
# Epoch 92: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2194e-04 - mae: 0.0059 - mse: 2.2194e-04 - val_loss: 6.1027e-04 - val_mae: 0.0067 - val_mse: 6.1027e-04 - 1s/epoch - 14ms/step
# Epoch 93/300
#
# Epoch 93: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.3222e-04 - mae: 0.0062 - mse: 2.3222e-04 - val_loss: 6.3604e-04 - val_mae: 0.0081 - val_mse: 6.3604e-04 - 1s/epoch - 13ms/step
# Epoch 94/300
#
# Epoch 94: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.3071e-04 - mae: 0.0059 - mse: 2.3071e-04 - val_loss: 6.2155e-04 - val_mae: 0.0073 - val_mse: 6.2155e-04 - 1s/epoch - 13ms/step
# Epoch 95/300
#
# Epoch 95: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0088e-04 - mae: 0.0055 - mse: 2.0088e-04 - val_loss: 6.5133e-04 - val_mae: 0.0070 - val_mse: 6.5133e-04 - 1s/epoch - 13ms/step
# Epoch 96/300
#
# Epoch 96: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0825e-04 - mae: 0.0056 - mse: 2.0825e-04 - val_loss: 6.2052e-04 - val_mae: 0.0072 - val_mse: 6.2052e-04 - 1s/epoch - 15ms/step
# Epoch 97/300
#
# Epoch 97: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9622e-04 - mae: 0.0053 - mse: 1.9622e-04 - val_loss: 5.7817e-04 - val_mae: 0.0078 - val_mse: 5.7817e-04 - 1s/epoch - 17ms/step
# Epoch 98/300
#
# Epoch 98: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.2323e-04 - mae: 0.0060 - mse: 2.2323e-04 - val_loss: 6.4706e-04 - val_mae: 0.0074 - val_mse: 6.4706e-04 - 2s/epoch - 22ms/step
# Epoch 99/300
#
# Epoch 99: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1161e-04 - mae: 0.0058 - mse: 2.1161e-04 - val_loss: 6.1467e-04 - val_mae: 0.0091 - val_mse: 6.1467e-04 - 1s/epoch - 14ms/step
# Epoch 100/300
#
# Epoch 100: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0622e-04 - mae: 0.0054 - mse: 2.0622e-04 - val_loss: 6.1139e-04 - val_mae: 0.0080 - val_mse: 6.1139e-04 - 1s/epoch - 13ms/step
# Epoch 101/300
#
# Epoch 101: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0457e-04 - mae: 0.0055 - mse: 2.0457e-04 - val_loss: 6.0640e-04 - val_mae: 0.0066 - val_mse: 6.0640e-04 - 1s/epoch - 13ms/step
# Epoch 102/300
#
# Epoch 102: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1119e-04 - mae: 0.0056 - mse: 2.1119e-04 - val_loss: 6.4243e-04 - val_mae: 0.0077 - val_mse: 6.4243e-04 - 1s/epoch - 14ms/step
# Epoch 103/300
#
# Epoch 103: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0311e-04 - mae: 0.0054 - mse: 2.0311e-04 - val_loss: 6.6450e-04 - val_mae: 0.0076 - val_mse: 6.6450e-04 - 1s/epoch - 14ms/step
# Epoch 104/300
#
# Epoch 104: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0580e-04 - mae: 0.0056 - mse: 2.0580e-04 - val_loss: 6.8937e-04 - val_mae: 0.0080 - val_mse: 6.8937e-04 - 1s/epoch - 14ms/step
# Epoch 105/300
#
# Epoch 105: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1070e-04 - mae: 0.0055 - mse: 2.1070e-04 - val_loss: 5.8298e-04 - val_mae: 0.0067 - val_mse: 5.8298e-04 - 1s/epoch - 14ms/step
# Epoch 106/300
#
# Epoch 106: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1821e-04 - mae: 0.0058 - mse: 2.1821e-04 - val_loss: 5.7369e-04 - val_mae: 0.0073 - val_mse: 5.7369e-04 - 1s/epoch - 14ms/step
# Epoch 107/300
#
# Epoch 107: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.0086e-04 - mae: 0.0053 - mse: 2.0086e-04 - val_loss: 6.0060e-04 - val_mae: 0.0077 - val_mse: 6.0060e-04 - 2s/epoch - 23ms/step
# Epoch 108/300
#
# Epoch 108: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.1066e-04 - mae: 0.0056 - mse: 2.1066e-04 - val_loss: 6.1484e-04 - val_mae: 0.0079 - val_mse: 6.1484e-04 - 1s/epoch - 16ms/step
# Epoch 109/300
#
# Epoch 109: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9777e-04 - mae: 0.0056 - mse: 1.9777e-04 - val_loss: 6.1887e-04 - val_mae: 0.0083 - val_mse: 6.1887e-04 - 1s/epoch - 13ms/step
# Epoch 110/300
#
# Epoch 110: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2636e-04 - mae: 0.0058 - mse: 2.2636e-04 - val_loss: 6.1745e-04 - val_mae: 0.0085 - val_mse: 6.1745e-04 - 1s/epoch - 15ms/step
# Epoch 111/300
#
# Epoch 111: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2358e-04 - mae: 0.0060 - mse: 2.2358e-04 - val_loss: 6.1016e-04 - val_mae: 0.0074 - val_mse: 6.1016e-04 - 1s/epoch - 13ms/step
# Epoch 112/300
#
# Epoch 112: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0071e-04 - mae: 0.0054 - mse: 2.0071e-04 - val_loss: 5.8948e-04 - val_mae: 0.0077 - val_mse: 5.8948e-04 - 1s/epoch - 12ms/step
# Epoch 113/300
#
# Epoch 113: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.8965e-04 - mae: 0.0052 - mse: 1.8965e-04 - val_loss: 6.1992e-04 - val_mae: 0.0070 - val_mse: 6.1992e-04 - 1s/epoch - 13ms/step
# Epoch 114/300
#
# Epoch 114: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9480e-04 - mae: 0.0053 - mse: 1.9480e-04 - val_loss: 5.9747e-04 - val_mae: 0.0074 - val_mse: 5.9747e-04 - 1s/epoch - 13ms/step
# Epoch 115/300
#
# Epoch 115: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0320e-04 - mae: 0.0056 - mse: 2.0320e-04 - val_loss: 6.9993e-04 - val_mae: 0.0081 - val_mse: 6.9993e-04 - 1s/epoch - 14ms/step
# Epoch 116/300
#
# Epoch 116: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0442e-04 - mae: 0.0057 - mse: 2.0442e-04 - val_loss: 6.5097e-04 - val_mae: 0.0075 - val_mse: 6.5097e-04 - 1s/epoch - 17ms/step
# Epoch 117/300
#
# Epoch 117: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.1333e-04 - mae: 0.0057 - mse: 2.1333e-04 - val_loss: 6.7265e-04 - val_mae: 0.0085 - val_mse: 6.7265e-04 - 2s/epoch - 23ms/step
# Epoch 118/300
#
# Epoch 118: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9905e-04 - mae: 0.0053 - mse: 1.9905e-04 - val_loss: 5.8932e-04 - val_mae: 0.0071 - val_mse: 5.8932e-04 - 1s/epoch - 14ms/step
# Epoch 119/300
#
# Epoch 119: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9046e-04 - mae: 0.0053 - mse: 1.9046e-04 - val_loss: 6.6156e-04 - val_mae: 0.0078 - val_mse: 6.6156e-04 - 1s/epoch - 15ms/step
# Epoch 120/300
#
# Epoch 120: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.8834e-04 - mae: 0.0052 - mse: 1.8834e-04 - val_loss: 6.7299e-04 - val_mae: 0.0081 - val_mse: 6.7299e-04 - 1s/epoch - 14ms/step
# Epoch 121/300
#
# Epoch 121: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9832e-04 - mae: 0.0052 - mse: 1.9832e-04 - val_loss: 6.0742e-04 - val_mae: 0.0083 - val_mse: 6.0742e-04 - 1s/epoch - 14ms/step
# Epoch 122/300
#
# Epoch 122: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2789e-04 - mae: 0.0060 - mse: 2.2789e-04 - val_loss: 6.2045e-04 - val_mae: 0.0073 - val_mse: 6.2045e-04 - 1s/epoch - 13ms/step
# Epoch 123/300
#
# Epoch 123: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0414e-04 - mae: 0.0055 - mse: 2.0414e-04 - val_loss: 7.0121e-04 - val_mae: 0.0087 - val_mse: 7.0121e-04 - 1s/epoch - 13ms/step
# Epoch 124/300
#
# Epoch 124: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.2583e-04 - mae: 0.0058 - mse: 2.2583e-04 - val_loss: 6.3128e-04 - val_mae: 0.0084 - val_mse: 6.3128e-04 - 1s/epoch - 13ms/step
# Epoch 125/300
#
# Epoch 125: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9880e-04 - mae: 0.0053 - mse: 1.9880e-04 - val_loss: 6.3651e-04 - val_mae: 0.0077 - val_mse: 6.3651e-04 - 1s/epoch - 13ms/step
# Epoch 126/300
#
# Epoch 126: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.2548e-04 - mae: 0.0056 - mse: 2.2548e-04 - val_loss: 7.4868e-04 - val_mae: 0.0102 - val_mse: 7.4868e-04 - 2s/epoch - 22ms/step
# Epoch 127/300
#
# Epoch 127: val_mse did not improve from 0.00057
# 88/88 - 2s - loss: 2.1675e-04 - mae: 0.0055 - mse: 2.1675e-04 - val_loss: 6.0311e-04 - val_mae: 0.0074 - val_mse: 6.0311e-04 - 2s/epoch - 17ms/step
# Epoch 128/300
#
# Epoch 128: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9941e-04 - mae: 0.0055 - mse: 1.9941e-04 - val_loss: 6.4367e-04 - val_mae: 0.0076 - val_mse: 6.4367e-04 - 1s/epoch - 14ms/step
# Epoch 129/300
#
# Epoch 129: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0894e-04 - mae: 0.0056 - mse: 2.0894e-04 - val_loss: 5.8319e-04 - val_mae: 0.0068 - val_mse: 5.8319e-04 - 1s/epoch - 14ms/step
# Epoch 130/300
#
# Epoch 130: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 1.9064e-04 - mae: 0.0052 - mse: 1.9064e-04 - val_loss: 6.2690e-04 - val_mae: 0.0070 - val_mse: 6.2690e-04 - 1s/epoch - 14ms/step
# Epoch 131/300
#
# Epoch 131: val_mse did not improve from 0.00057
# 88/88 - 1s - loss: 2.0533e-04 - mae: 0.0054 - mse: 2.0533e-04 - val_loss: 5.7700e-04 - val_mae: 0.0067 - val_mse: 5.7700e-04 - 1s/epoch - 15ms/step
# Epoch 132/300
#
# Epoch 132: val_mse improved from 0.00057 to 0.00056, saving model to best_model.h5
# 88/88 - 1s - loss: 1.8780e-04 - mae: 0.0051 - mse: 1.8780e-04 - val_loss: 5.5763e-04 - val_mae: 0.0093 - val_mse: 5.5763e-04 - 1s/epoch - 15ms/step
# Epoch 133/300
#
# Epoch 133: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.9251e-04 - mae: 0.0053 - mse: 1.9251e-04 - val_loss: 6.1269e-04 - val_mae: 0.0076 - val_mse: 6.1269e-04 - 1s/epoch - 15ms/step
# Epoch 134/300
#
# Epoch 134: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8308e-04 - mae: 0.0049 - mse: 1.8308e-04 - val_loss: 5.9100e-04 - val_mae: 0.0069 - val_mse: 5.9100e-04 - 1s/epoch - 13ms/step
# Epoch 135/300
#
# Epoch 135: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 2.0173e-04 - mae: 0.0053 - mse: 2.0173e-04 - val_loss: 6.0706e-04 - val_mae: 0.0081 - val_mse: 6.0706e-04 - 2s/epoch - 20ms/step
# Epoch 136/300
#
# Epoch 136: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 2.0686e-04 - mae: 0.0058 - mse: 2.0686e-04 - val_loss: 7.1634e-04 - val_mae: 0.0082 - val_mse: 7.1634e-04 - 2s/epoch - 19ms/step
# Epoch 137/300
#
# Epoch 137: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.9910e-04 - mae: 0.0054 - mse: 1.9910e-04 - val_loss: 5.9459e-04 - val_mae: 0.0072 - val_mse: 5.9459e-04 - 1s/epoch - 14ms/step
# Epoch 138/300
#
# Epoch 138: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8583e-04 - mae: 0.0049 - mse: 1.8583e-04 - val_loss: 5.7469e-04 - val_mae: 0.0076 - val_mse: 5.7469e-04 - 1s/epoch - 13ms/step
# Epoch 139/300
#
# Epoch 139: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8683e-04 - mae: 0.0054 - mse: 1.8683e-04 - val_loss: 6.7778e-04 - val_mae: 0.0081 - val_mse: 6.7778e-04 - 1s/epoch - 13ms/step
# Epoch 140/300
#
# Epoch 140: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.9729e-04 - mae: 0.0054 - mse: 1.9729e-04 - val_loss: 5.8268e-04 - val_mae: 0.0069 - val_mse: 5.8268e-04 - 1s/epoch - 13ms/step
# Epoch 141/300
#
# Epoch 141: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8601e-04 - mae: 0.0051 - mse: 1.8601e-04 - val_loss: 6.0396e-04 - val_mae: 0.0070 - val_mse: 6.0396e-04 - 1s/epoch - 14ms/step
# Epoch 142/300
#
# Epoch 142: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8837e-04 - mae: 0.0050 - mse: 1.8837e-04 - val_loss: 5.9363e-04 - val_mae: 0.0079 - val_mse: 5.9363e-04 - 1s/epoch - 13ms/step
# Epoch 143/300
#
# Epoch 143: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8602e-04 - mae: 0.0053 - mse: 1.8602e-04 - val_loss: 5.8788e-04 - val_mae: 0.0078 - val_mse: 5.8788e-04 - 1s/epoch - 13ms/step
# Epoch 144/300
#
# Epoch 144: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8284e-04 - mae: 0.0049 - mse: 1.8284e-04 - val_loss: 6.2264e-04 - val_mae: 0.0082 - val_mse: 6.2264e-04 - 1s/epoch - 14ms/step
# Epoch 145/300
#
# Epoch 145: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 1.8684e-04 - mae: 0.0051 - mse: 1.8684e-04 - val_loss: 5.7693e-04 - val_mae: 0.0069 - val_mse: 5.7693e-04 - 2s/epoch - 22ms/step
# Epoch 146/300
#
# Epoch 146: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.9804e-04 - mae: 0.0053 - mse: 1.9804e-04 - val_loss: 6.5860e-04 - val_mae: 0.0081 - val_mse: 6.5860e-04 - 1s/epoch - 16ms/step
# Epoch 147/300
#
# Epoch 147: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 2.1192e-04 - mae: 0.0055 - mse: 2.1192e-04 - val_loss: 6.0725e-04 - val_mae: 0.0077 - val_mse: 6.0725e-04 - 1s/epoch - 13ms/step
# Epoch 148/300
#
# Epoch 148: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8628e-04 - mae: 0.0052 - mse: 1.8628e-04 - val_loss: 6.3851e-04 - val_mae: 0.0077 - val_mse: 6.3851e-04 - 1s/epoch - 14ms/step
# Epoch 149/300
#
# Epoch 149: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8385e-04 - mae: 0.0050 - mse: 1.8385e-04 - val_loss: 6.0840e-04 - val_mae: 0.0067 - val_mse: 6.0840e-04 - 1s/epoch - 13ms/step
# Epoch 150/300
#
# Epoch 150: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8196e-04 - mae: 0.0049 - mse: 1.8196e-04 - val_loss: 6.0892e-04 - val_mae: 0.0072 - val_mse: 6.0892e-04 - 1s/epoch - 14ms/step
# Epoch 151/300
#
# Epoch 151: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8323e-04 - mae: 0.0052 - mse: 1.8323e-04 - val_loss: 5.8818e-04 - val_mae: 0.0077 - val_mse: 5.8818e-04 - 1s/epoch - 13ms/step
# Epoch 152/300
#
# Epoch 152: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.9015e-04 - mae: 0.0053 - mse: 1.9015e-04 - val_loss: 6.3390e-04 - val_mae: 0.0071 - val_mse: 6.3390e-04 - 1s/epoch - 12ms/step
# Epoch 153/300
#
# Epoch 153: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 2.1789e-04 - mae: 0.0058 - mse: 2.1789e-04 - val_loss: 6.1956e-04 - val_mae: 0.0069 - val_mse: 6.1956e-04 - 1s/epoch - 14ms/step
# Epoch 154/300
#
# Epoch 154: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 2.1317e-04 - mae: 0.0057 - mse: 2.1317e-04 - val_loss: 6.5490e-04 - val_mae: 0.0078 - val_mse: 6.5490e-04 - 2s/epoch - 18ms/step
# Epoch 155/300
#
# Epoch 155: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 1.8998e-04 - mae: 0.0054 - mse: 1.8998e-04 - val_loss: 6.8352e-04 - val_mae: 0.0080 - val_mse: 6.8352e-04 - 2s/epoch - 22ms/step
# Epoch 156/300
#
# Epoch 156: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 2.1050e-04 - mae: 0.0057 - mse: 2.1050e-04 - val_loss: 6.6361e-04 - val_mae: 0.0088 - val_mse: 6.6361e-04 - 1s/epoch - 14ms/step
# Epoch 157/300
#
# Epoch 157: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8559e-04 - mae: 0.0051 - mse: 1.8559e-04 - val_loss: 6.0767e-04 - val_mae: 0.0074 - val_mse: 6.0767e-04 - 1s/epoch - 14ms/step
# Epoch 158/300
#
# Epoch 158: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8412e-04 - mae: 0.0051 - mse: 1.8412e-04 - val_loss: 6.8706e-04 - val_mae: 0.0088 - val_mse: 6.8706e-04 - 1s/epoch - 12ms/step
# Epoch 159/300
#
# Epoch 159: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8333e-04 - mae: 0.0049 - mse: 1.8333e-04 - val_loss: 5.9229e-04 - val_mae: 0.0069 - val_mse: 5.9229e-04 - 1s/epoch - 13ms/step
# Epoch 160/300
#
# Epoch 160: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.7737e-04 - mae: 0.0050 - mse: 1.7737e-04 - val_loss: 5.7533e-04 - val_mae: 0.0072 - val_mse: 5.7533e-04 - 1s/epoch - 13ms/step
# Epoch 161/300
#
# Epoch 161: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.7888e-04 - mae: 0.0049 - mse: 1.7888e-04 - val_loss: 5.8846e-04 - val_mae: 0.0080 - val_mse: 5.8846e-04 - 1s/epoch - 14ms/step
# Epoch 162/300
#
# Epoch 162: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.7736e-04 - mae: 0.0049 - mse: 1.7736e-04 - val_loss: 6.1846e-04 - val_mae: 0.0070 - val_mse: 6.1846e-04 - 1s/epoch - 14ms/step
# Epoch 163/300
#
# Epoch 163: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.9296e-04 - mae: 0.0054 - mse: 1.9296e-04 - val_loss: 6.5428e-04 - val_mae: 0.0077 - val_mse: 6.5428e-04 - 1s/epoch - 13ms/step
# Epoch 164/300
#
# Epoch 164: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 2.0240e-04 - mae: 0.0055 - mse: 2.0240e-04 - val_loss: 6.1242e-04 - val_mae: 0.0067 - val_mse: 6.1242e-04 - 2s/epoch - 20ms/step
# Epoch 165/300
#
# Epoch 165: val_mse did not improve from 0.00056
# 88/88 - 2s - loss: 1.8552e-04 - mae: 0.0051 - mse: 1.8552e-04 - val_loss: 5.8658e-04 - val_mae: 0.0069 - val_mse: 5.8658e-04 - 2s/epoch - 18ms/step
# Epoch 166/300
#
# Epoch 166: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8839e-04 - mae: 0.0051 - mse: 1.8839e-04 - val_loss: 5.8963e-04 - val_mae: 0.0076 - val_mse: 5.8963e-04 - 1s/epoch - 13ms/step
# Epoch 167/300
#
# Epoch 167: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.7870e-04 - mae: 0.0048 - mse: 1.7870e-04 - val_loss: 6.2866e-04 - val_mae: 0.0075 - val_mse: 6.2866e-04 - 1s/epoch - 13ms/step
# Epoch 168/300
#
# Epoch 168: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8220e-04 - mae: 0.0048 - mse: 1.8220e-04 - val_loss: 6.5895e-04 - val_mae: 0.0101 - val_mse: 6.5895e-04 - 1s/epoch - 13ms/step
# Epoch 169/300
#
# Epoch 169: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 2.0678e-04 - mae: 0.0056 - mse: 2.0678e-04 - val_loss: 7.2291e-04 - val_mae: 0.0083 - val_mse: 7.2291e-04 - 1s/epoch - 12ms/step
# Epoch 170/300
#
# Epoch 170: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8575e-04 - mae: 0.0051 - mse: 1.8575e-04 - val_loss: 6.3892e-04 - val_mae: 0.0070 - val_mse: 6.3892e-04 - 1s/epoch - 13ms/step
# Epoch 171/300
#
# Epoch 171: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 1.8613e-04 - mae: 0.0051 - mse: 1.8613e-04 - val_loss: 6.8759e-04 - val_mae: 0.0085 - val_mse: 6.8759e-04 - 1s/epoch - 14ms/step
# Epoch 172/300
#
# Epoch 172: val_mse did not improve from 0.00056
# 88/88 - 1s - loss: 2.0017e-04 - mae: 0.0053 - mse: 2.0017e-04 - val_loss: 6.4235e-04 - val_mae: 0.0071 - val_mse: 6.4235e-04 - 1s/epoch - 14ms/step
# Epoch 173/300
#
# Epoch 173: val_mse improved from 0.00056 to 0.00055, saving model to best_model.h5
# 88/88 - 1s - loss: 1.9490e-04 - mae: 0.0055 - mse: 1.9490e-04 - val_loss: 5.5313e-04 - val_mae: 0.0067 - val_mse: 5.5313e-04 - 1s/epoch - 13ms/step
# Epoch 174/300
#
# Epoch 174: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.7972e-04 - mae: 0.0048 - mse: 1.7972e-04 - val_loss: 6.2375e-04 - val_mae: 0.0084 - val_mse: 6.2375e-04 - 2s/epoch - 21ms/step
# Epoch 175/300
#
# Epoch 175: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 2.0141e-04 - mae: 0.0054 - mse: 2.0141e-04 - val_loss: 6.0594e-04 - val_mae: 0.0079 - val_mse: 6.0594e-04 - 2s/epoch - 17ms/step
# Epoch 176/300
#
# Epoch 176: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7694e-04 - mae: 0.0048 - mse: 1.7694e-04 - val_loss: 6.1201e-04 - val_mae: 0.0079 - val_mse: 6.1201e-04 - 1s/epoch - 14ms/step
# Epoch 177/300
#
# Epoch 177: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7919e-04 - mae: 0.0049 - mse: 1.7919e-04 - val_loss: 5.9795e-04 - val_mae: 0.0080 - val_mse: 5.9795e-04 - 1s/epoch - 14ms/step
# Epoch 178/300
#
# Epoch 178: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8691e-04 - mae: 0.0052 - mse: 1.8691e-04 - val_loss: 5.8387e-04 - val_mae: 0.0074 - val_mse: 5.8387e-04 - 1s/epoch - 14ms/step
# Epoch 179/300
#
# Epoch 179: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8198e-04 - mae: 0.0049 - mse: 1.8198e-04 - val_loss: 6.0081e-04 - val_mae: 0.0068 - val_mse: 6.0081e-04 - 1s/epoch - 14ms/step
# Epoch 180/300
#
# Epoch 180: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7169e-04 - mae: 0.0048 - mse: 1.7169e-04 - val_loss: 5.7910e-04 - val_mae: 0.0080 - val_mse: 5.7910e-04 - 1s/epoch - 14ms/step
# Epoch 181/300
#
# Epoch 181: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7113e-04 - mae: 0.0048 - mse: 1.7113e-04 - val_loss: 6.0023e-04 - val_mae: 0.0067 - val_mse: 6.0023e-04 - 1s/epoch - 12ms/step
# Epoch 182/300
#
# Epoch 182: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8830e-04 - mae: 0.0051 - mse: 1.8830e-04 - val_loss: 6.5624e-04 - val_mae: 0.0081 - val_mse: 6.5624e-04 - 1s/epoch - 14ms/step
# Epoch 183/300
#
# Epoch 183: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8904e-04 - mae: 0.0054 - mse: 1.8904e-04 - val_loss: 6.2762e-04 - val_mae: 0.0072 - val_mse: 6.2762e-04 - 1s/epoch - 17ms/step
# Epoch 184/300
#
# Epoch 184: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.9222e-04 - mae: 0.0052 - mse: 1.9222e-04 - val_loss: 6.3297e-04 - val_mae: 0.0071 - val_mse: 6.3297e-04 - 2s/epoch - 22ms/step
# Epoch 185/300
#
# Epoch 185: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7889e-04 - mae: 0.0050 - mse: 1.7889e-04 - val_loss: 6.1895e-04 - val_mae: 0.0071 - val_mse: 6.1895e-04 - 1s/epoch - 14ms/step
# Epoch 186/300
#
# Epoch 186: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7680e-04 - mae: 0.0049 - mse: 1.7680e-04 - val_loss: 6.0906e-04 - val_mae: 0.0074 - val_mse: 6.0906e-04 - 1s/epoch - 14ms/step
# Epoch 187/300
#
# Epoch 187: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7785e-04 - mae: 0.0050 - mse: 1.7785e-04 - val_loss: 6.0022e-04 - val_mae: 0.0072 - val_mse: 6.0022e-04 - 1s/epoch - 14ms/step
# Epoch 188/300
#
# Epoch 188: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7195e-04 - mae: 0.0047 - mse: 1.7195e-04 - val_loss: 6.2338e-04 - val_mae: 0.0071 - val_mse: 6.2338e-04 - 1s/epoch - 12ms/step
# Epoch 189/300
#
# Epoch 189: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7107e-04 - mae: 0.0047 - mse: 1.7107e-04 - val_loss: 6.2027e-04 - val_mae: 0.0079 - val_mse: 6.2027e-04 - 1s/epoch - 14ms/step
# Epoch 190/300
#
# Epoch 190: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8748e-04 - mae: 0.0053 - mse: 1.8748e-04 - val_loss: 6.3935e-04 - val_mae: 0.0098 - val_mse: 6.3935e-04 - 1s/epoch - 13ms/step
# Epoch 191/300
#
# Epoch 191: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7523e-04 - mae: 0.0050 - mse: 1.7523e-04 - val_loss: 6.2637e-04 - val_mae: 0.0075 - val_mse: 6.2637e-04 - 1s/epoch - 12ms/step
# Epoch 192/300
#
# Epoch 192: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 2.2542e-04 - mae: 0.0059 - mse: 2.2542e-04 - val_loss: 5.8751e-04 - val_mae: 0.0069 - val_mse: 5.8751e-04 - 1s/epoch - 13ms/step
# Epoch 193/300
#
# Epoch 193: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.8282e-04 - mae: 0.0048 - mse: 1.8282e-04 - val_loss: 6.4910e-04 - val_mae: 0.0078 - val_mse: 6.4910e-04 - 2s/epoch - 19ms/step
# Epoch 194/300
#
# Epoch 194: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.7487e-04 - mae: 0.0049 - mse: 1.7487e-04 - val_loss: 5.8897e-04 - val_mae: 0.0072 - val_mse: 5.8897e-04 - 2s/epoch - 19ms/step
# Epoch 195/300
#
# Epoch 195: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7455e-04 - mae: 0.0049 - mse: 1.7455e-04 - val_loss: 5.7914e-04 - val_mae: 0.0076 - val_mse: 5.7914e-04 - 1s/epoch - 14ms/step
# Epoch 196/300
#
# Epoch 196: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7222e-04 - mae: 0.0048 - mse: 1.7222e-04 - val_loss: 6.5167e-04 - val_mae: 0.0072 - val_mse: 6.5167e-04 - 1s/epoch - 14ms/step
# Epoch 197/300
#
# Epoch 197: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7318e-04 - mae: 0.0047 - mse: 1.7318e-04 - val_loss: 6.0294e-04 - val_mae: 0.0070 - val_mse: 6.0294e-04 - 1s/epoch - 12ms/step
# Epoch 198/300
#
# Epoch 198: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7986e-04 - mae: 0.0050 - mse: 1.7986e-04 - val_loss: 6.4679e-04 - val_mae: 0.0074 - val_mse: 6.4679e-04 - 1s/epoch - 13ms/step
# Epoch 199/300
#
# Epoch 199: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7800e-04 - mae: 0.0050 - mse: 1.7800e-04 - val_loss: 5.9901e-04 - val_mae: 0.0072 - val_mse: 5.9901e-04 - 1s/epoch - 13ms/step
# Epoch 200/300
#
# Epoch 200: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7091e-04 - mae: 0.0049 - mse: 1.7091e-04 - val_loss: 6.0228e-04 - val_mae: 0.0079 - val_mse: 6.0228e-04 - 1s/epoch - 13ms/step
# Epoch 201/300
#
# Epoch 201: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6825e-04 - mae: 0.0046 - mse: 1.6825e-04 - val_loss: 8.3468e-04 - val_mae: 0.0092 - val_mse: 8.3468e-04 - 1s/epoch - 15ms/step
# Epoch 202/300
#
# Epoch 202: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8106e-04 - mae: 0.0051 - mse: 1.8106e-04 - val_loss: 6.6886e-04 - val_mae: 0.0076 - val_mse: 6.6886e-04 - 1s/epoch - 13ms/step
# Epoch 203/300
#
# Epoch 203: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.7426e-04 - mae: 0.0048 - mse: 1.7426e-04 - val_loss: 5.8082e-04 - val_mae: 0.0066 - val_mse: 5.8082e-04 - 2s/epoch - 22ms/step
# Epoch 204/300
#
# Epoch 204: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7786e-04 - mae: 0.0050 - mse: 1.7786e-04 - val_loss: 6.5246e-04 - val_mae: 0.0075 - val_mse: 6.5246e-04 - 1s/epoch - 17ms/step
# Epoch 205/300
#
# Epoch 205: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7036e-04 - mae: 0.0048 - mse: 1.7036e-04 - val_loss: 6.1131e-04 - val_mae: 0.0073 - val_mse: 6.1131e-04 - 1s/epoch - 14ms/step
# Epoch 206/300
#
# Epoch 206: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8054e-04 - mae: 0.0052 - mse: 1.8054e-04 - val_loss: 6.1140e-04 - val_mae: 0.0076 - val_mse: 6.1140e-04 - 1s/epoch - 14ms/step
# Epoch 207/300
#
# Epoch 207: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7266e-04 - mae: 0.0049 - mse: 1.7266e-04 - val_loss: 5.8885e-04 - val_mae: 0.0074 - val_mse: 5.8885e-04 - 1s/epoch - 12ms/step
# Epoch 208/300
#
# Epoch 208: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7404e-04 - mae: 0.0051 - mse: 1.7404e-04 - val_loss: 6.2554e-04 - val_mae: 0.0075 - val_mse: 6.2554e-04 - 1s/epoch - 12ms/step
# Epoch 209/300
#
# Epoch 209: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7894e-04 - mae: 0.0049 - mse: 1.7894e-04 - val_loss: 6.2299e-04 - val_mae: 0.0071 - val_mse: 6.2299e-04 - 1s/epoch - 13ms/step
# Epoch 210/300
#
# Epoch 210: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7420e-04 - mae: 0.0048 - mse: 1.7420e-04 - val_loss: 5.9407e-04 - val_mae: 0.0071 - val_mse: 5.9407e-04 - 1s/epoch - 12ms/step
# Epoch 211/300
#
# Epoch 211: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6613e-04 - mae: 0.0046 - mse: 1.6613e-04 - val_loss: 6.6408e-04 - val_mae: 0.0076 - val_mse: 6.6408e-04 - 1s/epoch - 13ms/step
# Epoch 212/300
#
# Epoch 212: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7285e-04 - mae: 0.0048 - mse: 1.7285e-04 - val_loss: 5.9452e-04 - val_mae: 0.0071 - val_mse: 5.9452e-04 - 1s/epoch - 14ms/step
# Epoch 213/300
#
# Epoch 213: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.7469e-04 - mae: 0.0047 - mse: 1.7469e-04 - val_loss: 6.0056e-04 - val_mae: 0.0078 - val_mse: 6.0056e-04 - 2s/epoch - 22ms/step
# Epoch 214/300
#
# Epoch 214: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8590e-04 - mae: 0.0052 - mse: 1.8590e-04 - val_loss: 6.3745e-04 - val_mae: 0.0072 - val_mse: 6.3745e-04 - 1s/epoch - 14ms/step
# Epoch 215/300
#
# Epoch 215: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7431e-04 - mae: 0.0048 - mse: 1.7431e-04 - val_loss: 6.3619e-04 - val_mae: 0.0084 - val_mse: 6.3619e-04 - 1s/epoch - 12ms/step
# Epoch 216/300
#
# Epoch 216: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7275e-04 - mae: 0.0048 - mse: 1.7275e-04 - val_loss: 5.7814e-04 - val_mae: 0.0078 - val_mse: 5.7814e-04 - 1s/epoch - 14ms/step
# Epoch 217/300
#
# Epoch 217: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6767e-04 - mae: 0.0047 - mse: 1.6767e-04 - val_loss: 6.6144e-04 - val_mae: 0.0087 - val_mse: 6.6144e-04 - 1s/epoch - 13ms/step
# Epoch 218/300
#
# Epoch 218: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7244e-04 - mae: 0.0050 - mse: 1.7244e-04 - val_loss: 6.2425e-04 - val_mae: 0.0076 - val_mse: 6.2425e-04 - 1s/epoch - 14ms/step
# Epoch 219/300
#
# Epoch 219: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 2.0892e-04 - mae: 0.0057 - mse: 2.0892e-04 - val_loss: 6.0140e-04 - val_mae: 0.0074 - val_mse: 6.0140e-04 - 1s/epoch - 14ms/step
# Epoch 220/300
#
# Epoch 220: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7222e-04 - mae: 0.0048 - mse: 1.7222e-04 - val_loss: 5.9940e-04 - val_mae: 0.0079 - val_mse: 5.9940e-04 - 1s/epoch - 14ms/step
# Epoch 221/300
#
# Epoch 221: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7342e-04 - mae: 0.0048 - mse: 1.7342e-04 - val_loss: 6.0219e-04 - val_mae: 0.0077 - val_mse: 6.0219e-04 - 1s/epoch - 12ms/step
# Epoch 222/300
#
# Epoch 222: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.9342e-04 - mae: 0.0052 - mse: 1.9342e-04 - val_loss: 6.8448e-04 - val_mae: 0.0078 - val_mse: 6.8448e-04 - 1s/epoch - 16ms/step
# Epoch 223/300
#
# Epoch 223: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 2.5483e-04 - mae: 0.0062 - mse: 2.5483e-04 - val_loss: 6.4659e-04 - val_mae: 0.0080 - val_mse: 6.4659e-04 - 2s/epoch - 22ms/step
# Epoch 224/300
#
# Epoch 224: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8752e-04 - mae: 0.0051 - mse: 1.8752e-04 - val_loss: 6.2187e-04 - val_mae: 0.0080 - val_mse: 6.2187e-04 - 1s/epoch - 13ms/step
# Epoch 225/300
#
# Epoch 225: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8461e-04 - mae: 0.0049 - mse: 1.8461e-04 - val_loss: 6.3311e-04 - val_mae: 0.0080 - val_mse: 6.3311e-04 - 1s/epoch - 13ms/step
# Epoch 226/300
#
# Epoch 226: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7037e-04 - mae: 0.0047 - mse: 1.7037e-04 - val_loss: 6.2084e-04 - val_mae: 0.0081 - val_mse: 6.2084e-04 - 1s/epoch - 14ms/step
# Epoch 227/300
#
# Epoch 227: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6656e-04 - mae: 0.0047 - mse: 1.6656e-04 - val_loss: 6.2361e-04 - val_mae: 0.0070 - val_mse: 6.2361e-04 - 1s/epoch - 13ms/step
# Epoch 228/300
#
# Epoch 228: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6538e-04 - mae: 0.0046 - mse: 1.6538e-04 - val_loss: 6.1418e-04 - val_mae: 0.0070 - val_mse: 6.1418e-04 - 1s/epoch - 12ms/step
# Epoch 229/300
#
# Epoch 229: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6592e-04 - mae: 0.0045 - mse: 1.6592e-04 - val_loss: 5.8845e-04 - val_mae: 0.0068 - val_mse: 5.8845e-04 - 1s/epoch - 14ms/step
# Epoch 230/300
#
# Epoch 230: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6829e-04 - mae: 0.0047 - mse: 1.6829e-04 - val_loss: 6.2727e-04 - val_mae: 0.0071 - val_mse: 6.2727e-04 - 1s/epoch - 14ms/step
# Epoch 231/300
#
# Epoch 231: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7337e-04 - mae: 0.0049 - mse: 1.7337e-04 - val_loss: 6.3029e-04 - val_mae: 0.0075 - val_mse: 6.3029e-04 - 1s/epoch - 13ms/step
# Epoch 232/300
#
# Epoch 232: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.6626e-04 - mae: 0.0047 - mse: 1.6626e-04 - val_loss: 6.0831e-04 - val_mae: 0.0070 - val_mse: 6.0831e-04 - 2s/epoch - 19ms/step
# Epoch 233/300
#
# Epoch 233: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.6327e-04 - mae: 0.0044 - mse: 1.6327e-04 - val_loss: 6.4298e-04 - val_mae: 0.0076 - val_mse: 6.4298e-04 - 2s/epoch - 18ms/step
# Epoch 234/300
#
# Epoch 234: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7639e-04 - mae: 0.0049 - mse: 1.7639e-04 - val_loss: 6.0742e-04 - val_mae: 0.0078 - val_mse: 6.0742e-04 - 1s/epoch - 14ms/step
# Epoch 235/300
#
# Epoch 235: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6492e-04 - mae: 0.0047 - mse: 1.6492e-04 - val_loss: 6.1155e-04 - val_mae: 0.0078 - val_mse: 6.1155e-04 - 1s/epoch - 13ms/step
# Epoch 236/300
#
# Epoch 236: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6642e-04 - mae: 0.0047 - mse: 1.6642e-04 - val_loss: 6.0137e-04 - val_mae: 0.0070 - val_mse: 6.0137e-04 - 1s/epoch - 14ms/step
# Epoch 237/300
#
# Epoch 237: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6885e-04 - mae: 0.0048 - mse: 1.6885e-04 - val_loss: 6.0630e-04 - val_mae: 0.0075 - val_mse: 6.0630e-04 - 1s/epoch - 14ms/step
# Epoch 238/300
#
# Epoch 238: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6102e-04 - mae: 0.0045 - mse: 1.6102e-04 - val_loss: 5.8244e-04 - val_mae: 0.0066 - val_mse: 5.8244e-04 - 1s/epoch - 12ms/step
# Epoch 239/300
#
# Epoch 239: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8438e-04 - mae: 0.0051 - mse: 1.8438e-04 - val_loss: 6.1671e-04 - val_mae: 0.0070 - val_mse: 6.1671e-04 - 1s/epoch - 13ms/step
# Epoch 240/300
#
# Epoch 240: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7408e-04 - mae: 0.0048 - mse: 1.7408e-04 - val_loss: 5.9180e-04 - val_mae: 0.0075 - val_mse: 5.9180e-04 - 1s/epoch - 14ms/step
# Epoch 241/300
#
# Epoch 241: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6454e-04 - mae: 0.0047 - mse: 1.6454e-04 - val_loss: 6.3099e-04 - val_mae: 0.0070 - val_mse: 6.3099e-04 - 1s/epoch - 13ms/step
# Epoch 242/300
#
# Epoch 242: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.7769e-04 - mae: 0.0051 - mse: 1.7769e-04 - val_loss: 6.3289e-04 - val_mae: 0.0075 - val_mse: 6.3289e-04 - 2s/epoch - 21ms/step
# Epoch 243/300
#
# Epoch 243: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.7948e-04 - mae: 0.0047 - mse: 1.7948e-04 - val_loss: 5.8238e-04 - val_mae: 0.0072 - val_mse: 5.8238e-04 - 2s/epoch - 17ms/step
# Epoch 244/300
#
# Epoch 244: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7105e-04 - mae: 0.0046 - mse: 1.7105e-04 - val_loss: 6.0925e-04 - val_mae: 0.0072 - val_mse: 6.0925e-04 - 1s/epoch - 14ms/step
# Epoch 245/300
#
# Epoch 245: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6636e-04 - mae: 0.0048 - mse: 1.6636e-04 - val_loss: 6.2117e-04 - val_mae: 0.0083 - val_mse: 6.2117e-04 - 1s/epoch - 14ms/step
# Epoch 246/300
#
# Epoch 246: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6337e-04 - mae: 0.0045 - mse: 1.6337e-04 - val_loss: 6.2033e-04 - val_mae: 0.0068 - val_mse: 6.2033e-04 - 1s/epoch - 13ms/step
# Epoch 247/300
#
# Epoch 247: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6020e-04 - mae: 0.0045 - mse: 1.6020e-04 - val_loss: 5.8837e-04 - val_mae: 0.0070 - val_mse: 5.8837e-04 - 1s/epoch - 14ms/step
# Epoch 248/300
#
# Epoch 248: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5919e-04 - mae: 0.0045 - mse: 1.5919e-04 - val_loss: 6.0459e-04 - val_mae: 0.0072 - val_mse: 6.0459e-04 - 1s/epoch - 14ms/step
# Epoch 249/300
#
# Epoch 249: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6377e-04 - mae: 0.0045 - mse: 1.6377e-04 - val_loss: 6.1003e-04 - val_mae: 0.0085 - val_mse: 6.1003e-04 - 1s/epoch - 13ms/step
# Epoch 250/300
#
# Epoch 250: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5977e-04 - mae: 0.0046 - mse: 1.5977e-04 - val_loss: 5.7441e-04 - val_mae: 0.0067 - val_mse: 5.7441e-04 - 1s/epoch - 13ms/step
# Epoch 251/300
#
# Epoch 251: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6295e-04 - mae: 0.0046 - mse: 1.6295e-04 - val_loss: 6.6332e-04 - val_mae: 0.0085 - val_mse: 6.6332e-04 - 1s/epoch - 16ms/step
# Epoch 252/300
#
# Epoch 252: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.8135e-04 - mae: 0.0055 - mse: 1.8135e-04 - val_loss: 5.7345e-04 - val_mae: 0.0082 - val_mse: 5.7345e-04 - 2s/epoch - 21ms/step
# Epoch 253/300
#
# Epoch 253: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6556e-04 - mae: 0.0046 - mse: 1.6556e-04 - val_loss: 6.3631e-04 - val_mae: 0.0074 - val_mse: 6.3631e-04 - 1s/epoch - 13ms/step
# Epoch 254/300
#
# Epoch 254: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7080e-04 - mae: 0.0049 - mse: 1.7080e-04 - val_loss: 7.5409e-04 - val_mae: 0.0107 - val_mse: 7.5409e-04 - 1s/epoch - 14ms/step
# Epoch 255/300
#
# Epoch 255: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7484e-04 - mae: 0.0050 - mse: 1.7484e-04 - val_loss: 5.6933e-04 - val_mae: 0.0071 - val_mse: 5.6933e-04 - 1s/epoch - 12ms/step
# Epoch 256/300
#
# Epoch 256: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6947e-04 - mae: 0.0048 - mse: 1.6947e-04 - val_loss: 6.5375e-04 - val_mae: 0.0092 - val_mse: 6.5375e-04 - 1s/epoch - 14ms/step
# Epoch 257/300
#
# Epoch 257: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.9787e-04 - mae: 0.0052 - mse: 1.9787e-04 - val_loss: 6.1525e-04 - val_mae: 0.0075 - val_mse: 6.1525e-04 - 1s/epoch - 14ms/step
# Epoch 258/300
#
# Epoch 258: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6501e-04 - mae: 0.0046 - mse: 1.6501e-04 - val_loss: 5.9403e-04 - val_mae: 0.0081 - val_mse: 5.9403e-04 - 1s/epoch - 14ms/step
# Epoch 259/300
#
# Epoch 259: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6494e-04 - mae: 0.0047 - mse: 1.6494e-04 - val_loss: 6.5756e-04 - val_mae: 0.0079 - val_mse: 6.5756e-04 - 1s/epoch - 12ms/step
# Epoch 260/300
#
# Epoch 260: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6860e-04 - mae: 0.0047 - mse: 1.6860e-04 - val_loss: 5.9391e-04 - val_mae: 0.0094 - val_mse: 5.9391e-04 - 1s/epoch - 12ms/step
# Epoch 261/300
#
# Epoch 261: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.6693e-04 - mae: 0.0047 - mse: 1.6693e-04 - val_loss: 6.0813e-04 - val_mae: 0.0068 - val_mse: 6.0813e-04 - 2s/epoch - 17ms/step
# Epoch 262/300
#
# Epoch 262: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.6785e-04 - mae: 0.0048 - mse: 1.6785e-04 - val_loss: 6.0159e-04 - val_mae: 0.0077 - val_mse: 6.0159e-04 - 2s/epoch - 21ms/step
# Epoch 263/300
#
# Epoch 263: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6769e-04 - mae: 0.0049 - mse: 1.6769e-04 - val_loss: 6.2827e-04 - val_mae: 0.0071 - val_mse: 6.2827e-04 - 1s/epoch - 12ms/step
# Epoch 264/300
#
# Epoch 264: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5653e-04 - mae: 0.0045 - mse: 1.5653e-04 - val_loss: 6.0605e-04 - val_mae: 0.0066 - val_mse: 6.0605e-04 - 1s/epoch - 14ms/step
# Epoch 265/300
#
# Epoch 265: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5853e-04 - mae: 0.0045 - mse: 1.5853e-04 - val_loss: 5.8798e-04 - val_mae: 0.0069 - val_mse: 5.8798e-04 - 1s/epoch - 14ms/step
# Epoch 266/300
#
# Epoch 266: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5874e-04 - mae: 0.0045 - mse: 1.5874e-04 - val_loss: 6.4838e-04 - val_mae: 0.0072 - val_mse: 6.4838e-04 - 1s/epoch - 14ms/step
# Epoch 267/300
#
# Epoch 267: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6486e-04 - mae: 0.0046 - mse: 1.6486e-04 - val_loss: 6.1701e-04 - val_mae: 0.0072 - val_mse: 6.1701e-04 - 1s/epoch - 12ms/step
# Epoch 268/300
#
# Epoch 268: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8278e-04 - mae: 0.0049 - mse: 1.8278e-04 - val_loss: 6.1071e-04 - val_mae: 0.0073 - val_mse: 6.1071e-04 - 1s/epoch - 14ms/step
# Epoch 269/300
#
# Epoch 269: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6409e-04 - mae: 0.0047 - mse: 1.6409e-04 - val_loss: 6.2844e-04 - val_mae: 0.0083 - val_mse: 6.2844e-04 - 1s/epoch - 13ms/step
# Epoch 270/300
#
# Epoch 270: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5977e-04 - mae: 0.0045 - mse: 1.5977e-04 - val_loss: 6.1037e-04 - val_mae: 0.0072 - val_mse: 6.1037e-04 - 1s/epoch - 12ms/step
# Epoch 271/300
#
# Epoch 271: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.6113e-04 - mae: 0.0047 - mse: 1.6113e-04 - val_loss: 6.5645e-04 - val_mae: 0.0102 - val_mse: 6.5645e-04 - 2s/epoch - 20ms/step
# Epoch 272/300
#
# Epoch 272: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.8241e-04 - mae: 0.0054 - mse: 1.8241e-04 - val_loss: 6.3320e-04 - val_mae: 0.0075 - val_mse: 6.3320e-04 - 2s/epoch - 18ms/step
# Epoch 273/300
#
# Epoch 273: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6964e-04 - mae: 0.0047 - mse: 1.6964e-04 - val_loss: 6.1636e-04 - val_mae: 0.0079 - val_mse: 6.1636e-04 - 1s/epoch - 14ms/step
# Epoch 274/300
#
# Epoch 274: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5709e-04 - mae: 0.0045 - mse: 1.5709e-04 - val_loss: 6.5849e-04 - val_mae: 0.0081 - val_mse: 6.5849e-04 - 1s/epoch - 14ms/step
# Epoch 275/300
#
# Epoch 275: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5873e-04 - mae: 0.0045 - mse: 1.5873e-04 - val_loss: 6.4768e-04 - val_mae: 0.0092 - val_mse: 6.4768e-04 - 1s/epoch - 14ms/step
# Epoch 276/300
#
# Epoch 276: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7066e-04 - mae: 0.0049 - mse: 1.7066e-04 - val_loss: 5.9116e-04 - val_mae: 0.0068 - val_mse: 5.9116e-04 - 1s/epoch - 14ms/step
# Epoch 277/300
#
# Epoch 277: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.8169e-04 - mae: 0.0049 - mse: 1.8169e-04 - val_loss: 6.3266e-04 - val_mae: 0.0072 - val_mse: 6.3266e-04 - 1s/epoch - 12ms/step
# Epoch 278/300
#
# Epoch 278: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6339e-04 - mae: 0.0045 - mse: 1.6339e-04 - val_loss: 6.0748e-04 - val_mae: 0.0072 - val_mse: 6.0748e-04 - 1s/epoch - 14ms/step
# Epoch 279/300
#
# Epoch 279: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5841e-04 - mae: 0.0045 - mse: 1.5841e-04 - val_loss: 6.0173e-04 - val_mae: 0.0073 - val_mse: 6.0173e-04 - 1s/epoch - 16ms/step
# Epoch 280/300
#
# Epoch 280: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6283e-04 - mae: 0.0046 - mse: 1.6283e-04 - val_loss: 6.3826e-04 - val_mae: 0.0078 - val_mse: 6.3826e-04 - 1s/epoch - 17ms/step
# Epoch 281/300
#
# Epoch 281: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.5972e-04 - mae: 0.0044 - mse: 1.5972e-04 - val_loss: 5.9159e-04 - val_mae: 0.0076 - val_mse: 5.9159e-04 - 2s/epoch - 21ms/step
# Epoch 282/300
#
# Epoch 282: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6558e-04 - mae: 0.0047 - mse: 1.6558e-04 - val_loss: 6.0999e-04 - val_mae: 0.0089 - val_mse: 6.0999e-04 - 1s/epoch - 14ms/step
# Epoch 283/300
#
# Epoch 283: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7146e-04 - mae: 0.0049 - mse: 1.7146e-04 - val_loss: 6.1273e-04 - val_mae: 0.0071 - val_mse: 6.1273e-04 - 1s/epoch - 12ms/step
# Epoch 284/300
#
# Epoch 284: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6579e-04 - mae: 0.0049 - mse: 1.6579e-04 - val_loss: 6.0332e-04 - val_mae: 0.0083 - val_mse: 6.0332e-04 - 1s/epoch - 14ms/step
# Epoch 285/300
#
# Epoch 285: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6189e-04 - mae: 0.0045 - mse: 1.6189e-04 - val_loss: 5.8828e-04 - val_mae: 0.0075 - val_mse: 5.8828e-04 - 1s/epoch - 12ms/step
# Epoch 286/300
#
# Epoch 286: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6117e-04 - mae: 0.0046 - mse: 1.6117e-04 - val_loss: 5.8788e-04 - val_mae: 0.0067 - val_mse: 5.8788e-04 - 1s/epoch - 14ms/step
# Epoch 287/300
#
# Epoch 287: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.7104e-04 - mae: 0.0048 - mse: 1.7104e-04 - val_loss: 6.1392e-04 - val_mae: 0.0082 - val_mse: 6.1392e-04 - 1s/epoch - 12ms/step
# Epoch 288/300
#
# Epoch 288: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6701e-04 - mae: 0.0049 - mse: 1.6701e-04 - val_loss: 6.5797e-04 - val_mae: 0.0075 - val_mse: 6.5797e-04 - 1s/epoch - 14ms/step
# Epoch 289/300
#
# Epoch 289: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6219e-04 - mae: 0.0046 - mse: 1.6219e-04 - val_loss: 5.8811e-04 - val_mae: 0.0073 - val_mse: 5.8811e-04 - 1s/epoch - 13ms/step
# Epoch 290/300
#
# Epoch 290: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.5442e-04 - mae: 0.0045 - mse: 1.5442e-04 - val_loss: 6.7048e-04 - val_mae: 0.0085 - val_mse: 6.7048e-04 - 2s/epoch - 20ms/step
# Epoch 291/300
#
# Epoch 291: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.6348e-04 - mae: 0.0049 - mse: 1.6348e-04 - val_loss: 5.9308e-04 - val_mae: 0.0069 - val_mse: 5.9308e-04 - 2s/epoch - 19ms/step
# Epoch 292/300
#
# Epoch 292: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6446e-04 - mae: 0.0048 - mse: 1.6446e-04 - val_loss: 6.2363e-04 - val_mae: 0.0074 - val_mse: 6.2363e-04 - 1s/epoch - 13ms/step
# Epoch 293/300
#
# Epoch 293: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6324e-04 - mae: 0.0047 - mse: 1.6324e-04 - val_loss: 6.1093e-04 - val_mae: 0.0074 - val_mse: 6.1093e-04 - 1s/epoch - 14ms/step
# Epoch 294/300
#
# Epoch 294: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6273e-04 - mae: 0.0046 - mse: 1.6273e-04 - val_loss: 6.7024e-04 - val_mae: 0.0075 - val_mse: 6.7024e-04 - 1s/epoch - 13ms/step
# Epoch 295/300
#
# Epoch 295: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6314e-04 - mae: 0.0046 - mse: 1.6314e-04 - val_loss: 6.3228e-04 - val_mae: 0.0067 - val_mse: 6.3228e-04 - 1s/epoch - 14ms/step
# Epoch 296/300
#
# Epoch 296: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5436e-04 - mae: 0.0043 - mse: 1.5436e-04 - val_loss: 7.4492e-04 - val_mae: 0.0098 - val_mse: 7.4492e-04 - 1s/epoch - 14ms/step
# Epoch 297/300
#
# Epoch 297: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.6894e-04 - mae: 0.0048 - mse: 1.6894e-04 - val_loss: 6.2625e-04 - val_mae: 0.0076 - val_mse: 6.2625e-04 - 1s/epoch - 12ms/step
# Epoch 298/300
#
# Epoch 298: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5938e-04 - mae: 0.0047 - mse: 1.5938e-04 - val_loss: 6.0555e-04 - val_mae: 0.0089 - val_mse: 6.0555e-04 - 1s/epoch - 14ms/step
# Epoch 299/300
#
# Epoch 299: val_mse did not improve from 0.00055
# 88/88 - 1s - loss: 1.5789e-04 - mae: 0.0045 - mse: 1.5789e-04 - val_loss: 6.2036e-04 - val_mae: 0.0075 - val_mse: 6.2036e-04 - 1s/epoch - 13ms/step
# Epoch 300/300
#
# Epoch 300: val_mse did not improve from 0.00055
# 88/88 - 2s - loss: 1.5879e-04 - mae: 0.0047 - mse: 1.5879e-04 - val_loss: 6.1689e-04 - val_mae: 0.0072 - val_mse: 6.1689e-04 - 2s/epoch - 21ms/step

# %% [markdown]
# Load the best model

# %%
# Load the best model
# Load the best model using keras.utils.custom_object_scope
from tensorflow.keras.models import load_model
custom_objects = {"AttentionLayer": AttentionLayer}
with tf.keras.utils.custom_object_scope(custom_objects):
    best_model = load_model(checkpoint_path,compile=False)

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.006566410884261131
# Minimum Validation MAE at epoch 237
# Minimum Validation loss 0.00015436485409736633
# Minimum Validation loss at epoch 172

# %%
trainPredict = best_model.predict(trainX)
testPredict = best_model.predict(testX)
# Out:
# 175/175 [==============================] - 1s 3ms/step
# 94/94 [==============================] - 0s 4ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.27 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.47 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.09583084262771456
# Mean Absolute Error on test data: 0.13401928357827628

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.07335861769159874
# Mean Squared Error (MSE) of test: 0.22125338370883582

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         0      1376314846          2                     5851.998636
# 1         1      1376315146          2                     5851.998636
# 2         2      1376315446          2                     5851.998636
# 3         3      1376315746          2                     5851.998636
# 4         4      1376316046          2                     5851.998636
# ...     ...             ...        ...                             ...
# 8452   8452      1378905598          2                     5851.998944
# 8453   8453      1378905898          2                     5851.998944
# 8454   8454      1378906198          2                     5851.998944
# 8455   8455      1378906498          2                     5851.998944
# 8456   8456      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8452        76.075986       1.300000                         2097152.0
# 8453        54.618657       0.933333                         2097152.0
# 8454        58.519989       1.000000                         2097152.0
# 8455       325.761275       5.566667                         2097152.0
# 8456        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8452      329950.133333                     0.333333
# 8453      244665.333333                     1.800000
# 8454      139808.800000                     0.200000
# 8455      325755.733333                  1029.666667
# 8456      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8452                    561.866667                          581.800000
# 8453                      1.133333                            2.466667
# 8454                      0.866667                            2.400000
# 8455                     55.466667                            2.466667
# 8456                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8452                              18.400000  1.409906
# 8453                               1.066667  0.007356
# 8454                               1.066667  0.002675
# 8455                               1.533333  2.721338
# 8456                               1.000000  0.002173
#
# [8457 rows x 13 columns]

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[30:530],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+30:6198+30],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
