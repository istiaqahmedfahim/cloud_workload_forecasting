# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/Workload_forecasting_of_cloud_%7C_Attention_based_BiLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'cloud-computing-history-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4018029%2F6990719%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240205%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240205T135728Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading cloud-computing-history-data, 143815 bytes compressed
# [==================================================] 143815 bytes downloaded
# Downloaded and uncompressed: cloud-computing-history-data
# Data source import complete.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv("/kaggle/input/cloud-computing-history-data/43.csv")
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(None, seq_size)))
model.add(LSTM(units=50))
model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
model2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64,kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, seq_size]),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.GRU(64,activation="relu"),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(15, activation="relu"),
  tf.keras.layers.Dense(1,'linear')
])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model3 = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64,kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, seq_size]),
  tf.keras.layers.Bidirectional(LSTM(64, activation='relu',return_sequences=True)),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.GRU(64,activation="relu", return_sequences=True),
  tf.keras.layers.LSTM(50,activation="relu"),
  tf.keras.layers.Dense(1,'linear')
])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Attention

class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W_q = self.add_weight(name="W_q", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.W_k = self.add_weight(name="W_k", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.V = self.add_weight(name="V", shape=(input_shape[-1], 1), initializer="uniform", trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        q = tf.matmul(x, self.W_q)
        k = tf.matmul(x, self.W_k)
        scores = tf.matmul(tf.nn.tanh(q + k), self.V)
        attention_weights = tf.nn.softmax(scores, axis=-2)
        context_vector = attention_weights * x
        return context_vector

    def compute_output_shape(self, input_shape):
        return input_shape

seq_size = 30  # Replace with your sequence size

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, seq_size]),
    tf.keras.layers.Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
    tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
    tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
    tf.keras.layers.GRU(64, activation="relu", return_sequences=True),
    AttentionLayer(),  # Add Attention Layer
    tf.keras.layers.Bidirectional(LSTM(50, activation="relu")),  # Return sequences here
    tf.keras.layers.Dense(1, 'linear')
])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_7 (Conv1D)           (None, None, 64)          9664
#
#  bidirectional_9 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  lstm_28 (LSTM)              (None, None, 64)          49408
#
#  lstm_29 (LSTM)              (None, None, 64)          33024
#
#  gru_7 (GRU)                 (None, None, 64)          24960
#
#  attention_layer_5 (Attentio  (None, None, 64)         8256
#  nLayer)
#
#  bidirectional_10 (Bidirecti  (None, 100)              46000
#  onal)
#
#  dense_6 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 237,461
# Trainable params: 237,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae','mse'])

# %% [markdown]
# # Model Fitting

# %%
history = model.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 175/175 - 19s - loss: 0.0025 - mae: 0.0338 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0366 - val_mse: 0.0030 - 19s/epoch - 106ms/step
# Epoch 2/100
# 175/175 - 4s - loss: 0.0024 - mae: 0.0337 - mse: 0.0024 - val_loss: 0.0018 - val_mae: 0.0243 - val_mse: 0.0018 - 4s/epoch - 22ms/step
# Epoch 3/100
# 175/175 - 3s - loss: 8.7052e-04 - mae: 0.0140 - mse: 8.7052e-04 - val_loss: 0.0011 - val_mae: 0.0116 - val_mse: 0.0011 - 3s/epoch - 15ms/step
# Epoch 4/100
# 175/175 - 3s - loss: 6.9699e-04 - mae: 0.0119 - mse: 6.9699e-04 - val_loss: 9.0673e-04 - val_mae: 0.0098 - val_mse: 9.0673e-04 - 3s/epoch - 16ms/step
# Epoch 5/100
# 175/175 - 4s - loss: 6.3901e-04 - mae: 0.0112 - mse: 6.3901e-04 - val_loss: 8.7088e-04 - val_mae: 0.0144 - val_mse: 8.7088e-04 - 4s/epoch - 24ms/step
# Epoch 6/100
# 175/175 - 4s - loss: 6.1563e-04 - mae: 0.0108 - mse: 6.1563e-04 - val_loss: 8.5372e-04 - val_mae: 0.0109 - val_mse: 8.5372e-04 - 4s/epoch - 23ms/step
# Epoch 7/100
# 175/175 - 3s - loss: 6.2337e-04 - mae: 0.0109 - mse: 6.2337e-04 - val_loss: 8.2620e-04 - val_mae: 0.0109 - val_mse: 8.2620e-04 - 3s/epoch - 15ms/step
# Epoch 8/100
# 175/175 - 2s - loss: 5.6014e-04 - mae: 0.0104 - mse: 5.6014e-04 - val_loss: 7.9773e-04 - val_mae: 0.0112 - val_mse: 7.9773e-04 - 2s/epoch - 14ms/step
# Epoch 9/100
# 175/175 - 3s - loss: 5.5607e-04 - mae: 0.0102 - mse: 5.5607e-04 - val_loss: 8.3060e-04 - val_mae: 0.0143 - val_mse: 8.3060e-04 - 3s/epoch - 15ms/step
# Epoch 10/100
# 175/175 - 4s - loss: 5.4390e-04 - mae: 0.0103 - mse: 5.4390e-04 - val_loss: 8.0691e-04 - val_mae: 0.0118 - val_mse: 8.0691e-04 - 4s/epoch - 21ms/step
# Epoch 11/100
# 175/175 - 2s - loss: 5.2556e-04 - mae: 0.0099 - mse: 5.2556e-04 - val_loss: 8.5565e-04 - val_mae: 0.0142 - val_mse: 8.5565e-04 - 2s/epoch - 13ms/step
# Epoch 12/100
# 175/175 - 2s - loss: 5.0545e-04 - mae: 0.0096 - mse: 5.0545e-04 - val_loss: 8.0842e-04 - val_mae: 0.0103 - val_mse: 8.0842e-04 - 2s/epoch - 14ms/step
# Epoch 13/100
# 175/175 - 3s - loss: 4.9022e-04 - mae: 0.0094 - mse: 4.9022e-04 - val_loss: 8.7131e-04 - val_mae: 0.0091 - val_mse: 8.7131e-04 - 3s/epoch - 15ms/step
# Epoch 14/100
# 175/175 - 3s - loss: 5.0027e-04 - mae: 0.0097 - mse: 5.0027e-04 - val_loss: 7.4925e-04 - val_mae: 0.0102 - val_mse: 7.4925e-04 - 3s/epoch - 16ms/step
# Epoch 15/100
# 175/175 - 3s - loss: 4.6383e-04 - mae: 0.0093 - mse: 4.6383e-04 - val_loss: 7.4865e-04 - val_mae: 0.0100 - val_mse: 7.4865e-04 - 3s/epoch - 19ms/step
# Epoch 16/100
# 175/175 - 3s - loss: 4.2092e-04 - mae: 0.0085 - mse: 4.2092e-04 - val_loss: 7.2555e-04 - val_mae: 0.0103 - val_mse: 7.2555e-04 - 3s/epoch - 15ms/step
# Epoch 17/100
# 175/175 - 3s - loss: 4.1280e-04 - mae: 0.0085 - mse: 4.1280e-04 - val_loss: 8.4543e-04 - val_mae: 0.0104 - val_mse: 8.4543e-04 - 3s/epoch - 17ms/step
# Epoch 18/100
# 175/175 - 3s - loss: 4.1378e-04 - mae: 0.0086 - mse: 4.1378e-04 - val_loss: 8.0364e-04 - val_mae: 0.0090 - val_mse: 8.0364e-04 - 3s/epoch - 15ms/step
# Epoch 19/100
# 175/175 - 3s - loss: 4.1184e-04 - mae: 0.0085 - mse: 4.1184e-04 - val_loss: 7.9515e-04 - val_mae: 0.0117 - val_mse: 7.9515e-04 - 3s/epoch - 20ms/step
# Epoch 20/100
# 175/175 - 3s - loss: 3.8868e-04 - mae: 0.0081 - mse: 3.8868e-04 - val_loss: 7.1660e-04 - val_mae: 0.0087 - val_mse: 7.1660e-04 - 3s/epoch - 15ms/step
# Epoch 21/100
# 175/175 - 3s - loss: 3.8171e-04 - mae: 0.0082 - mse: 3.8171e-04 - val_loss: 7.5177e-04 - val_mae: 0.0090 - val_mse: 7.5177e-04 - 3s/epoch - 18ms/step
# Epoch 22/100
# 175/175 - 3s - loss: 3.6303e-04 - mae: 0.0079 - mse: 3.6303e-04 - val_loss: 7.0331e-04 - val_mae: 0.0082 - val_mse: 7.0331e-04 - 3s/epoch - 15ms/step
# Epoch 23/100
# 175/175 - 4s - loss: 3.5545e-04 - mae: 0.0078 - mse: 3.5545e-04 - val_loss: 6.9270e-04 - val_mae: 0.0111 - val_mse: 6.9270e-04 - 4s/epoch - 22ms/step
# Epoch 24/100
# 175/175 - 3s - loss: 3.6229e-04 - mae: 0.0077 - mse: 3.6229e-04 - val_loss: 6.9887e-04 - val_mae: 0.0085 - val_mse: 6.9887e-04 - 3s/epoch - 16ms/step
# Epoch 25/100
# 175/175 - 3s - loss: 4.2510e-04 - mae: 0.0086 - mse: 4.2510e-04 - val_loss: 8.0745e-04 - val_mae: 0.0093 - val_mse: 8.0745e-04 - 3s/epoch - 17ms/step
# Epoch 26/100
# 175/175 - 3s - loss: 3.6752e-04 - mae: 0.0075 - mse: 3.6752e-04 - val_loss: 6.9427e-04 - val_mae: 0.0097 - val_mse: 6.9427e-04 - 3s/epoch - 18ms/step
# Epoch 27/100
# 175/175 - 4s - loss: 3.8175e-04 - mae: 0.0083 - mse: 3.8175e-04 - val_loss: 8.1024e-04 - val_mae: 0.0100 - val_mse: 8.1024e-04 - 4s/epoch - 25ms/step
# Epoch 28/100
# 175/175 - 3s - loss: 3.2931e-04 - mae: 0.0074 - mse: 3.2931e-04 - val_loss: 7.0606e-04 - val_mae: 0.0104 - val_mse: 7.0606e-04 - 3s/epoch - 16ms/step
# Epoch 29/100
# 175/175 - 3s - loss: 3.2726e-04 - mae: 0.0073 - mse: 3.2726e-04 - val_loss: 6.2629e-04 - val_mae: 0.0114 - val_mse: 6.2629e-04 - 3s/epoch - 16ms/step
# Epoch 30/100
# 175/175 - 3s - loss: 3.1723e-04 - mae: 0.0073 - mse: 3.1723e-04 - val_loss: 6.3670e-04 - val_mae: 0.0082 - val_mse: 6.3670e-04 - 3s/epoch - 19ms/step
# Epoch 31/100
# 175/175 - 4s - loss: 3.1160e-04 - mae: 0.0073 - mse: 3.1160e-04 - val_loss: 7.1638e-04 - val_mae: 0.0095 - val_mse: 7.1638e-04 - 4s/epoch - 23ms/step
# Epoch 32/100
# 175/175 - 3s - loss: 2.9987e-04 - mae: 0.0069 - mse: 2.9987e-04 - val_loss: 7.0245e-04 - val_mae: 0.0096 - val_mse: 7.0245e-04 - 3s/epoch - 15ms/step
# Epoch 33/100
# 175/175 - 2s - loss: 2.8946e-04 - mae: 0.0069 - mse: 2.8946e-04 - val_loss: 6.1123e-04 - val_mae: 0.0094 - val_mse: 6.1123e-04 - 2s/epoch - 14ms/step
# Epoch 34/100
# 175/175 - 3s - loss: 2.9628e-04 - mae: 0.0072 - mse: 2.9628e-04 - val_loss: 6.3171e-04 - val_mae: 0.0079 - val_mse: 6.3171e-04 - 3s/epoch - 19ms/step
# Epoch 35/100
# 175/175 - 4s - loss: 2.7858e-04 - mae: 0.0066 - mse: 2.7858e-04 - val_loss: 5.8220e-04 - val_mae: 0.0091 - val_mse: 5.8220e-04 - 4s/epoch - 22ms/step
# Epoch 36/100
# 175/175 - 3s - loss: 2.8291e-04 - mae: 0.0067 - mse: 2.8291e-04 - val_loss: 6.1822e-04 - val_mae: 0.0099 - val_mse: 6.1822e-04 - 3s/epoch - 17ms/step
# Epoch 37/100
# 175/175 - 2s - loss: 2.7544e-04 - mae: 0.0067 - mse: 2.7544e-04 - val_loss: 6.6118e-04 - val_mae: 0.0082 - val_mse: 6.6118e-04 - 2s/epoch - 14ms/step
# Epoch 38/100
# 175/175 - 3s - loss: 2.6820e-04 - mae: 0.0065 - mse: 2.6820e-04 - val_loss: 6.2806e-04 - val_mae: 0.0100 - val_mse: 6.2806e-04 - 3s/epoch - 17ms/step
# Epoch 39/100
# 175/175 - 4s - loss: 2.8947e-04 - mae: 0.0069 - mse: 2.8947e-04 - val_loss: 7.8861e-04 - val_mae: 0.0112 - val_mse: 7.8861e-04 - 4s/epoch - 23ms/step
# Epoch 40/100
# 175/175 - 3s - loss: 2.8240e-04 - mae: 0.0067 - mse: 2.8240e-04 - val_loss: 6.1669e-04 - val_mae: 0.0086 - val_mse: 6.1669e-04 - 3s/epoch - 16ms/step
# Epoch 41/100
# 175/175 - 3s - loss: 2.6385e-04 - mae: 0.0066 - mse: 2.6385e-04 - val_loss: 7.1470e-04 - val_mae: 0.0083 - val_mse: 7.1470e-04 - 3s/epoch - 17ms/step
# Epoch 42/100
# 175/175 - 3s - loss: 2.8078e-04 - mae: 0.0068 - mse: 2.8078e-04 - val_loss: 6.0662e-04 - val_mae: 0.0078 - val_mse: 6.0662e-04 - 3s/epoch - 17ms/step
# Epoch 43/100
# 175/175 - 4s - loss: 2.6351e-04 - mae: 0.0065 - mse: 2.6351e-04 - val_loss: 6.6308e-04 - val_mae: 0.0086 - val_mse: 6.6308e-04 - 4s/epoch - 23ms/step
# Epoch 44/100
# 175/175 - 3s - loss: 2.8150e-04 - mae: 0.0069 - mse: 2.8150e-04 - val_loss: 6.5159e-04 - val_mae: 0.0084 - val_mse: 6.5159e-04 - 3s/epoch - 15ms/step
# Epoch 45/100
# 175/175 - 3s - loss: 2.6885e-04 - mae: 0.0067 - mse: 2.6885e-04 - val_loss: 6.3283e-04 - val_mae: 0.0086 - val_mse: 6.3283e-04 - 3s/epoch - 14ms/step
# Epoch 46/100
# 175/175 - 3s - loss: 2.6187e-04 - mae: 0.0065 - mse: 2.6187e-04 - val_loss: 6.5373e-04 - val_mae: 0.0108 - val_mse: 6.5373e-04 - 3s/epoch - 15ms/step
# Epoch 47/100
# 175/175 - 4s - loss: 2.5427e-04 - mae: 0.0065 - mse: 2.5427e-04 - val_loss: 5.8543e-04 - val_mae: 0.0088 - val_mse: 5.8543e-04 - 4s/epoch - 21ms/step
# Epoch 48/100
# 175/175 - 3s - loss: 2.3772e-04 - mae: 0.0061 - mse: 2.3772e-04 - val_loss: 5.8353e-04 - val_mae: 0.0090 - val_mse: 5.8353e-04 - 3s/epoch - 18ms/step
# Epoch 49/100
# 175/175 - 3s - loss: 2.5507e-04 - mae: 0.0064 - mse: 2.5507e-04 - val_loss: 6.3124e-04 - val_mae: 0.0078 - val_mse: 6.3124e-04 - 3s/epoch - 18ms/step
# Epoch 50/100
# 175/175 - 3s - loss: 2.5889e-04 - mae: 0.0063 - mse: 2.5889e-04 - val_loss: 5.7241e-04 - val_mae: 0.0081 - val_mse: 5.7241e-04 - 3s/epoch - 15ms/step
# Epoch 51/100
# 175/175 - 4s - loss: 2.4664e-04 - mae: 0.0065 - mse: 2.4664e-04 - val_loss: 6.2158e-04 - val_mae: 0.0093 - val_mse: 6.2158e-04 - 4s/epoch - 23ms/step
# Epoch 52/100
# 175/175 - 3s - loss: 2.3674e-04 - mae: 0.0063 - mse: 2.3674e-04 - val_loss: 6.4289e-04 - val_mae: 0.0102 - val_mse: 6.4289e-04 - 3s/epoch - 18ms/step
# Epoch 53/100
# 175/175 - 3s - loss: 2.6310e-04 - mae: 0.0066 - mse: 2.6310e-04 - val_loss: 6.8518e-04 - val_mae: 0.0084 - val_mse: 6.8518e-04 - 3s/epoch - 18ms/step
# Epoch 54/100
# 175/175 - 3s - loss: 2.7127e-04 - mae: 0.0066 - mse: 2.7127e-04 - val_loss: 5.7269e-04 - val_mae: 0.0090 - val_mse: 5.7269e-04 - 3s/epoch - 18ms/step
# Epoch 55/100
# 175/175 - 4s - loss: 2.4800e-04 - mae: 0.0064 - mse: 2.4800e-04 - val_loss: 5.9543e-04 - val_mae: 0.0087 - val_mse: 5.9543e-04 - 4s/epoch - 23ms/step
# Epoch 56/100
# 175/175 - 3s - loss: 2.3834e-04 - mae: 0.0061 - mse: 2.3834e-04 - val_loss: 6.0452e-04 - val_mae: 0.0072 - val_mse: 6.0452e-04 - 3s/epoch - 19ms/step
# Epoch 57/100
# 175/175 - 3s - loss: 2.3806e-04 - mae: 0.0063 - mse: 2.3806e-04 - val_loss: 5.4853e-04 - val_mae: 0.0073 - val_mse: 5.4853e-04 - 3s/epoch - 16ms/step
# Epoch 58/100
# 175/175 - 3s - loss: 2.3260e-04 - mae: 0.0060 - mse: 2.3260e-04 - val_loss: 5.5450e-04 - val_mae: 0.0106 - val_mse: 5.5450e-04 - 3s/epoch - 18ms/step
# Epoch 59/100
# 175/175 - 3s - loss: 2.3596e-04 - mae: 0.0062 - mse: 2.3596e-04 - val_loss: 6.4251e-04 - val_mae: 0.0081 - val_mse: 6.4251e-04 - 3s/epoch - 20ms/step
# Epoch 60/100
# 175/175 - 3s - loss: 2.2989e-04 - mae: 0.0059 - mse: 2.2989e-04 - val_loss: 6.3208e-04 - val_mae: 0.0078 - val_mse: 6.3208e-04 - 3s/epoch - 17ms/step
# Epoch 61/100
# 175/175 - 3s - loss: 2.2890e-04 - mae: 0.0062 - mse: 2.2890e-04 - val_loss: 6.3555e-04 - val_mae: 0.0076 - val_mse: 6.3555e-04 - 3s/epoch - 15ms/step
# Epoch 62/100
# 175/175 - 3s - loss: 2.6425e-04 - mae: 0.0066 - mse: 2.6425e-04 - val_loss: 7.2156e-04 - val_mae: 0.0085 - val_mse: 7.2156e-04 - 3s/epoch - 16ms/step
# Epoch 63/100
# 175/175 - 4s - loss: 2.3151e-04 - mae: 0.0060 - mse: 2.3151e-04 - val_loss: 6.2243e-04 - val_mae: 0.0085 - val_mse: 6.2243e-04 - 4s/epoch - 22ms/step
# Epoch 64/100
# 175/175 - 3s - loss: 2.2074e-04 - mae: 0.0059 - mse: 2.2074e-04 - val_loss: 5.8493e-04 - val_mae: 0.0081 - val_mse: 5.8493e-04 - 3s/epoch - 17ms/step
# Epoch 65/100
# 175/175 - 3s - loss: 2.1996e-04 - mae: 0.0058 - mse: 2.1996e-04 - val_loss: 6.6704e-04 - val_mae: 0.0082 - val_mse: 6.6704e-04 - 3s/epoch - 16ms/step
# Epoch 66/100
# 175/175 - 3s - loss: 2.4453e-04 - mae: 0.0064 - mse: 2.4453e-04 - val_loss: 6.0718e-04 - val_mae: 0.0081 - val_mse: 6.0718e-04 - 3s/epoch - 15ms/step
# Epoch 67/100
# 175/175 - 4s - loss: 2.3162e-04 - mae: 0.0062 - mse: 2.3162e-04 - val_loss: 5.9667e-04 - val_mae: 0.0082 - val_mse: 5.9667e-04 - 4s/epoch - 23ms/step
# Epoch 68/100
# 175/175 - 3s - loss: 2.6898e-04 - mae: 0.0069 - mse: 2.6898e-04 - val_loss: 6.4254e-04 - val_mae: 0.0082 - val_mse: 6.4254e-04 - 3s/epoch - 18ms/step
# Epoch 69/100
# 175/175 - 3s - loss: 2.4054e-04 - mae: 0.0060 - mse: 2.4054e-04 - val_loss: 5.4934e-04 - val_mae: 0.0083 - val_mse: 5.4934e-04 - 3s/epoch - 17ms/step
# Epoch 70/100
# 175/175 - 3s - loss: 2.2759e-04 - mae: 0.0059 - mse: 2.2759e-04 - val_loss: 6.1982e-04 - val_mae: 0.0089 - val_mse: 6.1982e-04 - 3s/epoch - 17ms/step
# Epoch 71/100
# 175/175 - 4s - loss: 2.3057e-04 - mae: 0.0061 - mse: 2.3057e-04 - val_loss: 6.6900e-04 - val_mae: 0.0086 - val_mse: 6.6900e-04 - 4s/epoch - 21ms/step
# Epoch 72/100
# 175/175 - 3s - loss: 2.3065e-04 - mae: 0.0059 - mse: 2.3065e-04 - val_loss: 5.7951e-04 - val_mae: 0.0078 - val_mse: 5.7951e-04 - 3s/epoch - 15ms/step
# Epoch 73/100
# 175/175 - 3s - loss: 2.3414e-04 - mae: 0.0061 - mse: 2.3414e-04 - val_loss: 5.8046e-04 - val_mae: 0.0073 - val_mse: 5.8046e-04 - 3s/epoch - 17ms/step
# Epoch 74/100
# 175/175 - 3s - loss: 2.3775e-04 - mae: 0.0065 - mse: 2.3775e-04 - val_loss: 6.1204e-04 - val_mae: 0.0085 - val_mse: 6.1204e-04 - 3s/epoch - 16ms/step
# Epoch 75/100
# 175/175 - 4s - loss: 2.3367e-04 - mae: 0.0059 - mse: 2.3367e-04 - val_loss: 6.1916e-04 - val_mae: 0.0081 - val_mse: 6.1916e-04 - 4s/epoch - 22ms/step
# Epoch 76/100
# 175/175 - 2s - loss: 2.3181e-04 - mae: 0.0061 - mse: 2.3181e-04 - val_loss: 6.2698e-04 - val_mae: 0.0078 - val_mse: 6.2698e-04 - 2s/epoch - 14ms/step
# Epoch 77/100
# 175/175 - 2s - loss: 2.1418e-04 - mae: 0.0056 - mse: 2.1418e-04 - val_loss: 6.1112e-04 - val_mae: 0.0076 - val_mse: 6.1112e-04 - 2s/epoch - 14ms/step
# Epoch 78/100
# 175/175 - 3s - loss: 2.4109e-04 - mae: 0.0062 - mse: 2.4109e-04 - val_loss: 6.0551e-04 - val_mae: 0.0071 - val_mse: 6.0551e-04 - 3s/epoch - 15ms/step
# Epoch 79/100
# 175/175 - 4s - loss: 2.1636e-04 - mae: 0.0058 - mse: 2.1636e-04 - val_loss: 5.7789e-04 - val_mae: 0.0093 - val_mse: 5.7789e-04 - 4s/epoch - 22ms/step
# Epoch 80/100
# 175/175 - 3s - loss: 2.2725e-04 - mae: 0.0063 - mse: 2.2725e-04 - val_loss: 7.0882e-04 - val_mae: 0.0092 - val_mse: 7.0882e-04 - 3s/epoch - 18ms/step
# Epoch 81/100
# 175/175 - 3s - loss: 2.2119e-04 - mae: 0.0058 - mse: 2.2119e-04 - val_loss: 6.0570e-04 - val_mae: 0.0071 - val_mse: 6.0570e-04 - 3s/epoch - 16ms/step
# Epoch 82/100
# 175/175 - 3s - loss: 2.1753e-04 - mae: 0.0058 - mse: 2.1753e-04 - val_loss: 5.1393e-04 - val_mae: 0.0079 - val_mse: 5.1393e-04 - 3s/epoch - 17ms/step
# Epoch 83/100
# 175/175 - 3s - loss: 2.0805e-04 - mae: 0.0055 - mse: 2.0805e-04 - val_loss: 5.6788e-04 - val_mae: 0.0078 - val_mse: 5.6788e-04 - 3s/epoch - 19ms/step
# Epoch 84/100
# 175/175 - 3s - loss: 2.2484e-04 - mae: 0.0060 - mse: 2.2484e-04 - val_loss: 5.7489e-04 - val_mae: 0.0072 - val_mse: 5.7489e-04 - 3s/epoch - 17ms/step
# Epoch 85/100
# 175/175 - 3s - loss: 2.1259e-04 - mae: 0.0058 - mse: 2.1259e-04 - val_loss: 6.7818e-04 - val_mae: 0.0085 - val_mse: 6.7818e-04 - 3s/epoch - 18ms/step
# Epoch 86/100
# 175/175 - 2s - loss: 2.1321e-04 - mae: 0.0058 - mse: 2.1321e-04 - val_loss: 5.9698e-04 - val_mae: 0.0080 - val_mse: 5.9698e-04 - 2s/epoch - 13ms/step
# Epoch 87/100
# 175/175 - 4s - loss: 2.1825e-04 - mae: 0.0058 - mse: 2.1825e-04 - val_loss: 6.1327e-04 - val_mae: 0.0080 - val_mse: 6.1327e-04 - 4s/epoch - 20ms/step
# Epoch 88/100
# 175/175 - 3s - loss: 2.3515e-04 - mae: 0.0061 - mse: 2.3515e-04 - val_loss: 5.4311e-04 - val_mae: 0.0076 - val_mse: 5.4311e-04 - 3s/epoch - 16ms/step
# Epoch 89/100
# 175/175 - 3s - loss: 2.2419e-04 - mae: 0.0061 - mse: 2.2419e-04 - val_loss: 6.6568e-04 - val_mae: 0.0078 - val_mse: 6.6568e-04 - 3s/epoch - 16ms/step
# Epoch 90/100
# 175/175 - 3s - loss: 2.2889e-04 - mae: 0.0058 - mse: 2.2889e-04 - val_loss: 5.8688e-04 - val_mae: 0.0085 - val_mse: 5.8688e-04 - 3s/epoch - 16ms/step
# Epoch 91/100
# 175/175 - 3s - loss: 2.1495e-04 - mae: 0.0058 - mse: 2.1495e-04 - val_loss: 6.5860e-04 - val_mae: 0.0087 - val_mse: 6.5860e-04 - 3s/epoch - 18ms/step
# Epoch 92/100
# 175/175 - 4s - loss: 2.3896e-04 - mae: 0.0062 - mse: 2.3896e-04 - val_loss: 5.8166e-04 - val_mae: 0.0076 - val_mse: 5.8166e-04 - 4s/epoch - 22ms/step
# Epoch 93/100
# 175/175 - 3s - loss: 2.0949e-04 - mae: 0.0056 - mse: 2.0949e-04 - val_loss: 5.2909e-04 - val_mae: 0.0073 - val_mse: 5.2909e-04 - 3s/epoch - 16ms/step
# Epoch 94/100
# 175/175 - 3s - loss: 2.2339e-04 - mae: 0.0057 - mse: 2.2339e-04 - val_loss: 5.1705e-04 - val_mae: 0.0073 - val_mse: 5.1705e-04 - 3s/epoch - 15ms/step
# Epoch 95/100
# 175/175 - 3s - loss: 2.0419e-04 - mae: 0.0055 - mse: 2.0419e-04 - val_loss: 5.6329e-04 - val_mae: 0.0080 - val_mse: 5.6329e-04 - 3s/epoch - 15ms/step
# Epoch 96/100
# 175/175 - 4s - loss: 2.0360e-04 - mae: 0.0056 - mse: 2.0360e-04 - val_loss: 5.6914e-04 - val_mae: 0.0085 - val_mse: 5.6914e-04 - 4s/epoch - 23ms/step
# Epoch 97/100
# 175/175 - 3s - loss: 2.1507e-04 - mae: 0.0058 - mse: 2.1507e-04 - val_loss: 8.1529e-04 - val_mae: 0.0113 - val_mse: 8.1529e-04 - 3s/epoch - 17ms/step
# Epoch 98/100
# 175/175 - 3s - loss: 2.2374e-04 - mae: 0.0061 - mse: 2.2374e-04 - val_loss: 5.9476e-04 - val_mae: 0.0092 - val_mse: 5.9476e-04 - 3s/epoch - 15ms/step
# Epoch 99/100
# 175/175 - 2s - loss: 2.0780e-04 - mae: 0.0056 - mse: 2.0780e-04 - val_loss: 5.5310e-04 - val_mae: 0.0073 - val_mse: 5.5310e-04 - 2s/epoch - 14ms/step
# Epoch 100/100
# 175/175 - 4s - loss: 2.2722e-04 - mae: 0.0059 - mse: 2.2722e-04 - val_loss: 6.0222e-04 - val_mae: 0.0088 - val_mse: 6.0222e-04 - 4s/epoch - 22ms/step

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.007066819351166487
# Minimum Validation MAE at epoch 77
# Minimum Validation loss 0.00020360035705380142
# Minimum Validation loss at epoch 81

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 175/175 [==============================] - 2s 4ms/step
# 94/94 [==============================] - 0s 3ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.29 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.49 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.12873554044425692
# Mean Absolute Error on test data: 0.17502867382068066

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.08266758716366662
# Mean Squared Error (MSE) of test: 0.2408862272389414

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         0      1376314846          2                     5851.998636
# 1         1      1376315146          2                     5851.998636
# 2         2      1376315446          2                     5851.998636
# 3         3      1376315746          2                     5851.998636
# 4         4      1376316046          2                     5851.998636
# ...     ...             ...        ...                             ...
# 8627   8627      1378905598          2                     5851.998944
# 8628   8628      1378905898          2                     5851.998944
# 8629   8629      1378906198          2                     5851.998944
# 8630   8630      1378906498          2                     5851.998944
# 8631   8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 13 columns]

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[30:530],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+30:6198+30],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
