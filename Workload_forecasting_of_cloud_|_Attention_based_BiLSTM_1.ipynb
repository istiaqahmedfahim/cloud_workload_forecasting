# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/Workload_forecasting_of_cloud_%7C_Attention_based_BiLSTM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'cloud-computing-history-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4018029%2F6990719%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240205%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240205T135728Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading cloud-computing-history-data, 143815 bytes compressed
# [==================================================] 143815 bytes downloaded
# Downloaded and uncompressed: cloud-computing-history-data
# Data source import complete.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv("/kaggle/input/cloud-computing-history-data/43.csv")
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(None, seq_size)))
model.add(LSTM(units=50))
model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
model2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64,kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, seq_size]),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.GRU(64,activation="relu"),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(15, activation="relu"),
  tf.keras.layers.Dense(1,'linear')
])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model3 = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64,kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, seq_size]),
  tf.keras.layers.Bidirectional(LSTM(64, activation='relu',return_sequences=True)),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.GRU(64,activation="relu", return_sequences=True),
  tf.keras.layers.LSTM(50,activation="relu"),
  tf.keras.layers.Dense(1,'linear')
])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Attention

class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W_q = self.add_weight(name="W_q", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.W_k = self.add_weight(name="W_k", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
        self.V = self.add_weight(name="V", shape=(input_shape[-1], 1), initializer="uniform", trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        q = tf.matmul(x, self.W_q)
        k = tf.matmul(x, self.W_k)
        scores = tf.matmul(tf.nn.tanh(q + k), self.V)
        attention_weights = tf.nn.softmax(scores, axis=-2)
        context_vector = attention_weights * x
        return context_vector

    def compute_output_shape(self, input_shape):
        return input_shape

seq_size = 30  # Replace with your sequence size

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, seq_size]),
    tf.keras.layers.Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
    tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
    tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
    tf.keras.layers.GRU(64, activation="relu", return_sequences=True),
    AttentionLayer(),  # Add Attention Layer
    tf.keras.layers.Bidirectional(LSTM(50, activation="relu")),  # Return sequences here
    tf.keras.layers.Dense(1, 'linear')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 64)          9664
#
#  bidirectional (Bidirectiona  (None, None, 128)        66048
#  l)
#
#  lstm_1 (LSTM)               (None, None, 64)          49408
#
#  lstm_2 (LSTM)               (None, None, 64)          33024
#
#  gru (GRU)                   (None, None, 64)          24960
#
#  attention_layer (AttentionL  (None, None, 64)         8256
#  ayer)
#
#  bidirectional_1 (Bidirectio  (None, 100)              46000
#  nal)
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 237,461
# Trainable params: 237,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae','mse'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the ModelCheckpoint callback
checkpoint_path = "best_model.h5"
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_mae', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# # Model Fitting

# %%
history = model.fit(trainX, trainY, validation_data=(testX, testY),batch_size=64,
          verbose=2, epochs=150,callbacks=[checkpoint])
# Out:
# Epoch 1/150
#
# Epoch 1: val_mae improved from inf to 0.03408, saving model to best_model.h5
# 88/88 - 23s - loss: 0.0025 - mae: 0.0337 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0341 - val_mse: 0.0030 - 23s/epoch - 265ms/step
# Epoch 2/150
#
# Epoch 2: val_mae improved from 0.03408 to 0.03384, saving model to best_model.h5
# 88/88 - 2s - loss: 0.0025 - mae: 0.0338 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0338 - val_mse: 0.0030 - 2s/epoch - 19ms/step
# Epoch 3/150
#
# Epoch 3: val_mae improved from 0.03384 to 0.03369, saving model to best_model.h5
# 88/88 - 2s - loss: 0.0025 - mae: 0.0339 - mse: 0.0025 - val_loss: 0.0029 - val_mae: 0.0337 - val_mse: 0.0029 - 2s/epoch - 19ms/step
# Epoch 4/150
#
# Epoch 4: val_mae improved from 0.03369 to 0.01372, saving model to best_model.h5
# 88/88 - 2s - loss: 0.0014 - mae: 0.0208 - mse: 0.0014 - val_loss: 9.6323e-04 - val_mae: 0.0137 - val_mse: 9.6323e-04 - 2s/epoch - 22ms/step
# Epoch 5/150
#
# Epoch 5: val_mae improved from 0.01372 to 0.01119, saving model to best_model.h5
# 88/88 - 2s - loss: 7.2634e-04 - mae: 0.0121 - mse: 7.2634e-04 - val_loss: 9.6195e-04 - val_mae: 0.0112 - val_mse: 9.6195e-04 - 2s/epoch - 28ms/step
# Epoch 6/150
#
# Epoch 6: val_mae improved from 0.01119 to 0.01108, saving model to best_model.h5
# 88/88 - 2s - loss: 6.9517e-04 - mae: 0.0117 - mse: 6.9517e-04 - val_loss: 9.1030e-04 - val_mae: 0.0111 - val_mse: 9.1030e-04 - 2s/epoch - 19ms/step
# Epoch 7/150
#
# Epoch 7: val_mae did not improve from 0.01108
# 88/88 - 2s - loss: 6.7595e-04 - mae: 0.0116 - mse: 6.7595e-04 - val_loss: 8.3944e-04 - val_mae: 0.0122 - val_mse: 8.3944e-04 - 2s/epoch - 19ms/step
# Epoch 8/150
#
# Epoch 8: val_mae did not improve from 0.01108
# 88/88 - 2s - loss: 6.2989e-04 - mae: 0.0111 - mse: 6.2989e-04 - val_loss: 8.1068e-04 - val_mae: 0.0116 - val_mse: 8.1068e-04 - 2s/epoch - 19ms/step
# Epoch 9/150
#
# Epoch 9: val_mae improved from 0.01108 to 0.00930, saving model to best_model.h5
# 88/88 - 2s - loss: 6.1397e-04 - mae: 0.0108 - mse: 6.1397e-04 - val_loss: 8.4448e-04 - val_mae: 0.0093 - val_mse: 8.4448e-04 - 2s/epoch - 20ms/step
# Epoch 10/150
#
# Epoch 10: val_mae did not improve from 0.00930
# 88/88 - 2s - loss: 5.6968e-04 - mae: 0.0102 - mse: 5.6968e-04 - val_loss: 8.4700e-04 - val_mae: 0.0098 - val_mse: 8.4700e-04 - 2s/epoch - 19ms/step
# Epoch 11/150
#
# Epoch 11: val_mae did not improve from 0.00930
# 88/88 - 2s - loss: 5.5685e-04 - mae: 0.0102 - mse: 5.5685e-04 - val_loss: 8.3749e-04 - val_mae: 0.0102 - val_mse: 8.3749e-04 - 2s/epoch - 27ms/step
# Epoch 12/150
#
# Epoch 12: val_mae did not improve from 0.00930
# 88/88 - 2s - loss: 5.1136e-04 - mae: 0.0098 - mse: 5.1136e-04 - val_loss: 8.4550e-04 - val_mae: 0.0107 - val_mse: 8.4550e-04 - 2s/epoch - 22ms/step
# Epoch 13/150
#
# Epoch 13: val_mae did not improve from 0.00930
# 88/88 - 2s - loss: 5.1271e-04 - mae: 0.0098 - mse: 5.1271e-04 - val_loss: 7.8984e-04 - val_mae: 0.0096 - val_mse: 7.8984e-04 - 2s/epoch - 17ms/step
# Epoch 14/150
#
# Epoch 14: val_mae improved from 0.00930 to 0.00900, saving model to best_model.h5
# 88/88 - 2s - loss: 5.0498e-04 - mae: 0.0096 - mse: 5.0498e-04 - val_loss: 8.3132e-04 - val_mae: 0.0090 - val_mse: 8.3132e-04 - 2s/epoch - 19ms/step
# Epoch 15/150
#
# Epoch 15: val_mae did not improve from 0.00900
# 88/88 - 2s - loss: 4.7259e-04 - mae: 0.0089 - mse: 4.7259e-04 - val_loss: 7.9517e-04 - val_mae: 0.0091 - val_mse: 7.9517e-04 - 2s/epoch - 17ms/step
# Epoch 16/150
#
# Epoch 16: val_mae improved from 0.00900 to 0.00898, saving model to best_model.h5
# 88/88 - 2s - loss: 4.4401e-04 - mae: 0.0088 - mse: 4.4401e-04 - val_loss: 7.8451e-04 - val_mae: 0.0090 - val_mse: 7.8451e-04 - 2s/epoch - 19ms/step
# Epoch 17/150
#
# Epoch 17: val_mae did not improve from 0.00898
# 88/88 - 1s - loss: 4.6923e-04 - mae: 0.0089 - mse: 4.6923e-04 - val_loss: 7.6335e-04 - val_mae: 0.0121 - val_mse: 7.6335e-04 - 1s/epoch - 17ms/step
# Epoch 18/150
#
# Epoch 18: val_mae did not improve from 0.00898
# 88/88 - 2s - loss: 4.5279e-04 - mae: 0.0091 - mse: 4.5279e-04 - val_loss: 7.6199e-04 - val_mae: 0.0103 - val_mse: 7.6199e-04 - 2s/epoch - 25ms/step
# Epoch 19/150
#
# Epoch 19: val_mae did not improve from 0.00898
# 88/88 - 2s - loss: 4.1727e-04 - mae: 0.0082 - mse: 4.1727e-04 - val_loss: 7.3162e-04 - val_mae: 0.0104 - val_mse: 7.3162e-04 - 2s/epoch - 22ms/step
# Epoch 20/150
#
# Epoch 20: val_mae did not improve from 0.00898
# 88/88 - 1s - loss: 4.0528e-04 - mae: 0.0080 - mse: 4.0528e-04 - val_loss: 7.1218e-04 - val_mae: 0.0105 - val_mse: 7.1218e-04 - 1s/epoch - 17ms/step
# Epoch 21/150
#
# Epoch 21: val_mae did not improve from 0.00898
# 88/88 - 2s - loss: 4.2110e-04 - mae: 0.0085 - mse: 4.2110e-04 - val_loss: 7.5510e-04 - val_mae: 0.0090 - val_mse: 7.5510e-04 - 2s/epoch - 17ms/step
# Epoch 22/150
#
# Epoch 22: val_mae did not improve from 0.00898
# 88/88 - 2s - loss: 4.0033e-04 - mae: 0.0082 - mse: 4.0033e-04 - val_loss: 7.3499e-04 - val_mae: 0.0097 - val_mse: 7.3499e-04 - 2s/epoch - 18ms/step
# Epoch 23/150
#
# Epoch 23: val_mae did not improve from 0.00898
# 88/88 - 1s - loss: 4.0511e-04 - mae: 0.0082 - mse: 4.0511e-04 - val_loss: 9.2016e-04 - val_mae: 0.0138 - val_mse: 9.2016e-04 - 1s/epoch - 17ms/step
# Epoch 24/150
#
# Epoch 24: val_mae did not improve from 0.00898
# 88/88 - 1s - loss: 3.8831e-04 - mae: 0.0081 - mse: 3.8831e-04 - val_loss: 8.3474e-04 - val_mae: 0.0118 - val_mse: 8.3474e-04 - 1s/epoch - 17ms/step
# Epoch 25/150
#
# Epoch 25: val_mae did not improve from 0.00898
# 88/88 - 1s - loss: 3.9258e-04 - mae: 0.0082 - mse: 3.9258e-04 - val_loss: 8.1602e-04 - val_mae: 0.0123 - val_mse: 8.1602e-04 - 1s/epoch - 17ms/step
# Epoch 26/150
#
# Epoch 26: val_mae improved from 0.00898 to 0.00871, saving model to best_model.h5
# 88/88 - 3s - loss: 3.6619e-04 - mae: 0.0079 - mse: 3.6619e-04 - val_loss: 6.8815e-04 - val_mae: 0.0087 - val_mse: 6.8815e-04 - 3s/epoch - 30ms/step
# Epoch 27/150
#
# Epoch 27: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.7260e-04 - mae: 0.0080 - mse: 3.7260e-04 - val_loss: 7.5601e-04 - val_mae: 0.0095 - val_mse: 7.5601e-04 - 2s/epoch - 18ms/step
# Epoch 28/150
#
# Epoch 28: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.5406e-04 - mae: 0.0075 - mse: 3.5406e-04 - val_loss: 6.8342e-04 - val_mae: 0.0089 - val_mse: 6.8342e-04 - 2s/epoch - 18ms/step
# Epoch 29/150
#
# Epoch 29: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.5140e-04 - mae: 0.0075 - mse: 3.5140e-04 - val_loss: 6.5223e-04 - val_mae: 0.0090 - val_mse: 6.5223e-04 - 2s/epoch - 18ms/step
# Epoch 30/150
#
# Epoch 30: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.4059e-04 - mae: 0.0074 - mse: 3.4059e-04 - val_loss: 6.6431e-04 - val_mae: 0.0090 - val_mse: 6.6431e-04 - 2s/epoch - 17ms/step
# Epoch 31/150
#
# Epoch 31: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.4066e-04 - mae: 0.0075 - mse: 3.4066e-04 - val_loss: 6.3501e-04 - val_mae: 0.0094 - val_mse: 6.3501e-04 - 2s/epoch - 18ms/step
# Epoch 32/150
#
# Epoch 32: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.4169e-04 - mae: 0.0075 - mse: 3.4169e-04 - val_loss: 6.3029e-04 - val_mae: 0.0115 - val_mse: 6.3029e-04 - 2s/epoch - 18ms/step
# Epoch 33/150
#
# Epoch 33: val_mae did not improve from 0.00871
# 88/88 - 3s - loss: 3.2876e-04 - mae: 0.0074 - mse: 3.2876e-04 - val_loss: 6.5834e-04 - val_mae: 0.0088 - val_mse: 6.5834e-04 - 3s/epoch - 30ms/step
# Epoch 34/150
#
# Epoch 34: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.0900e-04 - mae: 0.0071 - mse: 3.0900e-04 - val_loss: 7.6962e-04 - val_mae: 0.0091 - val_mse: 7.6962e-04 - 2s/epoch - 19ms/step
# Epoch 35/150
#
# Epoch 35: val_mae did not improve from 0.00871
# 88/88 - 2s - loss: 3.1660e-04 - mae: 0.0071 - mse: 3.1660e-04 - val_loss: 6.5422e-04 - val_mae: 0.0105 - val_mse: 6.5422e-04 - 2s/epoch - 18ms/step
# Epoch 36/150
#
# Epoch 36: val_mae improved from 0.00871 to 0.00808, saving model to best_model.h5
# 88/88 - 2s - loss: 3.2561e-04 - mae: 0.0075 - mse: 3.2561e-04 - val_loss: 6.6785e-04 - val_mae: 0.0081 - val_mse: 6.6785e-04 - 2s/epoch - 19ms/step
# Epoch 37/150
#
# Epoch 37: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 2.9270e-04 - mae: 0.0068 - mse: 2.9270e-04 - val_loss: 6.3694e-04 - val_mae: 0.0084 - val_mse: 6.3694e-04 - 2s/epoch - 18ms/step
# Epoch 38/150
#
# Epoch 38: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 3.0936e-04 - mae: 0.0071 - mse: 3.0936e-04 - val_loss: 6.9027e-04 - val_mae: 0.0090 - val_mse: 6.9027e-04 - 2s/epoch - 17ms/step
# Epoch 39/150
#
# Epoch 39: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 3.0371e-04 - mae: 0.0070 - mse: 3.0371e-04 - val_loss: 5.8505e-04 - val_mae: 0.0094 - val_mse: 5.8505e-04 - 2s/epoch - 17ms/step
# Epoch 40/150
#
# Epoch 40: val_mae did not improve from 0.00808
# 88/88 - 3s - loss: 2.9138e-04 - mae: 0.0069 - mse: 2.9138e-04 - val_loss: 7.4364e-04 - val_mae: 0.0086 - val_mse: 7.4364e-04 - 3s/epoch - 29ms/step
# Epoch 41/150
#
# Epoch 41: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 2.9173e-04 - mae: 0.0068 - mse: 2.9173e-04 - val_loss: 7.7365e-04 - val_mae: 0.0093 - val_mse: 7.7365e-04 - 2s/epoch - 18ms/step
# Epoch 42/150
#
# Epoch 42: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 2.9487e-04 - mae: 0.0070 - mse: 2.9487e-04 - val_loss: 6.5336e-04 - val_mae: 0.0098 - val_mse: 6.5336e-04 - 2s/epoch - 18ms/step
# Epoch 43/150
#
# Epoch 43: val_mae did not improve from 0.00808
# 88/88 - 1s - loss: 2.8943e-04 - mae: 0.0068 - mse: 2.8943e-04 - val_loss: 6.7807e-04 - val_mae: 0.0089 - val_mse: 6.7807e-04 - 1s/epoch - 17ms/step
# Epoch 44/150
#
# Epoch 44: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 2.7140e-04 - mae: 0.0065 - mse: 2.7140e-04 - val_loss: 6.7177e-04 - val_mae: 0.0082 - val_mse: 6.7177e-04 - 2s/epoch - 18ms/step
# Epoch 45/150
#
# Epoch 45: val_mae did not improve from 0.00808
# 88/88 - 2s - loss: 2.6460e-04 - mae: 0.0063 - mse: 2.6460e-04 - val_loss: 5.8828e-04 - val_mae: 0.0094 - val_mse: 5.8828e-04 - 2s/epoch - 18ms/step
# Epoch 46/150
#
# Epoch 46: val_mae improved from 0.00808 to 0.00781, saving model to best_model.h5
# 88/88 - 2s - loss: 2.7825e-04 - mae: 0.0069 - mse: 2.7825e-04 - val_loss: 6.2363e-04 - val_mae: 0.0078 - val_mse: 6.2363e-04 - 2s/epoch - 19ms/step
# Epoch 47/150
#
# Epoch 47: val_mae improved from 0.00781 to 0.00770, saving model to best_model.h5
# 88/88 - 2s - loss: 2.6554e-04 - mae: 0.0067 - mse: 2.6554e-04 - val_loss: 6.4390e-04 - val_mae: 0.0077 - val_mse: 6.4390e-04 - 2s/epoch - 26ms/step
# Epoch 48/150
#
# Epoch 48: val_mae did not improve from 0.00770
# 88/88 - 2s - loss: 2.8104e-04 - mae: 0.0068 - mse: 2.8104e-04 - val_loss: 6.2587e-04 - val_mae: 0.0088 - val_mse: 6.2587e-04 - 2s/epoch - 22ms/step
# Epoch 49/150
#
# Epoch 49: val_mae did not improve from 0.00770
# 88/88 - 1s - loss: 2.6046e-04 - mae: 0.0065 - mse: 2.6046e-04 - val_loss: 5.8555e-04 - val_mae: 0.0084 - val_mse: 5.8555e-04 - 1s/epoch - 17ms/step
# Epoch 50/150
#
# Epoch 50: val_mae did not improve from 0.00770
# 88/88 - 2s - loss: 2.5860e-04 - mae: 0.0066 - mse: 2.5860e-04 - val_loss: 6.7235e-04 - val_mae: 0.0081 - val_mse: 6.7235e-04 - 2s/epoch - 18ms/step
# Epoch 51/150
#
# Epoch 51: val_mae improved from 0.00770 to 0.00727, saving model to best_model.h5
# 88/88 - 2s - loss: 2.5732e-04 - mae: 0.0064 - mse: 2.5732e-04 - val_loss: 6.1196e-04 - val_mae: 0.0073 - val_mse: 6.1196e-04 - 2s/epoch - 18ms/step
# Epoch 52/150
#
# Epoch 52: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.4808e-04 - mae: 0.0063 - mse: 2.4808e-04 - val_loss: 5.8668e-04 - val_mae: 0.0076 - val_mse: 5.8668e-04 - 2s/epoch - 17ms/step
# Epoch 53/150
#
# Epoch 53: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.4792e-04 - mae: 0.0062 - mse: 2.4792e-04 - val_loss: 6.0240e-04 - val_mae: 0.0096 - val_mse: 6.0240e-04 - 2s/epoch - 24ms/step
# Epoch 54/150
#
# Epoch 54: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.9188e-04 - mae: 0.0072 - mse: 2.9188e-04 - val_loss: 6.4012e-04 - val_mae: 0.0090 - val_mse: 6.4012e-04 - 2s/epoch - 27ms/step
# Epoch 55/150
#
# Epoch 55: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.5890e-04 - mae: 0.0064 - mse: 2.5890e-04 - val_loss: 6.5513e-04 - val_mae: 0.0084 - val_mse: 6.5513e-04 - 2s/epoch - 19ms/step
# Epoch 56/150
#
# Epoch 56: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.6566e-04 - mae: 0.0067 - mse: 2.6566e-04 - val_loss: 6.5406e-04 - val_mae: 0.0078 - val_mse: 6.5406e-04 - 2s/epoch - 18ms/step
# Epoch 57/150
#
# Epoch 57: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.4515e-04 - mae: 0.0063 - mse: 2.4515e-04 - val_loss: 6.0126e-04 - val_mae: 0.0095 - val_mse: 6.0126e-04 - 2s/epoch - 17ms/step
# Epoch 58/150
#
# Epoch 58: val_mae did not improve from 0.00727
# 88/88 - 1s - loss: 2.4020e-04 - mae: 0.0063 - mse: 2.4020e-04 - val_loss: 7.1815e-04 - val_mae: 0.0098 - val_mse: 7.1815e-04 - 1s/epoch - 17ms/step
# Epoch 59/150
#
# Epoch 59: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.6092e-04 - mae: 0.0064 - mse: 2.6092e-04 - val_loss: 6.2478e-04 - val_mae: 0.0083 - val_mse: 6.2478e-04 - 2s/epoch - 18ms/step
# Epoch 60/150
#
# Epoch 60: val_mae did not improve from 0.00727
# 88/88 - 1s - loss: 2.3208e-04 - mae: 0.0062 - mse: 2.3208e-04 - val_loss: 6.2109e-04 - val_mae: 0.0078 - val_mse: 6.2109e-04 - 1s/epoch - 17ms/step
# Epoch 61/150
#
# Epoch 61: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.3828e-04 - mae: 0.0061 - mse: 2.3828e-04 - val_loss: 7.3571e-04 - val_mae: 0.0090 - val_mse: 7.3571e-04 - 2s/epoch - 23ms/step
# Epoch 62/150
#
# Epoch 62: val_mae did not improve from 0.00727
# 88/88 - 2s - loss: 2.4635e-04 - mae: 0.0064 - mse: 2.4635e-04 - val_loss: 7.3772e-04 - val_mae: 0.0096 - val_mse: 7.3772e-04 - 2s/epoch - 23ms/step
# Epoch 63/150
#
# Epoch 63: val_mae did not improve from 0.00727
# 88/88 - 1s - loss: 2.4468e-04 - mae: 0.0064 - mse: 2.4468e-04 - val_loss: 6.5777e-04 - val_mae: 0.0080 - val_mse: 6.5777e-04 - 1s/epoch - 17ms/step
# Epoch 64/150
#
# Epoch 64: val_mae improved from 0.00727 to 0.00685, saving model to best_model.h5
# 88/88 - 2s - loss: 2.4360e-04 - mae: 0.0063 - mse: 2.4360e-04 - val_loss: 5.5677e-04 - val_mae: 0.0068 - val_mse: 5.5677e-04 - 2s/epoch - 20ms/step
# Epoch 65/150
#
# Epoch 65: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3674e-04 - mae: 0.0062 - mse: 2.3674e-04 - val_loss: 5.9085e-04 - val_mae: 0.0075 - val_mse: 5.9085e-04 - 2s/epoch - 18ms/step
# Epoch 66/150
#
# Epoch 66: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.4658e-04 - mae: 0.0062 - mse: 2.4658e-04 - val_loss: 6.4360e-04 - val_mae: 0.0089 - val_mse: 6.4360e-04 - 1s/epoch - 17ms/step
# Epoch 67/150
#
# Epoch 67: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3820e-04 - mae: 0.0062 - mse: 2.3820e-04 - val_loss: 5.5308e-04 - val_mae: 0.0071 - val_mse: 5.5308e-04 - 2s/epoch - 18ms/step
# Epoch 68/150
#
# Epoch 68: val_mae did not improve from 0.00685
# 88/88 - 4s - loss: 2.3865e-04 - mae: 0.0061 - mse: 2.3865e-04 - val_loss: 6.2457e-04 - val_mae: 0.0081 - val_mse: 6.2457e-04 - 4s/epoch - 41ms/step
# Epoch 69/150
#
# Epoch 69: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1868e-04 - mae: 0.0059 - mse: 2.1868e-04 - val_loss: 6.2795e-04 - val_mae: 0.0072 - val_mse: 6.2795e-04 - 2s/epoch - 17ms/step
# Epoch 70/150
#
# Epoch 70: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2812e-04 - mae: 0.0060 - mse: 2.2812e-04 - val_loss: 6.2721e-04 - val_mae: 0.0079 - val_mse: 6.2721e-04 - 2s/epoch - 18ms/step
# Epoch 71/150
#
# Epoch 71: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.4316e-04 - mae: 0.0062 - mse: 2.4316e-04 - val_loss: 7.0938e-04 - val_mae: 0.0084 - val_mse: 7.0938e-04 - 1s/epoch - 17ms/step
# Epoch 72/150
#
# Epoch 72: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.3923e-04 - mae: 0.0060 - mse: 2.3923e-04 - val_loss: 5.6034e-04 - val_mae: 0.0072 - val_mse: 5.6034e-04 - 1s/epoch - 17ms/step
# Epoch 73/150
#
# Epoch 73: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3348e-04 - mae: 0.0062 - mse: 2.3348e-04 - val_loss: 7.5594e-04 - val_mae: 0.0090 - val_mse: 7.5594e-04 - 2s/epoch - 18ms/step
# Epoch 74/150
#
# Epoch 74: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.2050e-04 - mae: 0.0057 - mse: 2.2050e-04 - val_loss: 5.9544e-04 - val_mae: 0.0084 - val_mse: 5.9544e-04 - 1s/epoch - 17ms/step
# Epoch 75/150
#
# Epoch 75: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2868e-04 - mae: 0.0060 - mse: 2.2868e-04 - val_loss: 5.6195e-04 - val_mae: 0.0070 - val_mse: 5.6195e-04 - 2s/epoch - 26ms/step
# Epoch 76/150
#
# Epoch 76: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2083e-04 - mae: 0.0057 - mse: 2.2083e-04 - val_loss: 5.6899e-04 - val_mae: 0.0087 - val_mse: 5.6899e-04 - 2s/epoch - 21ms/step
# Epoch 77/150
#
# Epoch 77: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2336e-04 - mae: 0.0059 - mse: 2.2336e-04 - val_loss: 5.7505e-04 - val_mae: 0.0083 - val_mse: 5.7505e-04 - 2s/epoch - 17ms/step
# Epoch 78/150
#
# Epoch 78: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2809e-04 - mae: 0.0059 - mse: 2.2809e-04 - val_loss: 6.1774e-04 - val_mae: 0.0087 - val_mse: 6.1774e-04 - 2s/epoch - 17ms/step
# Epoch 79/150
#
# Epoch 79: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.1480e-04 - mae: 0.0058 - mse: 2.1480e-04 - val_loss: 6.5403e-04 - val_mae: 0.0087 - val_mse: 6.5403e-04 - 1s/epoch - 17ms/step
# Epoch 80/150
#
# Epoch 80: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3079e-04 - mae: 0.0061 - mse: 2.3079e-04 - val_loss: 7.4870e-04 - val_mae: 0.0087 - val_mse: 7.4870e-04 - 2s/epoch - 18ms/step
# Epoch 81/150
#
# Epoch 81: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2665e-04 - mae: 0.0059 - mse: 2.2665e-04 - val_loss: 7.1332e-04 - val_mae: 0.0088 - val_mse: 7.1332e-04 - 2s/epoch - 18ms/step
# Epoch 82/150
#
# Epoch 82: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2582e-04 - mae: 0.0058 - mse: 2.2582e-04 - val_loss: 5.3506e-04 - val_mae: 0.0074 - val_mse: 5.3506e-04 - 2s/epoch - 23ms/step
# Epoch 83/150
#
# Epoch 83: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2118e-04 - mae: 0.0059 - mse: 2.2118e-04 - val_loss: 6.1489e-04 - val_mae: 0.0084 - val_mse: 6.1489e-04 - 2s/epoch - 26ms/step
# Epoch 84/150
#
# Epoch 84: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0671e-04 - mae: 0.0057 - mse: 2.0671e-04 - val_loss: 6.3720e-04 - val_mae: 0.0086 - val_mse: 6.3720e-04 - 2s/epoch - 17ms/step
# Epoch 85/150
#
# Epoch 85: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2292e-04 - mae: 0.0057 - mse: 2.2292e-04 - val_loss: 6.3068e-04 - val_mae: 0.0085 - val_mse: 6.3068e-04 - 2s/epoch - 19ms/step
# Epoch 86/150
#
# Epoch 86: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3094e-04 - mae: 0.0059 - mse: 2.3094e-04 - val_loss: 5.5668e-04 - val_mae: 0.0079 - val_mse: 5.5668e-04 - 2s/epoch - 18ms/step
# Epoch 87/150
#
# Epoch 87: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.2047e-04 - mae: 0.0055 - mse: 2.2047e-04 - val_loss: 5.3959e-04 - val_mae: 0.0075 - val_mse: 5.3959e-04 - 1s/epoch - 17ms/step
# Epoch 88/150
#
# Epoch 88: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3161e-04 - mae: 0.0061 - mse: 2.3161e-04 - val_loss: 7.8488e-04 - val_mae: 0.0096 - val_mse: 7.8488e-04 - 2s/epoch - 18ms/step
# Epoch 89/150
#
# Epoch 89: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3566e-04 - mae: 0.0059 - mse: 2.3566e-04 - val_loss: 5.7630e-04 - val_mae: 0.0082 - val_mse: 5.7630e-04 - 2s/epoch - 18ms/step
# Epoch 90/150
#
# Epoch 90: val_mae did not improve from 0.00685
# 88/88 - 3s - loss: 2.2085e-04 - mae: 0.0061 - mse: 2.2085e-04 - val_loss: 7.3924e-04 - val_mae: 0.0092 - val_mse: 7.3924e-04 - 3s/epoch - 30ms/step
# Epoch 91/150
#
# Epoch 91: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2925e-04 - mae: 0.0060 - mse: 2.2925e-04 - val_loss: 6.1343e-04 - val_mae: 0.0069 - val_mse: 6.1343e-04 - 2s/epoch - 18ms/step
# Epoch 92/150
#
# Epoch 92: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1252e-04 - mae: 0.0058 - mse: 2.1252e-04 - val_loss: 7.0767e-04 - val_mae: 0.0088 - val_mse: 7.0767e-04 - 2s/epoch - 17ms/step
# Epoch 93/150
#
# Epoch 93: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0516e-04 - mae: 0.0055 - mse: 2.0516e-04 - val_loss: 6.7437e-04 - val_mae: 0.0079 - val_mse: 6.7437e-04 - 2s/epoch - 18ms/step
# Epoch 94/150
#
# Epoch 94: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.0921e-04 - mae: 0.0056 - mse: 2.0921e-04 - val_loss: 6.3020e-04 - val_mae: 0.0073 - val_mse: 6.3020e-04 - 1s/epoch - 17ms/step
# Epoch 95/150
#
# Epoch 95: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.0857e-04 - mae: 0.0057 - mse: 2.0857e-04 - val_loss: 6.1220e-04 - val_mae: 0.0100 - val_mse: 6.1220e-04 - 1s/epoch - 17ms/step
# Epoch 96/150
#
# Epoch 96: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.1923e-04 - mae: 0.0058 - mse: 2.1923e-04 - val_loss: 5.4621e-04 - val_mae: 0.0073 - val_mse: 5.4621e-04 - 1s/epoch - 17ms/step
# Epoch 97/150
#
# Epoch 97: val_mae did not improve from 0.00685
# 88/88 - 3s - loss: 2.2471e-04 - mae: 0.0060 - mse: 2.2471e-04 - val_loss: 6.1604e-04 - val_mae: 0.0071 - val_mse: 6.1604e-04 - 3s/epoch - 29ms/step
# Epoch 98/150
#
# Epoch 98: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0685e-04 - mae: 0.0057 - mse: 2.0685e-04 - val_loss: 6.6356e-04 - val_mae: 0.0085 - val_mse: 6.6356e-04 - 2s/epoch - 19ms/step
# Epoch 99/150
#
# Epoch 99: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1304e-04 - mae: 0.0058 - mse: 2.1304e-04 - val_loss: 6.0122e-04 - val_mae: 0.0073 - val_mse: 6.0122e-04 - 2s/epoch - 18ms/step
# Epoch 100/150
#
# Epoch 100: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0138e-04 - mae: 0.0054 - mse: 2.0138e-04 - val_loss: 5.9598e-04 - val_mae: 0.0085 - val_mse: 5.9598e-04 - 2s/epoch - 18ms/step
# Epoch 101/150
#
# Epoch 101: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0259e-04 - mae: 0.0055 - mse: 2.0259e-04 - val_loss: 5.9226e-04 - val_mae: 0.0088 - val_mse: 5.9226e-04 - 2s/epoch - 18ms/step
# Epoch 102/150
#
# Epoch 102: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 2.2270e-04 - mae: 0.0060 - mse: 2.2270e-04 - val_loss: 6.4388e-04 - val_mae: 0.0087 - val_mse: 6.4388e-04 - 1s/epoch - 17ms/step
# Epoch 103/150
#
# Epoch 103: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1115e-04 - mae: 0.0055 - mse: 2.1115e-04 - val_loss: 5.5911e-04 - val_mae: 0.0079 - val_mse: 5.5911e-04 - 2s/epoch - 17ms/step
# Epoch 104/150
#
# Epoch 104: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1176e-04 - mae: 0.0057 - mse: 2.1176e-04 - val_loss: 7.4925e-04 - val_mae: 0.0086 - val_mse: 7.4925e-04 - 2s/epoch - 23ms/step
# Epoch 105/150
#
# Epoch 105: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1288e-04 - mae: 0.0056 - mse: 2.1288e-04 - val_loss: 5.7573e-04 - val_mae: 0.0081 - val_mse: 5.7573e-04 - 2s/epoch - 23ms/step
# Epoch 106/150
#
# Epoch 106: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0735e-04 - mae: 0.0055 - mse: 2.0735e-04 - val_loss: 6.0613e-04 - val_mae: 0.0095 - val_mse: 6.0613e-04 - 2s/epoch - 18ms/step
# Epoch 107/150
#
# Epoch 107: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0383e-04 - mae: 0.0056 - mse: 2.0383e-04 - val_loss: 6.3468e-04 - val_mae: 0.0075 - val_mse: 6.3468e-04 - 2s/epoch - 18ms/step
# Epoch 108/150
#
# Epoch 108: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.3400e-04 - mae: 0.0061 - mse: 2.3400e-04 - val_loss: 6.2631e-04 - val_mae: 0.0076 - val_mse: 6.2631e-04 - 2s/epoch - 18ms/step
# Epoch 109/150
#
# Epoch 109: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 1.9462e-04 - mae: 0.0053 - mse: 1.9462e-04 - val_loss: 6.9985e-04 - val_mae: 0.0092 - val_mse: 6.9985e-04 - 2s/epoch - 17ms/step
# Epoch 110/150
#
# Epoch 110: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0819e-04 - mae: 0.0054 - mse: 2.0819e-04 - val_loss: 6.2744e-04 - val_mae: 0.0081 - val_mse: 6.2744e-04 - 2s/epoch - 18ms/step
# Epoch 111/150
#
# Epoch 111: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1630e-04 - mae: 0.0055 - mse: 2.1630e-04 - val_loss: 5.4017e-04 - val_mae: 0.0078 - val_mse: 5.4017e-04 - 2s/epoch - 18ms/step
# Epoch 112/150
#
# Epoch 112: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2034e-04 - mae: 0.0059 - mse: 2.2034e-04 - val_loss: 6.2801e-04 - val_mae: 0.0072 - val_mse: 6.2801e-04 - 2s/epoch - 28ms/step
# Epoch 113/150
#
# Epoch 113: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.2439e-04 - mae: 0.0056 - mse: 2.2439e-04 - val_loss: 6.6455e-04 - val_mae: 0.0078 - val_mse: 6.6455e-04 - 2s/epoch - 18ms/step
# Epoch 114/150
#
# Epoch 114: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0652e-04 - mae: 0.0056 - mse: 2.0652e-04 - val_loss: 6.5050e-04 - val_mae: 0.0082 - val_mse: 6.5050e-04 - 2s/epoch - 18ms/step
# Epoch 115/150
#
# Epoch 115: val_mae did not improve from 0.00685
# 88/88 - 1s - loss: 1.9741e-04 - mae: 0.0054 - mse: 1.9741e-04 - val_loss: 5.3741e-04 - val_mae: 0.0070 - val_mse: 5.3741e-04 - 1s/epoch - 17ms/step
# Epoch 116/150
#
# Epoch 116: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 1.9845e-04 - mae: 0.0053 - mse: 1.9845e-04 - val_loss: 6.2353e-04 - val_mae: 0.0072 - val_mse: 6.2353e-04 - 2s/epoch - 18ms/step
# Epoch 117/150
#
# Epoch 117: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0257e-04 - mae: 0.0055 - mse: 2.0257e-04 - val_loss: 6.0937e-04 - val_mae: 0.0073 - val_mse: 6.0937e-04 - 2s/epoch - 18ms/step
# Epoch 118/150
#
# Epoch 118: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 1.9799e-04 - mae: 0.0054 - mse: 1.9799e-04 - val_loss: 5.9752e-04 - val_mae: 0.0079 - val_mse: 5.9752e-04 - 2s/epoch - 18ms/step
# Epoch 119/150
#
# Epoch 119: val_mae did not improve from 0.00685
# 88/88 - 3s - loss: 1.9881e-04 - mae: 0.0052 - mse: 1.9881e-04 - val_loss: 5.8777e-04 - val_mae: 0.0073 - val_mse: 5.8777e-04 - 3s/epoch - 30ms/step
# Epoch 120/150
#
# Epoch 120: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.1602e-04 - mae: 0.0057 - mse: 2.1602e-04 - val_loss: 6.1232e-04 - val_mae: 0.0074 - val_mse: 6.1232e-04 - 2s/epoch - 17ms/step
# Epoch 121/150
#
# Epoch 121: val_mae did not improve from 0.00685
# 88/88 - 2s - loss: 2.0004e-04 - mae: 0.0055 - mse: 2.0004e-04 - val_loss: 5.6968e-04 - val_mae: 0.0071 - val_mse: 5.6968e-04 - 2s/epoch - 17ms/step
# Epoch 122/150
#
# Epoch 122: val_mae improved from 0.00685 to 0.00654, saving model to best_model.h5
# 88/88 - 2s - loss: 1.9811e-04 - mae: 0.0055 - mse: 1.9811e-04 - val_loss: 5.9836e-04 - val_mae: 0.0065 - val_mse: 5.9836e-04 - 2s/epoch - 18ms/step
# Epoch 123/150
#
# Epoch 123: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.0693e-04 - mae: 0.0054 - mse: 2.0693e-04 - val_loss: 5.9302e-04 - val_mae: 0.0079 - val_mse: 5.9302e-04 - 2s/epoch - 18ms/step
# Epoch 124/150
#
# Epoch 124: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.9388e-04 - mae: 0.0052 - mse: 1.9388e-04 - val_loss: 6.0964e-04 - val_mae: 0.0070 - val_mse: 6.0964e-04 - 2s/epoch - 18ms/step
# Epoch 125/150
#
# Epoch 125: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8577e-04 - mae: 0.0052 - mse: 1.8577e-04 - val_loss: 7.5984e-04 - val_mae: 0.0085 - val_mse: 7.5984e-04 - 2s/epoch - 18ms/step
# Epoch 126/150
#
# Epoch 126: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.0440e-04 - mae: 0.0055 - mse: 2.0440e-04 - val_loss: 7.4260e-04 - val_mae: 0.0094 - val_mse: 7.4260e-04 - 2s/epoch - 27ms/step
# Epoch 127/150
#
# Epoch 127: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.0930e-04 - mae: 0.0057 - mse: 2.0930e-04 - val_loss: 6.3489e-04 - val_mae: 0.0074 - val_mse: 6.3489e-04 - 2s/epoch - 19ms/step
# Epoch 128/150
#
# Epoch 128: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.0081e-04 - mae: 0.0052 - mse: 2.0081e-04 - val_loss: 6.2038e-04 - val_mae: 0.0081 - val_mse: 6.2038e-04 - 2s/epoch - 18ms/step
# Epoch 129/150
#
# Epoch 129: val_mae did not improve from 0.00654
# 88/88 - 1s - loss: 1.8936e-04 - mae: 0.0050 - mse: 1.8936e-04 - val_loss: 7.1234e-04 - val_mae: 0.0089 - val_mse: 7.1234e-04 - 1s/epoch - 17ms/step
# Epoch 130/150
#
# Epoch 130: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.1524e-04 - mae: 0.0058 - mse: 2.1524e-04 - val_loss: 6.1210e-04 - val_mae: 0.0090 - val_mse: 6.1210e-04 - 2s/epoch - 18ms/step
# Epoch 131/150
#
# Epoch 131: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.9523e-04 - mae: 0.0054 - mse: 1.9523e-04 - val_loss: 5.9806e-04 - val_mae: 0.0070 - val_mse: 5.9806e-04 - 2s/epoch - 17ms/step
# Epoch 132/150
#
# Epoch 132: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8467e-04 - mae: 0.0050 - mse: 1.8467e-04 - val_loss: 6.1413e-04 - val_mae: 0.0085 - val_mse: 6.1413e-04 - 2s/epoch - 17ms/step
# Epoch 133/150
#
# Epoch 133: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8754e-04 - mae: 0.0051 - mse: 1.8754e-04 - val_loss: 6.3979e-04 - val_mae: 0.0080 - val_mse: 6.3979e-04 - 2s/epoch - 24ms/step
# Epoch 134/150
#
# Epoch 134: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.0782e-04 - mae: 0.0056 - mse: 2.0782e-04 - val_loss: 6.5254e-04 - val_mae: 0.0079 - val_mse: 6.5254e-04 - 2s/epoch - 23ms/step
# Epoch 135/150
#
# Epoch 135: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8346e-04 - mae: 0.0051 - mse: 1.8346e-04 - val_loss: 5.9668e-04 - val_mae: 0.0076 - val_mse: 5.9668e-04 - 2s/epoch - 18ms/step
# Epoch 136/150
#
# Epoch 136: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.0472e-04 - mae: 0.0054 - mse: 2.0472e-04 - val_loss: 6.0914e-04 - val_mae: 0.0086 - val_mse: 6.0914e-04 - 2s/epoch - 18ms/step
# Epoch 137/150
#
# Epoch 137: val_mae did not improve from 0.00654
# 88/88 - 1s - loss: 1.8756e-04 - mae: 0.0050 - mse: 1.8756e-04 - val_loss: 6.2018e-04 - val_mae: 0.0085 - val_mse: 6.2018e-04 - 1s/epoch - 17ms/step
# Epoch 138/150
#
# Epoch 138: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8981e-04 - mae: 0.0052 - mse: 1.8981e-04 - val_loss: 6.3262e-04 - val_mae: 0.0071 - val_mse: 6.3262e-04 - 2s/epoch - 18ms/step
# Epoch 139/150
#
# Epoch 139: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 2.1145e-04 - mae: 0.0059 - mse: 2.1145e-04 - val_loss: 5.9385e-04 - val_mae: 0.0066 - val_mse: 5.9385e-04 - 2s/epoch - 18ms/step
# Epoch 140/150
#
# Epoch 140: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8863e-04 - mae: 0.0051 - mse: 1.8863e-04 - val_loss: 5.5801e-04 - val_mae: 0.0069 - val_mse: 5.5801e-04 - 2s/epoch - 24ms/step
# Epoch 141/150
#
# Epoch 141: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8774e-04 - mae: 0.0051 - mse: 1.8774e-04 - val_loss: 6.0565e-04 - val_mae: 0.0073 - val_mse: 6.0565e-04 - 2s/epoch - 24ms/step
# Epoch 142/150
#
# Epoch 142: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8392e-04 - mae: 0.0051 - mse: 1.8392e-04 - val_loss: 6.7503e-04 - val_mae: 0.0076 - val_mse: 6.7503e-04 - 2s/epoch - 18ms/step
# Epoch 143/150
#
# Epoch 143: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.9705e-04 - mae: 0.0053 - mse: 1.9705e-04 - val_loss: 6.2981e-04 - val_mae: 0.0073 - val_mse: 6.2981e-04 - 2s/epoch - 18ms/step
# Epoch 144/150
#
# Epoch 144: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.9980e-04 - mae: 0.0054 - mse: 1.9980e-04 - val_loss: 5.8411e-04 - val_mae: 0.0080 - val_mse: 5.8411e-04 - 2s/epoch - 18ms/step
# Epoch 145/150
#
# Epoch 145: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.9132e-04 - mae: 0.0054 - mse: 1.9132e-04 - val_loss: 6.0256e-04 - val_mae: 0.0069 - val_mse: 6.0256e-04 - 2s/epoch - 17ms/step
# Epoch 146/150
#
# Epoch 146: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8165e-04 - mae: 0.0050 - mse: 1.8165e-04 - val_loss: 6.6662e-04 - val_mae: 0.0071 - val_mse: 6.6662e-04 - 2s/epoch - 18ms/step
# Epoch 147/150
#
# Epoch 147: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8985e-04 - mae: 0.0053 - mse: 1.8985e-04 - val_loss: 6.2995e-04 - val_mae: 0.0076 - val_mse: 6.2995e-04 - 2s/epoch - 23ms/step
# Epoch 148/150
#
# Epoch 148: val_mae did not improve from 0.00654
# 88/88 - 2s - loss: 1.8259e-04 - mae: 0.0050 - mse: 1.8259e-04 - val_loss: 6.1190e-04 - val_mae: 0.0078 - val_mse: 6.1190e-04 - 2s/epoch - 24ms/step
# Epoch 149/150
#
# Epoch 149: val_mae improved from 0.00654 to 0.00654, saving model to best_model.h5
# 88/88 - 2s - loss: 1.8330e-04 - mae: 0.0051 - mse: 1.8330e-04 - val_loss: 5.7176e-04 - val_mae: 0.0065 - val_mse: 5.7176e-04 - 2s/epoch - 19ms/step
# Epoch 150/150
#
# Epoch 150: val_mae improved from 0.00654 to 0.00638, saving model to best_model.h5
# 88/88 - 2s - loss: 2.1259e-04 - mae: 0.0058 - mse: 2.1259e-04 - val_loss: 5.8598e-04 - val_mae: 0.0064 - val_mse: 5.8598e-04 - 2s/epoch - 19ms/step

# %%
# Load the best model
best_model = tf.keras.models.load_model(checkpoint_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d2940e522954> in <cell line: 2>()
#       1 # Load the best model
# ----> 2 best_model = tf.keras.models.load_model(checkpoint_path)
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     210
#     211     # Legacy case.
# --> 212     return legacy_sm_saving_lib.load_model(
#     213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/legacy/serialization.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     366     )
#     367     if cls is None:
# --> 368         raise ValueError(
#     369             f"Unknown {printable_module_name}: '{class_name}'. "
#     370             "Please ensure you are using a `keras.utils.custom_object_scope` "
#
# ValueError: Unknown layer: 'AttentionLayer'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.006375990808010101
# Minimum Validation MAE at epoch 149
# Minimum Validation loss 0.00018165224173571914
# Minimum Validation loss at epoch 81

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 175/175 [==============================] - 5s 8ms/step
# 94/94 [==============================] - 0s 4ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.29 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.48 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.08982112722249636
# Mean Absolute Error on test data: 0.12751979704652747

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.08477780038258985
# Mean Squared Error (MSE) of test: 0.23439037151664513

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         0      1376314846          2                     5851.998636
# 1         1      1376315146          2                     5851.998636
# 2         2      1376315446          2                     5851.998636
# 3         3      1376315746          2                     5851.998636
# 4         4      1376316046          2                     5851.998636
# ...     ...             ...        ...                             ...
# 8627   8627      1378905598          2                     5851.998944
# 8628   8628      1378905898          2                     5851.998944
# 8629   8629      1378906198          2                     5851.998944
# 8630   8630      1378906498          2                     5851.998944
# 8631   8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 13 columns]

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[30:530],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+30:6198+30],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
