# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/Workload_forecasting_of_cloud_%7C_BiLSTM%2BGRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'cloud-computing-history-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4018029%2F6990719%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240205%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240205T135728Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading cloud-computing-history-data, 143815 bytes compressed
# [==================================================] 143815 bytes downloaded
# Downloaded and uncompressed: cloud-computing-history-data
# Data source import complete.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv("/kaggle/input/cloud-computing-history-data/43.csv")
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(None, seq_size)))
model.add(LSTM(units=50))
model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
model2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64,kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, seq_size]),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.GRU(64,activation="relu"),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(15, activation="relu"),
  tf.keras.layers.Dense(1,'linear')
])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model3 = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64,kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, seq_size]),
  tf.keras.layers.Bidirectional(LSTM(64, activation='relu',return_sequences=True)),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
  tf.keras.layers.GRU(64,activation="relu", return_sequences=True),
  tf.keras.layers.LSTM(50,activation="relu"),
  tf.keras.layers.Dense(1,'linear')
])

# %%
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, None, 64)          9664
#
#  bidirectional_1 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  lstm_5 (LSTM)               (None, None, 64)          49408
#
#  lstm_6 (LSTM)               (None, None, 64)          33024
#
#  gru_1 (GRU)                 (None, None, 64)          24960
#
#  lstm_7 (LSTM)               (None, 50)                23000
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 206,155
# Trainable params: 206,155
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model3.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae','mse'])

# %% [markdown]
# # Model Fitting

# %%
history = model3.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=200)
# Out:
# Epoch 1/200
# 175/175 - 12s - loss: 0.0025 - mae: 0.0338 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0343 - val_mse: 0.0030 - 12s/epoch - 70ms/step
# Epoch 2/200
# 175/175 - 3s - loss: 0.0016 - mae: 0.0231 - mse: 0.0016 - val_loss: 9.7318e-04 - val_mae: 0.0149 - val_mse: 9.7318e-04 - 3s/epoch - 15ms/step
# Epoch 3/200
# 175/175 - 2s - loss: 7.6405e-04 - mae: 0.0127 - mse: 7.6405e-04 - val_loss: 9.1391e-04 - val_mae: 0.0121 - val_mse: 9.1391e-04 - 2s/epoch - 10ms/step
# Epoch 4/200
# 175/175 - 2s - loss: 6.8575e-04 - mae: 0.0116 - mse: 6.8575e-04 - val_loss: 8.9759e-04 - val_mae: 0.0116 - val_mse: 8.9759e-04 - 2s/epoch - 10ms/step
# Epoch 5/200
# 175/175 - 2s - loss: 6.6344e-04 - mae: 0.0114 - mse: 6.6344e-04 - val_loss: 8.6444e-04 - val_mae: 0.0135 - val_mse: 8.6444e-04 - 2s/epoch - 10ms/step
# Epoch 6/200
# 175/175 - 2s - loss: 6.4226e-04 - mae: 0.0112 - mse: 6.4226e-04 - val_loss: 8.4271e-04 - val_mae: 0.0139 - val_mse: 8.4271e-04 - 2s/epoch - 10ms/step
# Epoch 7/200
# 175/175 - 2s - loss: 6.0631e-04 - mae: 0.0107 - mse: 6.0631e-04 - val_loss: 8.0737e-04 - val_mae: 0.0118 - val_mse: 8.0737e-04 - 2s/epoch - 10ms/step
# Epoch 8/200
# 175/175 - 3s - loss: 5.6852e-04 - mae: 0.0105 - mse: 5.6852e-04 - val_loss: 7.9580e-04 - val_mae: 0.0110 - val_mse: 7.9580e-04 - 3s/epoch - 16ms/step
# Epoch 9/200
# 175/175 - 2s - loss: 5.4528e-04 - mae: 0.0104 - mse: 5.4528e-04 - val_loss: 8.1629e-04 - val_mae: 0.0093 - val_mse: 8.1629e-04 - 2s/epoch - 11ms/step
# Epoch 10/200
# 175/175 - 2s - loss: 5.1911e-04 - mae: 0.0099 - mse: 5.1911e-04 - val_loss: 7.7411e-04 - val_mae: 0.0109 - val_mse: 7.7411e-04 - 2s/epoch - 11ms/step
# Epoch 11/200
# 175/175 - 2s - loss: 4.9486e-04 - mae: 0.0096 - mse: 4.9486e-04 - val_loss: 8.2332e-04 - val_mae: 0.0091 - val_mse: 8.2332e-04 - 2s/epoch - 10ms/step
# Epoch 12/200
# 175/175 - 2s - loss: 4.8362e-04 - mae: 0.0095 - mse: 4.8362e-04 - val_loss: 7.9725e-04 - val_mae: 0.0097 - val_mse: 7.9725e-04 - 2s/epoch - 11ms/step
# Epoch 13/200
# 175/175 - 2s - loss: 4.7665e-04 - mae: 0.0092 - mse: 4.7665e-04 - val_loss: 7.7881e-04 - val_mae: 0.0104 - val_mse: 7.7881e-04 - 2s/epoch - 11ms/step
# Epoch 14/200
# 175/175 - 3s - loss: 4.5180e-04 - mae: 0.0088 - mse: 4.5180e-04 - val_loss: 8.4091e-04 - val_mae: 0.0103 - val_mse: 8.4091e-04 - 3s/epoch - 15ms/step
# Epoch 15/200
# 175/175 - 2s - loss: 4.4104e-04 - mae: 0.0087 - mse: 4.4104e-04 - val_loss: 7.8354e-04 - val_mae: 0.0099 - val_mse: 7.8354e-04 - 2s/epoch - 11ms/step
# Epoch 16/200
# 175/175 - 2s - loss: 4.1882e-04 - mae: 0.0084 - mse: 4.1882e-04 - val_loss: 7.7193e-04 - val_mae: 0.0112 - val_mse: 7.7193e-04 - 2s/epoch - 11ms/step
# Epoch 17/200
# 175/175 - 2s - loss: 4.1229e-04 - mae: 0.0083 - mse: 4.1229e-04 - val_loss: 0.0011 - val_mae: 0.0171 - val_mse: 0.0011 - 2s/epoch - 11ms/step
# Epoch 18/200
# 175/175 - 2s - loss: 4.4145e-04 - mae: 0.0089 - mse: 4.4145e-04 - val_loss: 8.2687e-04 - val_mae: 0.0121 - val_mse: 8.2687e-04 - 2s/epoch - 10ms/step
# Epoch 19/200
# 175/175 - 2s - loss: 3.8594e-04 - mae: 0.0082 - mse: 3.8594e-04 - val_loss: 7.3213e-04 - val_mae: 0.0114 - val_mse: 7.3213e-04 - 2s/epoch - 10ms/step
# Epoch 20/200
# 175/175 - 3s - loss: 3.7667e-04 - mae: 0.0080 - mse: 3.7667e-04 - val_loss: 8.4213e-04 - val_mae: 0.0136 - val_mse: 8.4213e-04 - 3s/epoch - 15ms/step
# Epoch 21/200
# 175/175 - 2s - loss: 3.5009e-04 - mae: 0.0076 - mse: 3.5009e-04 - val_loss: 7.3150e-04 - val_mae: 0.0087 - val_mse: 7.3150e-04 - 2s/epoch - 10ms/step
# Epoch 22/200
# 175/175 - 2s - loss: 3.3653e-04 - mae: 0.0075 - mse: 3.3653e-04 - val_loss: 7.7481e-04 - val_mae: 0.0088 - val_mse: 7.7481e-04 - 2s/epoch - 10ms/step
# Epoch 23/200
# 175/175 - 2s - loss: 3.4513e-04 - mae: 0.0077 - mse: 3.4513e-04 - val_loss: 7.2808e-04 - val_mae: 0.0104 - val_mse: 7.2808e-04 - 2s/epoch - 10ms/step
# Epoch 24/200
# 175/175 - 2s - loss: 3.1567e-04 - mae: 0.0071 - mse: 3.1567e-04 - val_loss: 8.0539e-04 - val_mae: 0.0099 - val_mse: 8.0539e-04 - 2s/epoch - 10ms/step
# Epoch 25/200
# 175/175 - 2s - loss: 3.3508e-04 - mae: 0.0075 - mse: 3.3508e-04 - val_loss: 7.8905e-04 - val_mae: 0.0110 - val_mse: 7.8905e-04 - 2s/epoch - 10ms/step
# Epoch 26/200
# 175/175 - 2s - loss: 3.3986e-04 - mae: 0.0076 - mse: 3.3986e-04 - val_loss: 8.3663e-04 - val_mae: 0.0117 - val_mse: 8.3663e-04 - 2s/epoch - 11ms/step
# Epoch 27/200
# 175/175 - 2s - loss: 3.6891e-04 - mae: 0.0079 - mse: 3.6891e-04 - val_loss: 7.8690e-04 - val_mae: 0.0090 - val_mse: 7.8690e-04 - 2s/epoch - 13ms/step
# Epoch 28/200
# 175/175 - 2s - loss: 3.1510e-04 - mae: 0.0071 - mse: 3.1510e-04 - val_loss: 7.5878e-04 - val_mae: 0.0102 - val_mse: 7.5878e-04 - 2s/epoch - 10ms/step
# Epoch 29/200
# 175/175 - 2s - loss: 3.0343e-04 - mae: 0.0071 - mse: 3.0343e-04 - val_loss: 7.1378e-04 - val_mae: 0.0086 - val_mse: 7.1378e-04 - 2s/epoch - 10ms/step
# Epoch 30/200
# 175/175 - 2s - loss: 2.9564e-04 - mae: 0.0068 - mse: 2.9564e-04 - val_loss: 8.2120e-04 - val_mae: 0.0101 - val_mse: 8.2120e-04 - 2s/epoch - 10ms/step
# Epoch 31/200
# 175/175 - 2s - loss: 3.0118e-04 - mae: 0.0072 - mse: 3.0118e-04 - val_loss: 6.8823e-04 - val_mae: 0.0089 - val_mse: 6.8823e-04 - 2s/epoch - 10ms/step
# Epoch 32/200
# 175/175 - 2s - loss: 2.9287e-04 - mae: 0.0070 - mse: 2.9287e-04 - val_loss: 7.8939e-04 - val_mae: 0.0095 - val_mse: 7.8939e-04 - 2s/epoch - 11ms/step
# Epoch 33/200
# 175/175 - 3s - loss: 2.8314e-04 - mae: 0.0068 - mse: 2.8314e-04 - val_loss: 7.9194e-04 - val_mae: 0.0087 - val_mse: 7.9194e-04 - 3s/epoch - 15ms/step
# Epoch 34/200
# 175/175 - 2s - loss: 2.8511e-04 - mae: 0.0070 - mse: 2.8511e-04 - val_loss: 8.5535e-04 - val_mae: 0.0091 - val_mse: 8.5535e-04 - 2s/epoch - 10ms/step
# Epoch 35/200
# 175/175 - 2s - loss: 2.7588e-04 - mae: 0.0067 - mse: 2.7588e-04 - val_loss: 8.2256e-04 - val_mae: 0.0098 - val_mse: 8.2256e-04 - 2s/epoch - 10ms/step
# Epoch 36/200
# 175/175 - 2s - loss: 2.7393e-04 - mae: 0.0069 - mse: 2.7393e-04 - val_loss: 9.5609e-04 - val_mae: 0.0103 - val_mse: 9.5609e-04 - 2s/epoch - 10ms/step
# Epoch 37/200
# 175/175 - 2s - loss: 2.7854e-04 - mae: 0.0070 - mse: 2.7854e-04 - val_loss: 9.3145e-04 - val_mae: 0.0099 - val_mse: 9.3145e-04 - 2s/epoch - 10ms/step
# Epoch 38/200
# 175/175 - 2s - loss: 2.6444e-04 - mae: 0.0067 - mse: 2.6444e-04 - val_loss: 7.7916e-04 - val_mae: 0.0092 - val_mse: 7.7916e-04 - 2s/epoch - 10ms/step
# Epoch 39/200
# 175/175 - 3s - loss: 2.5434e-04 - mae: 0.0064 - mse: 2.5434e-04 - val_loss: 7.7685e-04 - val_mae: 0.0084 - val_mse: 7.7685e-04 - 3s/epoch - 15ms/step
# Epoch 40/200
# 175/175 - 2s - loss: 2.7677e-04 - mae: 0.0068 - mse: 2.7677e-04 - val_loss: 8.7377e-04 - val_mae: 0.0111 - val_mse: 8.7377e-04 - 2s/epoch - 10ms/step
# Epoch 41/200
# 175/175 - 2s - loss: 2.6445e-04 - mae: 0.0068 - mse: 2.6445e-04 - val_loss: 8.5003e-04 - val_mae: 0.0085 - val_mse: 8.5003e-04 - 2s/epoch - 10ms/step
# Epoch 42/200
# 175/175 - 2s - loss: 2.7361e-04 - mae: 0.0068 - mse: 2.7361e-04 - val_loss: 0.0011 - val_mae: 0.0096 - val_mse: 0.0011 - 2s/epoch - 10ms/step
# Epoch 43/200
# 175/175 - 2s - loss: 2.7418e-04 - mae: 0.0067 - mse: 2.7418e-04 - val_loss: 9.2189e-04 - val_mae: 0.0087 - val_mse: 9.2189e-04 - 2s/epoch - 10ms/step
# Epoch 44/200
# 175/175 - 2s - loss: 2.5827e-04 - mae: 0.0066 - mse: 2.5827e-04 - val_loss: 9.0625e-04 - val_mae: 0.0130 - val_mse: 9.0625e-04 - 2s/epoch - 10ms/step
# Epoch 45/200
# 175/175 - 2s - loss: 2.8109e-04 - mae: 0.0070 - mse: 2.8109e-04 - val_loss: 8.2870e-04 - val_mae: 0.0087 - val_mse: 8.2870e-04 - 2s/epoch - 12ms/step
# Epoch 46/200
# 175/175 - 2s - loss: 2.8696e-04 - mae: 0.0070 - mse: 2.8696e-04 - val_loss: 7.3452e-04 - val_mae: 0.0084 - val_mse: 7.3452e-04 - 2s/epoch - 13ms/step
# Epoch 47/200
# 175/175 - 2s - loss: 3.0036e-04 - mae: 0.0070 - mse: 3.0036e-04 - val_loss: 8.4374e-04 - val_mae: 0.0083 - val_mse: 8.4374e-04 - 2s/epoch - 10ms/step
# Epoch 48/200
# 175/175 - 2s - loss: 2.5727e-04 - mae: 0.0065 - mse: 2.5727e-04 - val_loss: 0.0013 - val_mae: 0.0098 - val_mse: 0.0013 - 2s/epoch - 10ms/step
# Epoch 49/200
# 175/175 - 2s - loss: 2.7001e-04 - mae: 0.0066 - mse: 2.7001e-04 - val_loss: 7.9262e-04 - val_mae: 0.0116 - val_mse: 7.9262e-04 - 2s/epoch - 10ms/step
# Epoch 50/200
# 175/175 - 2s - loss: 2.8021e-04 - mae: 0.0066 - mse: 2.8021e-04 - val_loss: 8.1573e-04 - val_mae: 0.0086 - val_mse: 8.1573e-04 - 2s/epoch - 10ms/step
# Epoch 51/200
# 175/175 - 2s - loss: 2.4884e-04 - mae: 0.0063 - mse: 2.4884e-04 - val_loss: 8.8954e-04 - val_mae: 0.0091 - val_mse: 8.8954e-04 - 2s/epoch - 9ms/step
# Epoch 52/200
# 175/175 - 3s - loss: 2.3123e-04 - mae: 0.0061 - mse: 2.3123e-04 - val_loss: 7.9005e-04 - val_mae: 0.0082 - val_mse: 7.9005e-04 - 3s/epoch - 15ms/step
# Epoch 53/200
# 175/175 - 2s - loss: 2.5168e-04 - mae: 0.0064 - mse: 2.5168e-04 - val_loss: 9.3404e-04 - val_mae: 0.0091 - val_mse: 9.3404e-04 - 2s/epoch - 10ms/step
# Epoch 54/200
# 175/175 - 2s - loss: 2.2953e-04 - mae: 0.0060 - mse: 2.2953e-04 - val_loss: 0.0010 - val_mae: 0.0092 - val_mse: 0.0010 - 2s/epoch - 10ms/step
# Epoch 55/200
# 175/175 - 2s - loss: 2.3259e-04 - mae: 0.0061 - mse: 2.3259e-04 - val_loss: 9.7373e-04 - val_mae: 0.0081 - val_mse: 9.7373e-04 - 2s/epoch - 10ms/step
# Epoch 56/200
# 175/175 - 2s - loss: 2.3387e-04 - mae: 0.0060 - mse: 2.3387e-04 - val_loss: 0.0014 - val_mae: 0.0096 - val_mse: 0.0014 - 2s/epoch - 10ms/step
# Epoch 57/200
# 175/175 - 2s - loss: 2.7051e-04 - mae: 0.0068 - mse: 2.7051e-04 - val_loss: 7.1642e-04 - val_mae: 0.0096 - val_mse: 7.1642e-04 - 2s/epoch - 10ms/step
# Epoch 58/200
# 175/175 - 2s - loss: 2.4002e-04 - mae: 0.0063 - mse: 2.4002e-04 - val_loss: 8.6006e-04 - val_mae: 0.0083 - val_mse: 8.6006e-04 - 2s/epoch - 13ms/step
# Epoch 59/200
# 175/175 - 2s - loss: 2.5400e-04 - mae: 0.0064 - mse: 2.5400e-04 - val_loss: 6.6811e-04 - val_mae: 0.0095 - val_mse: 6.6811e-04 - 2s/epoch - 12ms/step
# Epoch 60/200
# 175/175 - 2s - loss: 2.3931e-04 - mae: 0.0064 - mse: 2.3931e-04 - val_loss: 0.0010 - val_mae: 0.0084 - val_mse: 0.0010 - 2s/epoch - 10ms/step
# Epoch 61/200
# 175/175 - 2s - loss: 2.3025e-04 - mae: 0.0061 - mse: 2.3025e-04 - val_loss: 8.9681e-04 - val_mae: 0.0089 - val_mse: 8.9681e-04 - 2s/epoch - 10ms/step
# Epoch 62/200
# 175/175 - 2s - loss: 2.3664e-04 - mae: 0.0064 - mse: 2.3664e-04 - val_loss: 7.9964e-04 - val_mae: 0.0086 - val_mse: 7.9964e-04 - 2s/epoch - 10ms/step
# Epoch 63/200
# 175/175 - 2s - loss: 2.5324e-04 - mae: 0.0065 - mse: 2.5324e-04 - val_loss: 8.6236e-04 - val_mae: 0.0085 - val_mse: 8.6236e-04 - 2s/epoch - 10ms/step
# Epoch 64/200
# 175/175 - 2s - loss: 2.2836e-04 - mae: 0.0059 - mse: 2.2836e-04 - val_loss: 8.0283e-04 - val_mae: 0.0089 - val_mse: 8.0283e-04 - 2s/epoch - 10ms/step
# Epoch 65/200
# 175/175 - 2s - loss: 2.3123e-04 - mae: 0.0061 - mse: 2.3123e-04 - val_loss: 9.0731e-04 - val_mae: 0.0080 - val_mse: 9.0731e-04 - 2s/epoch - 14ms/step
# Epoch 66/200
# 175/175 - 2s - loss: 2.2848e-04 - mae: 0.0060 - mse: 2.2848e-04 - val_loss: 7.9574e-04 - val_mae: 0.0087 - val_mse: 7.9574e-04 - 2s/epoch - 10ms/step
# Epoch 67/200
# 175/175 - 2s - loss: 2.2035e-04 - mae: 0.0059 - mse: 2.2035e-04 - val_loss: 9.0993e-04 - val_mae: 0.0090 - val_mse: 9.0993e-04 - 2s/epoch - 10ms/step
# Epoch 68/200
# 175/175 - 2s - loss: 2.1901e-04 - mae: 0.0058 - mse: 2.1901e-04 - val_loss: 8.4252e-04 - val_mae: 0.0085 - val_mse: 8.4252e-04 - 2s/epoch - 10ms/step
# Epoch 69/200
# 175/175 - 2s - loss: 2.4150e-04 - mae: 0.0061 - mse: 2.4150e-04 - val_loss: 6.7426e-04 - val_mae: 0.0076 - val_mse: 6.7426e-04 - 2s/epoch - 10ms/step
# Epoch 70/200
# 175/175 - 2s - loss: 2.6070e-04 - mae: 0.0065 - mse: 2.6070e-04 - val_loss: 9.6680e-04 - val_mae: 0.0093 - val_mse: 9.6680e-04 - 2s/epoch - 10ms/step
# Epoch 71/200
# 175/175 - 3s - loss: 2.2937e-04 - mae: 0.0059 - mse: 2.2937e-04 - val_loss: 8.6273e-04 - val_mae: 0.0091 - val_mse: 8.6273e-04 - 3s/epoch - 15ms/step
# Epoch 72/200
# 175/175 - 2s - loss: 2.3692e-04 - mae: 0.0062 - mse: 2.3692e-04 - val_loss: 7.5326e-04 - val_mae: 0.0096 - val_mse: 7.5326e-04 - 2s/epoch - 11ms/step
# Epoch 73/200
# 175/175 - 2s - loss: 2.6654e-04 - mae: 0.0066 - mse: 2.6654e-04 - val_loss: 7.2044e-04 - val_mae: 0.0096 - val_mse: 7.2044e-04 - 2s/epoch - 11ms/step
# Epoch 74/200
# 175/175 - 2s - loss: 2.2598e-04 - mae: 0.0063 - mse: 2.2598e-04 - val_loss: 8.1596e-04 - val_mae: 0.0082 - val_mse: 8.1596e-04 - 2s/epoch - 10ms/step
# Epoch 75/200
# 175/175 - 2s - loss: 2.1696e-04 - mae: 0.0058 - mse: 2.1696e-04 - val_loss: 6.2548e-04 - val_mae: 0.0073 - val_mse: 6.2548e-04 - 2s/epoch - 10ms/step
# Epoch 76/200
# 175/175 - 2s - loss: 2.3678e-04 - mae: 0.0063 - mse: 2.3678e-04 - val_loss: 7.3713e-04 - val_mae: 0.0080 - val_mse: 7.3713e-04 - 2s/epoch - 10ms/step
# Epoch 77/200
# 175/175 - 2s - loss: 2.1758e-04 - mae: 0.0058 - mse: 2.1758e-04 - val_loss: 7.1338e-04 - val_mae: 0.0099 - val_mse: 7.1338e-04 - 2s/epoch - 12ms/step
# Epoch 78/200
# 175/175 - 2s - loss: 2.1669e-04 - mae: 0.0059 - mse: 2.1669e-04 - val_loss: 8.8907e-04 - val_mae: 0.0104 - val_mse: 8.8907e-04 - 2s/epoch - 13ms/step
# Epoch 79/200
# 175/175 - 2s - loss: 2.1159e-04 - mae: 0.0057 - mse: 2.1159e-04 - val_loss: 8.2945e-04 - val_mae: 0.0100 - val_mse: 8.2945e-04 - 2s/epoch - 10ms/step
# Epoch 80/200
# 175/175 - 2s - loss: 2.1960e-04 - mae: 0.0061 - mse: 2.1960e-04 - val_loss: 7.4444e-04 - val_mae: 0.0086 - val_mse: 7.4444e-04 - 2s/epoch - 10ms/step
# Epoch 81/200
# 175/175 - 2s - loss: 2.3260e-04 - mae: 0.0060 - mse: 2.3260e-04 - val_loss: 7.0206e-04 - val_mae: 0.0074 - val_mse: 7.0206e-04 - 2s/epoch - 10ms/step
# Epoch 82/200
# 175/175 - 2s - loss: 2.2724e-04 - mae: 0.0059 - mse: 2.2724e-04 - val_loss: 0.0011 - val_mae: 0.0095 - val_mse: 0.0011 - 2s/epoch - 10ms/step
# Epoch 83/200
# 175/175 - 2s - loss: 2.2947e-04 - mae: 0.0061 - mse: 2.2947e-04 - val_loss: 7.0568e-04 - val_mae: 0.0098 - val_mse: 7.0568e-04 - 2s/epoch - 10ms/step
# Epoch 84/200
# 175/175 - 3s - loss: 2.1658e-04 - mae: 0.0059 - mse: 2.1658e-04 - val_loss: 7.5573e-04 - val_mae: 0.0085 - val_mse: 7.5573e-04 - 3s/epoch - 15ms/step
# Epoch 85/200
# 175/175 - 2s - loss: 2.1262e-04 - mae: 0.0056 - mse: 2.1262e-04 - val_loss: 9.2759e-04 - val_mae: 0.0081 - val_mse: 9.2759e-04 - 2s/epoch - 10ms/step
# Epoch 86/200
# 175/175 - 2s - loss: 2.3184e-04 - mae: 0.0064 - mse: 2.3184e-04 - val_loss: 8.3186e-04 - val_mae: 0.0090 - val_mse: 8.3186e-04 - 2s/epoch - 10ms/step
# Epoch 87/200
# 175/175 - 2s - loss: 2.1269e-04 - mae: 0.0058 - mse: 2.1269e-04 - val_loss: 6.8368e-04 - val_mae: 0.0078 - val_mse: 6.8368e-04 - 2s/epoch - 10ms/step
# Epoch 88/200
# 175/175 - 2s - loss: 2.0666e-04 - mae: 0.0055 - mse: 2.0666e-04 - val_loss: 7.7807e-04 - val_mae: 0.0078 - val_mse: 7.7807e-04 - 2s/epoch - 10ms/step
# Epoch 89/200
# 175/175 - 2s - loss: 2.2435e-04 - mae: 0.0061 - mse: 2.2435e-04 - val_loss: 7.4754e-04 - val_mae: 0.0079 - val_mse: 7.4754e-04 - 2s/epoch - 10ms/step
# Epoch 90/200
# 175/175 - 3s - loss: 2.4658e-04 - mae: 0.0066 - mse: 2.4658e-04 - val_loss: 7.0829e-04 - val_mae: 0.0071 - val_mse: 7.0829e-04 - 3s/epoch - 15ms/step
# Epoch 91/200
# 175/175 - 2s - loss: 2.1680e-04 - mae: 0.0057 - mse: 2.1680e-04 - val_loss: 9.8913e-04 - val_mae: 0.0099 - val_mse: 9.8913e-04 - 2s/epoch - 10ms/step
# Epoch 92/200
# 175/175 - 2s - loss: 2.1065e-04 - mae: 0.0057 - mse: 2.1065e-04 - val_loss: 7.5111e-04 - val_mae: 0.0072 - val_mse: 7.5111e-04 - 2s/epoch - 10ms/step
# Epoch 93/200
# 175/175 - 2s - loss: 2.0693e-04 - mae: 0.0053 - mse: 2.0693e-04 - val_loss: 7.6569e-04 - val_mae: 0.0087 - val_mse: 7.6569e-04 - 2s/epoch - 10ms/step
# Epoch 94/200
# 175/175 - 2s - loss: 2.1448e-04 - mae: 0.0060 - mse: 2.1448e-04 - val_loss: 7.9406e-04 - val_mae: 0.0077 - val_mse: 7.9406e-04 - 2s/epoch - 10ms/step
# Epoch 95/200
# 175/175 - 2s - loss: 2.1610e-04 - mae: 0.0059 - mse: 2.1610e-04 - val_loss: 7.1222e-04 - val_mae: 0.0077 - val_mse: 7.1222e-04 - 2s/epoch - 10ms/step
# Epoch 96/200
# 175/175 - 2s - loss: 2.1132e-04 - mae: 0.0055 - mse: 2.1132e-04 - val_loss: 0.0012 - val_mae: 0.0080 - val_mse: 0.0012 - 2s/epoch - 14ms/step
# Epoch 97/200
# 175/175 - 2s - loss: 2.1807e-04 - mae: 0.0055 - mse: 2.1807e-04 - val_loss: 6.7385e-04 - val_mae: 0.0068 - val_mse: 6.7385e-04 - 2s/epoch - 12ms/step
# Epoch 98/200
# 175/175 - 2s - loss: 2.0501e-04 - mae: 0.0056 - mse: 2.0501e-04 - val_loss: 8.6756e-04 - val_mae: 0.0082 - val_mse: 8.6756e-04 - 2s/epoch - 10ms/step
# Epoch 99/200
# 175/175 - 2s - loss: 2.2169e-04 - mae: 0.0059 - mse: 2.2169e-04 - val_loss: 8.1705e-04 - val_mae: 0.0082 - val_mse: 8.1705e-04 - 2s/epoch - 10ms/step
# Epoch 100/200
# 175/175 - 2s - loss: 2.1395e-04 - mae: 0.0057 - mse: 2.1395e-04 - val_loss: 7.0206e-04 - val_mae: 0.0084 - val_mse: 7.0206e-04 - 2s/epoch - 10ms/step
# Epoch 101/200
# 175/175 - 2s - loss: 2.1882e-04 - mae: 0.0060 - mse: 2.1882e-04 - val_loss: 9.9999e-04 - val_mae: 0.0079 - val_mse: 9.9999e-04 - 2s/epoch - 10ms/step
# Epoch 102/200
# 175/175 - 2s - loss: 2.2379e-04 - mae: 0.0058 - mse: 2.2379e-04 - val_loss: 0.0010 - val_mae: 0.0084 - val_mse: 0.0010 - 2s/epoch - 10ms/step
# Epoch 103/200
# 175/175 - 3s - loss: 2.2202e-04 - mae: 0.0059 - mse: 2.2202e-04 - val_loss: 6.3029e-04 - val_mae: 0.0068 - val_mse: 6.3029e-04 - 3s/epoch - 15ms/step
# Epoch 104/200
# 175/175 - 2s - loss: 2.1080e-04 - mae: 0.0056 - mse: 2.1080e-04 - val_loss: 6.9142e-04 - val_mae: 0.0083 - val_mse: 6.9142e-04 - 2s/epoch - 10ms/step
# Epoch 105/200
# 175/175 - 2s - loss: 2.0437e-04 - mae: 0.0054 - mse: 2.0437e-04 - val_loss: 8.3513e-04 - val_mae: 0.0082 - val_mse: 8.3513e-04 - 2s/epoch - 10ms/step
# Epoch 106/200
# 175/175 - 2s - loss: 2.2594e-04 - mae: 0.0061 - mse: 2.2594e-04 - val_loss: 7.9784e-04 - val_mae: 0.0085 - val_mse: 7.9784e-04 - 2s/epoch - 10ms/step
# Epoch 107/200
# 175/175 - 2s - loss: 2.2332e-04 - mae: 0.0060 - mse: 2.2332e-04 - val_loss: 7.1972e-04 - val_mae: 0.0091 - val_mse: 7.1972e-04 - 2s/epoch - 10ms/step
# Epoch 108/200
# 175/175 - 2s - loss: 2.3195e-04 - mae: 0.0058 - mse: 2.3195e-04 - val_loss: 8.5994e-04 - val_mae: 0.0089 - val_mse: 8.5994e-04 - 2s/epoch - 10ms/step
# Epoch 109/200
# 175/175 - 2s - loss: 2.1393e-04 - mae: 0.0055 - mse: 2.1393e-04 - val_loss: 7.4773e-04 - val_mae: 0.0115 - val_mse: 7.4773e-04 - 2s/epoch - 14ms/step
# Epoch 110/200
# 175/175 - 2s - loss: 2.1500e-04 - mae: 0.0058 - mse: 2.1500e-04 - val_loss: 6.8927e-04 - val_mae: 0.0080 - val_mse: 6.8927e-04 - 2s/epoch - 12ms/step
# Epoch 111/200
# 175/175 - 2s - loss: 1.9216e-04 - mae: 0.0053 - mse: 1.9216e-04 - val_loss: 7.7732e-04 - val_mae: 0.0072 - val_mse: 7.7732e-04 - 2s/epoch - 10ms/step
# Epoch 112/200
# 175/175 - 2s - loss: 1.9202e-04 - mae: 0.0053 - mse: 1.9202e-04 - val_loss: 6.8606e-04 - val_mae: 0.0074 - val_mse: 6.8606e-04 - 2s/epoch - 10ms/step
# Epoch 113/200
# 175/175 - 2s - loss: 1.9116e-04 - mae: 0.0052 - mse: 1.9116e-04 - val_loss: 7.2777e-04 - val_mae: 0.0081 - val_mse: 7.2777e-04 - 2s/epoch - 10ms/step
# Epoch 114/200
# 175/175 - 2s - loss: 2.0491e-04 - mae: 0.0055 - mse: 2.0491e-04 - val_loss: 7.8585e-04 - val_mae: 0.0082 - val_mse: 7.8585e-04 - 2s/epoch - 10ms/step
# Epoch 115/200
# 175/175 - 2s - loss: 2.0238e-04 - mae: 0.0055 - mse: 2.0238e-04 - val_loss: 6.6572e-04 - val_mae: 0.0077 - val_mse: 6.6572e-04 - 2s/epoch - 12ms/step
# Epoch 116/200
# 175/175 - 2s - loss: 2.1304e-04 - mae: 0.0054 - mse: 2.1304e-04 - val_loss: 0.0011 - val_mae: 0.0116 - val_mse: 0.0011 - 2s/epoch - 13ms/step
# Epoch 117/200
# 175/175 - 2s - loss: 2.3569e-04 - mae: 0.0061 - mse: 2.3569e-04 - val_loss: 7.5928e-04 - val_mae: 0.0085 - val_mse: 7.5928e-04 - 2s/epoch - 10ms/step
# Epoch 118/200
# 175/175 - 2s - loss: 2.0460e-04 - mae: 0.0055 - mse: 2.0460e-04 - val_loss: 6.4496e-04 - val_mae: 0.0068 - val_mse: 6.4496e-04 - 2s/epoch - 11ms/step
# Epoch 119/200
# 175/175 - 2s - loss: 2.0241e-04 - mae: 0.0055 - mse: 2.0241e-04 - val_loss: 6.8435e-04 - val_mae: 0.0065 - val_mse: 6.8435e-04 - 2s/epoch - 10ms/step
# Epoch 120/200
# 175/175 - 2s - loss: 1.9983e-04 - mae: 0.0055 - mse: 1.9983e-04 - val_loss: 6.9039e-04 - val_mae: 0.0080 - val_mse: 6.9039e-04 - 2s/epoch - 10ms/step
# Epoch 121/200
# 175/175 - 2s - loss: 1.9046e-04 - mae: 0.0053 - mse: 1.9046e-04 - val_loss: 6.9204e-04 - val_mae: 0.0072 - val_mse: 6.9204e-04 - 2s/epoch - 10ms/step
# Epoch 122/200
# 175/175 - 3s - loss: 1.8928e-04 - mae: 0.0051 - mse: 1.8928e-04 - val_loss: 7.1031e-04 - val_mae: 0.0080 - val_mse: 7.1031e-04 - 3s/epoch - 15ms/step
# Epoch 123/200
# 175/175 - 2s - loss: 2.0690e-04 - mae: 0.0056 - mse: 2.0690e-04 - val_loss: 6.8313e-04 - val_mae: 0.0067 - val_mse: 6.8313e-04 - 2s/epoch - 9ms/step
# Epoch 124/200
# 175/175 - 2s - loss: 1.9363e-04 - mae: 0.0055 - mse: 1.9363e-04 - val_loss: 7.0914e-04 - val_mae: 0.0097 - val_mse: 7.0914e-04 - 2s/epoch - 10ms/step
# Epoch 125/200
# 175/175 - 2s - loss: 2.0014e-04 - mae: 0.0056 - mse: 2.0014e-04 - val_loss: 6.7855e-04 - val_mae: 0.0076 - val_mse: 6.7855e-04 - 2s/epoch - 10ms/step
# Epoch 126/200
# 175/175 - 2s - loss: 1.9451e-04 - mae: 0.0054 - mse: 1.9451e-04 - val_loss: 6.8290e-04 - val_mae: 0.0074 - val_mse: 6.8290e-04 - 2s/epoch - 11ms/step
# Epoch 127/200
# 175/175 - 2s - loss: 1.9826e-04 - mae: 0.0056 - mse: 1.9826e-04 - val_loss: 6.3585e-04 - val_mae: 0.0074 - val_mse: 6.3585e-04 - 2s/epoch - 10ms/step
# Epoch 128/200
# 175/175 - 2s - loss: 1.9456e-04 - mae: 0.0052 - mse: 1.9456e-04 - val_loss: 7.2980e-04 - val_mae: 0.0082 - val_mse: 7.2980e-04 - 2s/epoch - 14ms/step
# Epoch 129/200
# 175/175 - 2s - loss: 1.9217e-04 - mae: 0.0053 - mse: 1.9217e-04 - val_loss: 6.5537e-04 - val_mae: 0.0073 - val_mse: 6.5537e-04 - 2s/epoch - 11ms/step
# Epoch 130/200
# 175/175 - 2s - loss: 1.9547e-04 - mae: 0.0053 - mse: 1.9547e-04 - val_loss: 7.5665e-04 - val_mae: 0.0075 - val_mse: 7.5665e-04 - 2s/epoch - 10ms/step
# Epoch 131/200
# 175/175 - 2s - loss: 1.9308e-04 - mae: 0.0053 - mse: 1.9308e-04 - val_loss: 6.3650e-04 - val_mae: 0.0076 - val_mse: 6.3650e-04 - 2s/epoch - 10ms/step
# Epoch 132/200
# 175/175 - 2s - loss: 1.9596e-04 - mae: 0.0053 - mse: 1.9596e-04 - val_loss: 6.6026e-04 - val_mae: 0.0084 - val_mse: 6.6026e-04 - 2s/epoch - 10ms/step
# Epoch 133/200
# 175/175 - 2s - loss: 2.0188e-04 - mae: 0.0056 - mse: 2.0188e-04 - val_loss: 6.9660e-04 - val_mae: 0.0078 - val_mse: 6.9660e-04 - 2s/epoch - 10ms/step
# Epoch 134/200
# 175/175 - 2s - loss: 1.8451e-04 - mae: 0.0050 - mse: 1.8451e-04 - val_loss: 7.3622e-04 - val_mae: 0.0076 - val_mse: 7.3622e-04 - 2s/epoch - 10ms/step
# Epoch 135/200
# 175/175 - 2s - loss: 2.1603e-04 - mae: 0.0058 - mse: 2.1603e-04 - val_loss: 7.2500e-04 - val_mae: 0.0099 - val_mse: 7.2500e-04 - 2s/epoch - 14ms/step
# Epoch 136/200
# 175/175 - 2s - loss: 1.9840e-04 - mae: 0.0053 - mse: 1.9840e-04 - val_loss: 7.7946e-04 - val_mae: 0.0085 - val_mse: 7.7946e-04 - 2s/epoch - 10ms/step
# Epoch 137/200
# 175/175 - 2s - loss: 2.1670e-04 - mae: 0.0058 - mse: 2.1670e-04 - val_loss: 8.2291e-04 - val_mae: 0.0086 - val_mse: 8.2291e-04 - 2s/epoch - 10ms/step
# Epoch 138/200
# 175/175 - 2s - loss: 1.8689e-04 - mae: 0.0051 - mse: 1.8689e-04 - val_loss: 7.3813e-04 - val_mae: 0.0079 - val_mse: 7.3813e-04 - 2s/epoch - 10ms/step
# Epoch 139/200
# 175/175 - 2s - loss: 2.0047e-04 - mae: 0.0053 - mse: 2.0047e-04 - val_loss: 7.0076e-04 - val_mae: 0.0093 - val_mse: 7.0076e-04 - 2s/epoch - 10ms/step
# Epoch 140/200
# 175/175 - 2s - loss: 1.9270e-04 - mae: 0.0053 - mse: 1.9270e-04 - val_loss: 7.4961e-04 - val_mae: 0.0079 - val_mse: 7.4961e-04 - 2s/epoch - 10ms/step
# Epoch 141/200
# 175/175 - 3s - loss: 1.9512e-04 - mae: 0.0053 - mse: 1.9512e-04 - val_loss: 7.3153e-04 - val_mae: 0.0073 - val_mse: 7.3153e-04 - 3s/epoch - 15ms/step
# Epoch 142/200
# 175/175 - 2s - loss: 2.2024e-04 - mae: 0.0055 - mse: 2.2024e-04 - val_loss: 6.7937e-04 - val_mae: 0.0076 - val_mse: 6.7937e-04 - 2s/epoch - 10ms/step
# Epoch 143/200
# 175/175 - 2s - loss: 1.9102e-04 - mae: 0.0054 - mse: 1.9102e-04 - val_loss: 7.6207e-04 - val_mae: 0.0072 - val_mse: 7.6207e-04 - 2s/epoch - 10ms/step
# Epoch 144/200
# 175/175 - 2s - loss: 1.8211e-04 - mae: 0.0048 - mse: 1.8211e-04 - val_loss: 6.7202e-04 - val_mae: 0.0070 - val_mse: 6.7202e-04 - 2s/epoch - 10ms/step
# Epoch 145/200
# 175/175 - 2s - loss: 1.7827e-04 - mae: 0.0049 - mse: 1.7827e-04 - val_loss: 7.4407e-04 - val_mae: 0.0080 - val_mse: 7.4407e-04 - 2s/epoch - 10ms/step
# Epoch 146/200
# 175/175 - 2s - loss: 1.9323e-04 - mae: 0.0054 - mse: 1.9323e-04 - val_loss: 6.9377e-04 - val_mae: 0.0072 - val_mse: 6.9377e-04 - 2s/epoch - 11ms/step
# Epoch 147/200
# 175/175 - 2s - loss: 1.8241e-04 - mae: 0.0050 - mse: 1.8241e-04 - val_loss: 6.9554e-04 - val_mae: 0.0071 - val_mse: 6.9554e-04 - 2s/epoch - 12ms/step
# Epoch 148/200
# 175/175 - 2s - loss: 1.9212e-04 - mae: 0.0054 - mse: 1.9212e-04 - val_loss: 6.7633e-04 - val_mae: 0.0070 - val_mse: 6.7633e-04 - 2s/epoch - 14ms/step
# Epoch 149/200
# 175/175 - 2s - loss: 1.9055e-04 - mae: 0.0054 - mse: 1.9055e-04 - val_loss: 7.0029e-04 - val_mae: 0.0085 - val_mse: 7.0029e-04 - 2s/epoch - 11ms/step
# Epoch 150/200
# 175/175 - 2s - loss: 2.6105e-04 - mae: 0.0064 - mse: 2.6105e-04 - val_loss: 6.9761e-04 - val_mae: 0.0074 - val_mse: 6.9761e-04 - 2s/epoch - 11ms/step
# Epoch 151/200
# 175/175 - 2s - loss: 1.9553e-04 - mae: 0.0052 - mse: 1.9553e-04 - val_loss: 7.2721e-04 - val_mae: 0.0088 - val_mse: 7.2721e-04 - 2s/epoch - 11ms/step
# Epoch 152/200
# 175/175 - 2s - loss: 1.8200e-04 - mae: 0.0052 - mse: 1.8200e-04 - val_loss: 6.4568e-04 - val_mae: 0.0074 - val_mse: 6.4568e-04 - 2s/epoch - 10ms/step
# Epoch 153/200
# 175/175 - 2s - loss: 1.8278e-04 - mae: 0.0050 - mse: 1.8278e-04 - val_loss: 6.7899e-04 - val_mae: 0.0086 - val_mse: 6.7899e-04 - 2s/epoch - 10ms/step
# Epoch 154/200
# 175/175 - 2s - loss: 1.7590e-04 - mae: 0.0049 - mse: 1.7590e-04 - val_loss: 7.0040e-04 - val_mae: 0.0070 - val_mse: 7.0040e-04 - 2s/epoch - 14ms/step
# Epoch 155/200
# 175/175 - 2s - loss: 2.0497e-04 - mae: 0.0054 - mse: 2.0497e-04 - val_loss: 6.6371e-04 - val_mae: 0.0084 - val_mse: 6.6371e-04 - 2s/epoch - 10ms/step
# Epoch 156/200
# 175/175 - 2s - loss: 1.8954e-04 - mae: 0.0053 - mse: 1.8954e-04 - val_loss: 7.8406e-04 - val_mae: 0.0113 - val_mse: 7.8406e-04 - 2s/epoch - 10ms/step
# Epoch 157/200
# 175/175 - 2s - loss: 1.9380e-04 - mae: 0.0054 - mse: 1.9380e-04 - val_loss: 7.0507e-04 - val_mae: 0.0080 - val_mse: 7.0507e-04 - 2s/epoch - 10ms/step
# Epoch 158/200
# 175/175 - 2s - loss: 1.7853e-04 - mae: 0.0050 - mse: 1.7853e-04 - val_loss: 6.9287e-04 - val_mae: 0.0077 - val_mse: 6.9287e-04 - 2s/epoch - 10ms/step
# Epoch 159/200
# 175/175 - 2s - loss: 1.8281e-04 - mae: 0.0050 - mse: 1.8281e-04 - val_loss: 7.5913e-04 - val_mae: 0.0084 - val_mse: 7.5913e-04 - 2s/epoch - 10ms/step
# Epoch 160/200
# 175/175 - 3s - loss: 1.9424e-04 - mae: 0.0053 - mse: 1.9424e-04 - val_loss: 6.5573e-04 - val_mae: 0.0078 - val_mse: 6.5573e-04 - 3s/epoch - 15ms/step
# Epoch 161/200
# 175/175 - 2s - loss: 1.8371e-04 - mae: 0.0051 - mse: 1.8371e-04 - val_loss: 7.6005e-04 - val_mae: 0.0107 - val_mse: 7.6005e-04 - 2s/epoch - 10ms/step
# Epoch 162/200
# 175/175 - 2s - loss: 2.1557e-04 - mae: 0.0058 - mse: 2.1557e-04 - val_loss: 6.8044e-04 - val_mae: 0.0080 - val_mse: 6.8044e-04 - 2s/epoch - 10ms/step
# Epoch 163/200
# 175/175 - 2s - loss: 1.8475e-04 - mae: 0.0053 - mse: 1.8475e-04 - val_loss: 7.1444e-04 - val_mae: 0.0073 - val_mse: 7.1444e-04 - 2s/epoch - 10ms/step
# Epoch 164/200
# 175/175 - 2s - loss: 1.8485e-04 - mae: 0.0051 - mse: 1.8485e-04 - val_loss: 6.4477e-04 - val_mae: 0.0069 - val_mse: 6.4477e-04 - 2s/epoch - 11ms/step
# Epoch 165/200
# 175/175 - 2s - loss: 1.8558e-04 - mae: 0.0053 - mse: 1.8558e-04 - val_loss: 7.1405e-04 - val_mae: 0.0071 - val_mse: 7.1405e-04 - 2s/epoch - 10ms/step
# Epoch 166/200
# 175/175 - 2s - loss: 1.8344e-04 - mae: 0.0054 - mse: 1.8344e-04 - val_loss: 6.6826e-04 - val_mae: 0.0085 - val_mse: 6.6826e-04 - 2s/epoch - 13ms/step
# Epoch 167/200
# 175/175 - 2s - loss: 1.9062e-04 - mae: 0.0051 - mse: 1.9062e-04 - val_loss: 6.6902e-04 - val_mae: 0.0081 - val_mse: 6.6902e-04 - 2s/epoch - 12ms/step
# Epoch 168/200
# 175/175 - 2s - loss: 1.7352e-04 - mae: 0.0048 - mse: 1.7352e-04 - val_loss: 6.9992e-04 - val_mae: 0.0072 - val_mse: 6.9992e-04 - 2s/epoch - 10ms/step
# Epoch 169/200
# 175/175 - 2s - loss: 1.7430e-04 - mae: 0.0047 - mse: 1.7430e-04 - val_loss: 6.5511e-04 - val_mae: 0.0083 - val_mse: 6.5511e-04 - 2s/epoch - 10ms/step
# Epoch 170/200
# 175/175 - 2s - loss: 1.7094e-04 - mae: 0.0050 - mse: 1.7094e-04 - val_loss: 6.5708e-04 - val_mae: 0.0072 - val_mse: 6.5708e-04 - 2s/epoch - 11ms/step
# Epoch 171/200
# 175/175 - 2s - loss: 1.7105e-04 - mae: 0.0048 - mse: 1.7105e-04 - val_loss: 6.4474e-04 - val_mae: 0.0070 - val_mse: 6.4474e-04 - 2s/epoch - 11ms/step
# Epoch 172/200
# 175/175 - 2s - loss: 1.7393e-04 - mae: 0.0047 - mse: 1.7393e-04 - val_loss: 6.5040e-04 - val_mae: 0.0077 - val_mse: 6.5040e-04 - 2s/epoch - 13ms/step
# Epoch 173/200
# 175/175 - 2s - loss: 1.7898e-04 - mae: 0.0050 - mse: 1.7898e-04 - val_loss: 6.6626e-04 - val_mae: 0.0072 - val_mse: 6.6626e-04 - 2s/epoch - 13ms/step
# Epoch 174/200
# 175/175 - 2s - loss: 2.1059e-04 - mae: 0.0057 - mse: 2.1059e-04 - val_loss: 6.5776e-04 - val_mae: 0.0093 - val_mse: 6.5776e-04 - 2s/epoch - 10ms/step
# Epoch 175/200
# 175/175 - 2s - loss: 1.9652e-04 - mae: 0.0055 - mse: 1.9652e-04 - val_loss: 6.8037e-04 - val_mae: 0.0078 - val_mse: 6.8037e-04 - 2s/epoch - 11ms/step
# Epoch 176/200
# 175/175 - 2s - loss: 1.8970e-04 - mae: 0.0054 - mse: 1.8970e-04 - val_loss: 6.5588e-04 - val_mae: 0.0075 - val_mse: 6.5588e-04 - 2s/epoch - 11ms/step
# Epoch 177/200
# 175/175 - 2s - loss: 1.8276e-04 - mae: 0.0050 - mse: 1.8276e-04 - val_loss: 7.2672e-04 - val_mae: 0.0080 - val_mse: 7.2672e-04 - 2s/epoch - 11ms/step
# Epoch 178/200
# 175/175 - 2s - loss: 1.8267e-04 - mae: 0.0052 - mse: 1.8267e-04 - val_loss: 6.6681e-04 - val_mae: 0.0078 - val_mse: 6.6681e-04 - 2s/epoch - 13ms/step
# Epoch 179/200
# 175/175 - 2s - loss: 1.7316e-04 - mae: 0.0049 - mse: 1.7316e-04 - val_loss: 6.9515e-04 - val_mae: 0.0078 - val_mse: 6.9515e-04 - 2s/epoch - 13ms/step
# Epoch 180/200
# 175/175 - 2s - loss: 2.2598e-04 - mae: 0.0058 - mse: 2.2598e-04 - val_loss: 6.6601e-04 - val_mae: 0.0083 - val_mse: 6.6601e-04 - 2s/epoch - 11ms/step
# Epoch 181/200
# 175/175 - 2s - loss: 2.2813e-04 - mae: 0.0062 - mse: 2.2813e-04 - val_loss: 6.8917e-04 - val_mae: 0.0067 - val_mse: 6.8917e-04 - 2s/epoch - 10ms/step
# Epoch 182/200
# 175/175 - 2s - loss: 1.8012e-04 - mae: 0.0049 - mse: 1.8012e-04 - val_loss: 6.9521e-04 - val_mae: 0.0067 - val_mse: 6.9521e-04 - 2s/epoch - 10ms/step
# Epoch 183/200
# 175/175 - 2s - loss: 1.8187e-04 - mae: 0.0050 - mse: 1.8187e-04 - val_loss: 6.3918e-04 - val_mae: 0.0077 - val_mse: 6.3918e-04 - 2s/epoch - 10ms/step
# Epoch 184/200
# 175/175 - 2s - loss: 1.7644e-04 - mae: 0.0049 - mse: 1.7644e-04 - val_loss: 6.5225e-04 - val_mae: 0.0068 - val_mse: 6.5225e-04 - 2s/epoch - 10ms/step
# Epoch 185/200
# 175/175 - 2s - loss: 1.7726e-04 - mae: 0.0048 - mse: 1.7726e-04 - val_loss: 6.3967e-04 - val_mae: 0.0090 - val_mse: 6.3967e-04 - 2s/epoch - 14ms/step
# Epoch 186/200
# 175/175 - 2s - loss: 1.7885e-04 - mae: 0.0049 - mse: 1.7885e-04 - val_loss: 7.7618e-04 - val_mae: 0.0086 - val_mse: 7.7618e-04 - 2s/epoch - 10ms/step
# Epoch 187/200
# 175/175 - 2s - loss: 2.0962e-04 - mae: 0.0054 - mse: 2.0962e-04 - val_loss: 7.8953e-04 - val_mae: 0.0126 - val_mse: 7.8953e-04 - 2s/epoch - 11ms/step
# Epoch 188/200
# 175/175 - 2s - loss: 2.0626e-04 - mae: 0.0055 - mse: 2.0626e-04 - val_loss: 7.1532e-04 - val_mae: 0.0077 - val_mse: 7.1532e-04 - 2s/epoch - 10ms/step
# Epoch 189/200
# 175/175 - 2s - loss: 1.7689e-04 - mae: 0.0048 - mse: 1.7689e-04 - val_loss: 7.2285e-04 - val_mae: 0.0088 - val_mse: 7.2285e-04 - 2s/epoch - 11ms/step
# Epoch 190/200
# 175/175 - 2s - loss: 1.7167e-04 - mae: 0.0049 - mse: 1.7167e-04 - val_loss: 6.3361e-04 - val_mae: 0.0075 - val_mse: 6.3361e-04 - 2s/epoch - 10ms/step
# Epoch 191/200
# 175/175 - 3s - loss: 1.7345e-04 - mae: 0.0049 - mse: 1.7345e-04 - val_loss: 6.5374e-04 - val_mae: 0.0078 - val_mse: 6.5374e-04 - 3s/epoch - 15ms/step
# Epoch 192/200
# 175/175 - 2s - loss: 1.6624e-04 - mae: 0.0046 - mse: 1.6624e-04 - val_loss: 6.0850e-04 - val_mae: 0.0076 - val_mse: 6.0850e-04 - 2s/epoch - 11ms/step
# Epoch 193/200
# 175/175 - 2s - loss: 1.7742e-04 - mae: 0.0049 - mse: 1.7742e-04 - val_loss: 6.6468e-04 - val_mae: 0.0089 - val_mse: 6.6468e-04 - 2s/epoch - 10ms/step
# Epoch 194/200
# 175/175 - 2s - loss: 1.7549e-04 - mae: 0.0051 - mse: 1.7549e-04 - val_loss: 6.5329e-04 - val_mae: 0.0091 - val_mse: 6.5329e-04 - 2s/epoch - 11ms/step
# Epoch 195/200
# 175/175 - 2s - loss: 1.7048e-04 - mae: 0.0048 - mse: 1.7048e-04 - val_loss: 6.0908e-04 - val_mae: 0.0073 - val_mse: 6.0908e-04 - 2s/epoch - 11ms/step
# Epoch 196/200
# 175/175 - 2s - loss: 1.7047e-04 - mae: 0.0047 - mse: 1.7047e-04 - val_loss: 6.4879e-04 - val_mae: 0.0072 - val_mse: 6.4879e-04 - 2s/epoch - 11ms/step
# Epoch 197/200
# 175/175 - 3s - loss: 1.9765e-04 - mae: 0.0051 - mse: 1.9765e-04 - val_loss: 6.5094e-04 - val_mae: 0.0079 - val_mse: 6.5094e-04 - 3s/epoch - 14ms/step
# Epoch 198/200
# 175/175 - 2s - loss: 1.7430e-04 - mae: 0.0051 - mse: 1.7430e-04 - val_loss: 6.2688e-04 - val_mae: 0.0081 - val_mse: 6.2688e-04 - 2s/epoch - 10ms/step
# Epoch 199/200
# 175/175 - 2s - loss: 1.6633e-04 - mae: 0.0047 - mse: 1.6633e-04 - val_loss: 6.5476e-04 - val_mae: 0.0076 - val_mse: 6.5476e-04 - 2s/epoch - 10ms/step
# Epoch 200/200
# 175/175 - 2s - loss: 1.6206e-04 - mae: 0.0047 - mse: 1.6206e-04 - val_loss: 6.4471e-04 - val_mae: 0.0067 - val_mse: 6.4471e-04 - 2s/epoch - 10ms/step

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.006454765796661377
# Minimum Validation MAE at epoch 118
# Minimum Validation loss 0.00016205638530664146
# Minimum Validation loss at epoch 191

# %%
trainPredict = model3.predict(trainX)
testPredict = model3.predict(testX)
# Out:
# 175/175 [==============================] - 1s 3ms/step
# 94/94 [==============================] - 0s 3ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.25 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.51 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.07638130449377437
# Mean Absolute Error on test data: 0.1341517758364965

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.06122241206261195
# Mean Squared Error (MSE) of test: 0.2578846170773323

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[64:564],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+64:6198+64],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
