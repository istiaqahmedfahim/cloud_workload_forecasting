# %% [markdown]
# <a href="https://colab.research.google.com/github/istiaqahmedfahim/cloud_workload_forecasting/blob/main/Workload_forecasting_of_cloud_%7C_simple_GRU_based.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'cloud-computing-history-data:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4018029%2F6990719%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240205%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240205T135728Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading cloud-computing-history-data, 143815 bytes compressed
# [==================================================] 143815 bytes downloaded
# Downloaded and uncompressed: cloud-computing-history-data
# Data source import complete.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import tensorflow as tf
rcParams['figure.figsize'] = 20, 16

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
df = pd.read_csv("/kaggle/input/cloud-computing-history-data/43.csv")
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# ...                                     ...
# 8627                              18.400000
# 8628                               1.066667
# 8629                               1.066667
# 8630                               1.533333
# 8631                               1.000000
#
# [8632 rows x 11 columns]

# %%
Sum_disk=(df["Disk read throughput [KB/s]"] + df["Disk write throughput [KB/s]"])
df["Disk I/O"]=Sum_disk
df["Disk I/O"]=((df["Disk I/O"]-df["Disk I/O"].min())/(df["Disk I/O"].max()-df["Disk I/O"].min()))*20
df
# Out:
#       Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         1376314846          2                     5851.998636
# 1         1376315146          2                     5851.998636
# 2         1376315446          2                     5851.998636
# 3         1376315746          2                     5851.998636
# 4         1376316046          2                     5851.998636
# ...              ...        ...                             ...
# 8627      1378905598          2                     5851.998944
# 8628      1378905898          2                     5851.998944
# 8629      1378906198          2                     5851.998944
# 8630      1378906498          2                     5851.998944
# 8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 12 columns]

# %% [markdown]
# # choosing the target feature

# %%
df1 = df['Disk I/O']
df1=df1.to_frame()
plt.plot(df1)
dataset = df1.values
dataset = dataset.astype('float32') #COnvert values to float

# %% [markdown]
# # data normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # Train test split

# %%
train_size = int(len(dataset) * 0.65)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # define window function

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])

    return np.array(x),np.array(y)

# %% [markdown]
# # Windowing the data|Preprocess before model input

# %%
seq_size = 30  # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (5579, 30)
# Shape of test set: (2991, 30)

# %%
# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Define the model

# %%
# model = Sequential()
# model.add(LSTM(50,return_sequences=True, input_shape=(None, seq_size)))
# model.add(LSTM(units=50))
# model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# %%
# model2 = tf.keras.models.Sequential([
#   tf.keras.layers.Conv1D(filters=64,kernel_size=5,
#                       strides=1, padding="causal",
#                       activation="relu",
#                       input_shape=[None, seq_size]),
#   tf.keras.layers.BatchNormalization(),
#   tf.keras.layers.LSTM(64,activation="relu", return_sequences=True),
#   tf.keras.layers.BatchNormalization(),
#   tf.keras.layers.GRU(64,activation="relu"),
#   tf.keras.layers.Dense(30, activation="relu"),
#   tf.keras.layers.Dense(15, activation="relu"),
#   tf.keras.layers.Dense(1,'linear')
# ])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model3 = tf.keras.models.Sequential([
  tf.keras.layers.GRU(64,activation="relu", input_shape=[None, seq_size]),
  tf.keras.layers.Dense(1,'linear')
])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import Layer, Attention

# class AttentionLayer(Layer):
#     def __init__(self, **kwargs):
#         super(AttentionLayer, self).__init__(**kwargs)

#     def build(self, input_shape):
#         self.W_q = self.add_weight(name="W_q", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
#         self.W_k = self.add_weight(name="W_k", shape=(input_shape[-1], input_shape[-1]), initializer="uniform", trainable=True)
#         self.V = self.add_weight(name="V", shape=(input_shape[-1], 1), initializer="uniform", trainable=True)
#         super(AttentionLayer, self).build(input_shape)

#     def call(self, x):
#         q = tf.matmul(x, self.W_q)
#         k = tf.matmul(x, self.W_k)
#         scores = tf.matmul(tf.nn.tanh(q + k), self.V)
#         attention_weights = tf.nn.softmax(scores, axis=-2)
#         context_vector = attention_weights * x
#         return context_vector

#     def compute_output_shape(self, input_shape):
#         return input_shape

# seq_size = 30  # Replace with your sequence size

# model = tf.keras.models.Sequential([
#     tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, seq_size]),
#     tf.keras.layers.Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
#     tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
#     tf.keras.layers.LSTM(64, activation="relu", return_sequences=True),
#     tf.keras.layers.GRU(64, activation="relu", return_sequences=True),
#     AttentionLayer(),  # Add Attention Layer
#     tf.keras.layers.Bidirectional(LSTM(50, activation="relu")),  # Return sequences here
#     tf.keras.layers.Dense(1, 'linear')
# ])

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                18432
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 18497 (72.25 KB)
# Trainable params: 18497 (72.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model3.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae','mse'])

# %% [markdown]
# # Model Fitting

# %%
history = model3.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 175/175 - 5s - loss: 0.0013 - mae: 0.0227 - mse: 0.0013 - val_loss: 0.0012 - val_mae: 0.0183 - val_mse: 0.0012 - 5s/epoch - 28ms/step
# Epoch 2/100
# 175/175 - 1s - loss: 7.6501e-04 - mae: 0.0151 - mse: 7.6501e-04 - val_loss: 0.0010 - val_mae: 0.0141 - val_mse: 0.0010 - 950ms/epoch - 5ms/step
# Epoch 3/100
# 175/175 - 1s - loss: 6.8529e-04 - mae: 0.0138 - mse: 6.8529e-04 - val_loss: 9.8020e-04 - val_mae: 0.0168 - val_mse: 9.8020e-04 - 1s/epoch - 6ms/step
# Epoch 4/100
# 175/175 - 1s - loss: 6.4226e-04 - mae: 0.0135 - mse: 6.4226e-04 - val_loss: 9.3022e-04 - val_mae: 0.0143 - val_mse: 9.3022e-04 - 955ms/epoch - 5ms/step
# Epoch 5/100
# 175/175 - 1s - loss: 6.2601e-04 - mae: 0.0134 - mse: 6.2601e-04 - val_loss: 9.4979e-04 - val_mae: 0.0141 - val_mse: 9.4979e-04 - 1s/epoch - 6ms/step
# Epoch 6/100
# 175/175 - 2s - loss: 5.8953e-04 - mae: 0.0126 - mse: 5.8953e-04 - val_loss: 9.0368e-04 - val_mae: 0.0146 - val_mse: 9.0368e-04 - 2s/epoch - 10ms/step
# Epoch 7/100
# 175/175 - 1s - loss: 5.7475e-04 - mae: 0.0128 - mse: 5.7475e-04 - val_loss: 8.8853e-04 - val_mae: 0.0132 - val_mse: 8.8853e-04 - 1s/epoch - 6ms/step
# Epoch 8/100
# 175/175 - 1s - loss: 5.6189e-04 - mae: 0.0124 - mse: 5.6189e-04 - val_loss: 8.9506e-04 - val_mae: 0.0135 - val_mse: 8.9506e-04 - 1s/epoch - 6ms/step
# Epoch 9/100
# 175/175 - 1s - loss: 5.4043e-04 - mae: 0.0121 - mse: 5.4043e-04 - val_loss: 9.3001e-04 - val_mae: 0.0156 - val_mse: 9.3001e-04 - 995ms/epoch - 6ms/step
# Epoch 10/100
# 175/175 - 1s - loss: 5.3076e-04 - mae: 0.0122 - mse: 5.3076e-04 - val_loss: 8.7182e-04 - val_mae: 0.0132 - val_mse: 8.7182e-04 - 1s/epoch - 6ms/step
# Epoch 11/100
# 175/175 - 1s - loss: 5.1918e-04 - mae: 0.0121 - mse: 5.1918e-04 - val_loss: 9.2033e-04 - val_mae: 0.0182 - val_mse: 9.2033e-04 - 1s/epoch - 6ms/step
# Epoch 12/100
# 175/175 - 1s - loss: 5.0801e-04 - mae: 0.0120 - mse: 5.0801e-04 - val_loss: 8.4931e-04 - val_mae: 0.0127 - val_mse: 8.4931e-04 - 1s/epoch - 6ms/step
# Epoch 13/100
# 175/175 - 1s - loss: 4.9008e-04 - mae: 0.0116 - mse: 4.9008e-04 - val_loss: 8.6093e-04 - val_mae: 0.0127 - val_mse: 8.6093e-04 - 1s/epoch - 6ms/step
# Epoch 14/100
# 175/175 - 1s - loss: 4.9041e-04 - mae: 0.0119 - mse: 4.9041e-04 - val_loss: 8.5372e-04 - val_mae: 0.0136 - val_mse: 8.5372e-04 - 958ms/epoch - 5ms/step
# Epoch 15/100
# 175/175 - 1s - loss: 4.8241e-04 - mae: 0.0116 - mse: 4.8241e-04 - val_loss: 8.4699e-04 - val_mae: 0.0136 - val_mse: 8.4699e-04 - 1s/epoch - 6ms/step
# Epoch 16/100
# 175/175 - 1s - loss: 4.6931e-04 - mae: 0.0117 - mse: 4.6931e-04 - val_loss: 8.4807e-04 - val_mae: 0.0132 - val_mse: 8.4807e-04 - 1s/epoch - 7ms/step
# Epoch 17/100
# 175/175 - 2s - loss: 4.5986e-04 - mae: 0.0114 - mse: 4.5986e-04 - val_loss: 8.7061e-04 - val_mae: 0.0135 - val_mse: 8.7061e-04 - 2s/epoch - 10ms/step
# Epoch 18/100
# 175/175 - 1s - loss: 4.4789e-04 - mae: 0.0113 - mse: 4.4789e-04 - val_loss: 8.4935e-04 - val_mae: 0.0141 - val_mse: 8.4935e-04 - 971ms/epoch - 6ms/step
# Epoch 19/100
# 175/175 - 1s - loss: 4.4140e-04 - mae: 0.0114 - mse: 4.4140e-04 - val_loss: 8.4175e-04 - val_mae: 0.0129 - val_mse: 8.4175e-04 - 1s/epoch - 6ms/step
# Epoch 20/100
# 175/175 - 1s - loss: 4.3146e-04 - mae: 0.0110 - mse: 4.3146e-04 - val_loss: 9.2422e-04 - val_mae: 0.0144 - val_mse: 9.2422e-04 - 1s/epoch - 6ms/step
# Epoch 21/100
# 175/175 - 1s - loss: 4.1991e-04 - mae: 0.0108 - mse: 4.1991e-04 - val_loss: 8.5172e-04 - val_mae: 0.0131 - val_mse: 8.5172e-04 - 1s/epoch - 6ms/step
# Epoch 22/100
# 175/175 - 1s - loss: 4.1785e-04 - mae: 0.0110 - mse: 4.1785e-04 - val_loss: 8.8519e-04 - val_mae: 0.0152 - val_mse: 8.8519e-04 - 1s/epoch - 6ms/step
# Epoch 23/100
# 175/175 - 1s - loss: 4.1113e-04 - mae: 0.0110 - mse: 4.1113e-04 - val_loss: 8.7655e-04 - val_mae: 0.0140 - val_mse: 8.7655e-04 - 945ms/epoch - 5ms/step
# Epoch 24/100
# 175/175 - 1s - loss: 4.0535e-04 - mae: 0.0107 - mse: 4.0535e-04 - val_loss: 8.4369e-04 - val_mae: 0.0138 - val_mse: 8.4369e-04 - 971ms/epoch - 6ms/step
# Epoch 25/100
# 175/175 - 1s - loss: 3.9336e-04 - mae: 0.0105 - mse: 3.9336e-04 - val_loss: 8.2800e-04 - val_mae: 0.0125 - val_mse: 8.2800e-04 - 1s/epoch - 6ms/step
# Epoch 26/100
# 175/175 - 1s - loss: 3.8530e-04 - mae: 0.0104 - mse: 3.8530e-04 - val_loss: 8.9994e-04 - val_mae: 0.0133 - val_mse: 8.9994e-04 - 1s/epoch - 6ms/step
# Epoch 27/100
# 175/175 - 1s - loss: 3.9721e-04 - mae: 0.0112 - mse: 3.9721e-04 - val_loss: 8.5624e-04 - val_mae: 0.0127 - val_mse: 8.5624e-04 - 1s/epoch - 8ms/step
# Epoch 28/100
# 175/175 - 1s - loss: 3.7538e-04 - mae: 0.0102 - mse: 3.7538e-04 - val_loss: 8.5814e-04 - val_mae: 0.0129 - val_mse: 8.5814e-04 - 1s/epoch - 8ms/step
# Epoch 29/100
# 175/175 - 1s - loss: 3.7229e-04 - mae: 0.0102 - mse: 3.7229e-04 - val_loss: 9.1414e-04 - val_mae: 0.0162 - val_mse: 9.1414e-04 - 1s/epoch - 6ms/step
# Epoch 30/100
# 175/175 - 1s - loss: 3.7036e-04 - mae: 0.0103 - mse: 3.7036e-04 - val_loss: 8.6118e-04 - val_mae: 0.0129 - val_mse: 8.6118e-04 - 919ms/epoch - 5ms/step
# Epoch 31/100
# 175/175 - 1s - loss: 3.7754e-04 - mae: 0.0107 - mse: 3.7754e-04 - val_loss: 8.7697e-04 - val_mae: 0.0140 - val_mse: 8.7697e-04 - 957ms/epoch - 5ms/step
# Epoch 32/100
# 175/175 - 1s - loss: 3.7138e-04 - mae: 0.0104 - mse: 3.7138e-04 - val_loss: 8.5769e-04 - val_mae: 0.0133 - val_mse: 8.5769e-04 - 1s/epoch - 6ms/step
# Epoch 33/100
# 175/175 - 1s - loss: 3.6409e-04 - mae: 0.0103 - mse: 3.6409e-04 - val_loss: 8.4589e-04 - val_mae: 0.0129 - val_mse: 8.4589e-04 - 1s/epoch - 6ms/step
# Epoch 34/100
# 175/175 - 1s - loss: 3.5358e-04 - mae: 0.0102 - mse: 3.5358e-04 - val_loss: 8.5965e-04 - val_mae: 0.0129 - val_mse: 8.5965e-04 - 1s/epoch - 6ms/step
# Epoch 35/100
# 175/175 - 1s - loss: 3.6043e-04 - mae: 0.0105 - mse: 3.6043e-04 - val_loss: 8.5784e-04 - val_mae: 0.0135 - val_mse: 8.5784e-04 - 953ms/epoch - 5ms/step
# Epoch 36/100
# 175/175 - 1s - loss: 3.5090e-04 - mae: 0.0102 - mse: 3.5090e-04 - val_loss: 8.5718e-04 - val_mae: 0.0130 - val_mse: 8.5718e-04 - 943ms/epoch - 5ms/step
# Epoch 37/100
# 175/175 - 1s - loss: 3.4127e-04 - mae: 0.0096 - mse: 3.4127e-04 - val_loss: 8.6444e-04 - val_mae: 0.0130 - val_mse: 8.6444e-04 - 1s/epoch - 6ms/step
# Epoch 38/100
# 175/175 - 1s - loss: 3.4742e-04 - mae: 0.0103 - mse: 3.4742e-04 - val_loss: 8.4788e-04 - val_mae: 0.0135 - val_mse: 8.4788e-04 - 1s/epoch - 8ms/step
# Epoch 39/100
# 175/175 - 1s - loss: 3.4895e-04 - mae: 0.0103 - mse: 3.4895e-04 - val_loss: 8.6222e-04 - val_mae: 0.0146 - val_mse: 8.6222e-04 - 1s/epoch - 8ms/step
# Epoch 40/100
# 175/175 - 1s - loss: 3.4418e-04 - mae: 0.0102 - mse: 3.4418e-04 - val_loss: 8.3212e-04 - val_mae: 0.0127 - val_mse: 8.3212e-04 - 1s/epoch - 6ms/step
# Epoch 41/100
# 175/175 - 1s - loss: 3.3808e-04 - mae: 0.0101 - mse: 3.3808e-04 - val_loss: 8.4734e-04 - val_mae: 0.0128 - val_mse: 8.4734e-04 - 938ms/epoch - 5ms/step
# Epoch 42/100
# 175/175 - 1s - loss: 3.3523e-04 - mae: 0.0101 - mse: 3.3523e-04 - val_loss: 8.9072e-04 - val_mae: 0.0147 - val_mse: 8.9072e-04 - 1s/epoch - 6ms/step
# Epoch 43/100
# 175/175 - 1s - loss: 3.2268e-04 - mae: 0.0096 - mse: 3.2268e-04 - val_loss: 8.8764e-04 - val_mae: 0.0141 - val_mse: 8.8764e-04 - 956ms/epoch - 5ms/step
# Epoch 44/100
# 175/175 - 1s - loss: 3.2972e-04 - mae: 0.0097 - mse: 3.2972e-04 - val_loss: 8.8068e-04 - val_mae: 0.0155 - val_mse: 8.8068e-04 - 1s/epoch - 6ms/step
# Epoch 45/100
# 175/175 - 1s - loss: 3.4430e-04 - mae: 0.0106 - mse: 3.4430e-04 - val_loss: 8.9570e-04 - val_mae: 0.0136 - val_mse: 8.9570e-04 - 1s/epoch - 6ms/step
# Epoch 46/100
# 175/175 - 1s - loss: 3.2892e-04 - mae: 0.0099 - mse: 3.2892e-04 - val_loss: 8.5710e-04 - val_mae: 0.0139 - val_mse: 8.5710e-04 - 960ms/epoch - 5ms/step
# Epoch 47/100
# 175/175 - 1s - loss: 3.2413e-04 - mae: 0.0098 - mse: 3.2413e-04 - val_loss: 8.3507e-04 - val_mae: 0.0132 - val_mse: 8.3507e-04 - 1s/epoch - 6ms/step
# Epoch 48/100
# 175/175 - 1s - loss: 3.1571e-04 - mae: 0.0095 - mse: 3.1571e-04 - val_loss: 8.9650e-04 - val_mae: 0.0152 - val_mse: 8.9650e-04 - 1s/epoch - 6ms/step
# Epoch 49/100
# 175/175 - 2s - loss: 3.1918e-04 - mae: 0.0097 - mse: 3.1918e-04 - val_loss: 8.5008e-04 - val_mae: 0.0130 - val_mse: 8.5008e-04 - 2s/epoch - 9ms/step
# Epoch 50/100
# 175/175 - 1s - loss: 3.2066e-04 - mae: 0.0097 - mse: 3.2066e-04 - val_loss: 8.2410e-04 - val_mae: 0.0128 - val_mse: 8.2410e-04 - 1s/epoch - 8ms/step
# Epoch 51/100
# 175/175 - 1s - loss: 3.2808e-04 - mae: 0.0101 - mse: 3.2808e-04 - val_loss: 8.3392e-04 - val_mae: 0.0131 - val_mse: 8.3392e-04 - 1s/epoch - 6ms/step
# Epoch 52/100
# 175/175 - 1s - loss: 3.3029e-04 - mae: 0.0102 - mse: 3.3029e-04 - val_loss: 8.7682e-04 - val_mae: 0.0158 - val_mse: 8.7682e-04 - 1s/epoch - 6ms/step
# Epoch 53/100
# 175/175 - 1s - loss: 3.1412e-04 - mae: 0.0097 - mse: 3.1412e-04 - val_loss: 8.6093e-04 - val_mae: 0.0141 - val_mse: 8.6093e-04 - 1s/epoch - 6ms/step
# Epoch 54/100
# 175/175 - 1s - loss: 3.0906e-04 - mae: 0.0095 - mse: 3.0906e-04 - val_loss: 8.1850e-04 - val_mae: 0.0125 - val_mse: 8.1850e-04 - 965ms/epoch - 6ms/step
# Epoch 55/100
# 175/175 - 1s - loss: 3.0672e-04 - mae: 0.0096 - mse: 3.0672e-04 - val_loss: 8.2057e-04 - val_mae: 0.0124 - val_mse: 8.2057e-04 - 937ms/epoch - 5ms/step
# Epoch 56/100
# 175/175 - 1s - loss: 3.0497e-04 - mae: 0.0095 - mse: 3.0497e-04 - val_loss: 7.9476e-04 - val_mae: 0.0125 - val_mse: 7.9476e-04 - 994ms/epoch - 6ms/step
# Epoch 57/100
# 175/175 - 1s - loss: 3.1286e-04 - mae: 0.0099 - mse: 3.1286e-04 - val_loss: 8.3955e-04 - val_mae: 0.0135 - val_mse: 8.3955e-04 - 1s/epoch - 6ms/step
# Epoch 58/100
# 175/175 - 1s - loss: 3.1548e-04 - mae: 0.0099 - mse: 3.1548e-04 - val_loss: 8.2099e-04 - val_mae: 0.0132 - val_mse: 8.2099e-04 - 948ms/epoch - 5ms/step
# Epoch 59/100
# 175/175 - 1s - loss: 3.0025e-04 - mae: 0.0094 - mse: 3.0025e-04 - val_loss: 8.2711e-04 - val_mae: 0.0130 - val_mse: 8.2711e-04 - 959ms/epoch - 5ms/step
# Epoch 60/100
# 175/175 - 2s - loss: 3.0634e-04 - mae: 0.0096 - mse: 3.0634e-04 - val_loss: 8.4359e-04 - val_mae: 0.0127 - val_mse: 8.4359e-04 - 2s/epoch - 9ms/step
# Epoch 61/100
# 175/175 - 1s - loss: 2.9932e-04 - mae: 0.0093 - mse: 2.9932e-04 - val_loss: 8.4636e-04 - val_mae: 0.0135 - val_mse: 8.4636e-04 - 1s/epoch - 8ms/step
# Epoch 62/100
# 175/175 - 1s - loss: 3.0048e-04 - mae: 0.0095 - mse: 3.0048e-04 - val_loss: 8.3594e-04 - val_mae: 0.0128 - val_mse: 8.3594e-04 - 969ms/epoch - 6ms/step
# Epoch 63/100
# 175/175 - 1s - loss: 2.9906e-04 - mae: 0.0096 - mse: 2.9906e-04 - val_loss: 8.5074e-04 - val_mae: 0.0136 - val_mse: 8.5074e-04 - 915ms/epoch - 5ms/step
# Epoch 64/100
# 175/175 - 1s - loss: 3.0318e-04 - mae: 0.0097 - mse: 3.0318e-04 - val_loss: 8.2049e-04 - val_mae: 0.0125 - val_mse: 8.2049e-04 - 1s/epoch - 6ms/step
# Epoch 65/100
# 175/175 - 1s - loss: 2.9640e-04 - mae: 0.0094 - mse: 2.9640e-04 - val_loss: 8.1804e-04 - val_mae: 0.0126 - val_mse: 8.1804e-04 - 1s/epoch - 6ms/step
# Epoch 66/100
# 175/175 - 1s - loss: 2.9069e-04 - mae: 0.0091 - mse: 2.9069e-04 - val_loss: 8.0291e-04 - val_mae: 0.0128 - val_mse: 8.0291e-04 - 922ms/epoch - 5ms/step
# Epoch 67/100
# 175/175 - 1s - loss: 2.9071e-04 - mae: 0.0091 - mse: 2.9071e-04 - val_loss: 8.1021e-04 - val_mae: 0.0124 - val_mse: 8.1021e-04 - 968ms/epoch - 6ms/step
# Epoch 68/100
# 175/175 - 1s - loss: 2.9187e-04 - mae: 0.0092 - mse: 2.9187e-04 - val_loss: 8.1211e-04 - val_mae: 0.0122 - val_mse: 8.1211e-04 - 1s/epoch - 6ms/step
# Epoch 69/100
# 175/175 - 1s - loss: 2.8671e-04 - mae: 0.0091 - mse: 2.8671e-04 - val_loss: 8.4469e-04 - val_mae: 0.0133 - val_mse: 8.4469e-04 - 1s/epoch - 6ms/step
# Epoch 70/100
# 175/175 - 1s - loss: 2.8713e-04 - mae: 0.0095 - mse: 2.8713e-04 - val_loss: 8.7073e-04 - val_mae: 0.0139 - val_mse: 8.7073e-04 - 1s/epoch - 6ms/step
# Epoch 71/100
# 175/175 - 2s - loss: 2.8773e-04 - mae: 0.0092 - mse: 2.8773e-04 - val_loss: 8.5038e-04 - val_mae: 0.0132 - val_mse: 8.5038e-04 - 2s/epoch - 9ms/step
# Epoch 72/100
# 175/175 - 1s - loss: 2.9503e-04 - mae: 0.0094 - mse: 2.9503e-04 - val_loss: 8.3438e-04 - val_mae: 0.0135 - val_mse: 8.3438e-04 - 1s/epoch - 7ms/step
# Epoch 73/100
# 175/175 - 1s - loss: 2.8205e-04 - mae: 0.0091 - mse: 2.8205e-04 - val_loss: 8.2243e-04 - val_mae: 0.0137 - val_mse: 8.2243e-04 - 1s/epoch - 6ms/step
# Epoch 74/100
# 175/175 - 1s - loss: 2.8126e-04 - mae: 0.0090 - mse: 2.8126e-04 - val_loss: 8.0197e-04 - val_mae: 0.0128 - val_mse: 8.0197e-04 - 1s/epoch - 6ms/step
# Epoch 75/100
# 175/175 - 1s - loss: 2.8712e-04 - mae: 0.0094 - mse: 2.8712e-04 - val_loss: 8.3487e-04 - val_mae: 0.0130 - val_mse: 8.3487e-04 - 956ms/epoch - 5ms/step
# Epoch 76/100
# 175/175 - 1s - loss: 2.8206e-04 - mae: 0.0090 - mse: 2.8206e-04 - val_loss: 8.3528e-04 - val_mae: 0.0126 - val_mse: 8.3528e-04 - 919ms/epoch - 5ms/step
# Epoch 77/100
# 175/175 - 1s - loss: 2.8728e-04 - mae: 0.0095 - mse: 2.8728e-04 - val_loss: 8.3982e-04 - val_mae: 0.0126 - val_mse: 8.3982e-04 - 1s/epoch - 6ms/step
# Epoch 78/100
# 175/175 - 1s - loss: 2.7858e-04 - mae: 0.0091 - mse: 2.7858e-04 - val_loss: 8.1904e-04 - val_mae: 0.0131 - val_mse: 8.1904e-04 - 928ms/epoch - 5ms/step
# Epoch 79/100
# 175/175 - 1s - loss: 2.8718e-04 - mae: 0.0094 - mse: 2.8718e-04 - val_loss: 8.3843e-04 - val_mae: 0.0129 - val_mse: 8.3843e-04 - 1s/epoch - 6ms/step
# Epoch 80/100
# 175/175 - 1s - loss: 2.7996e-04 - mae: 0.0092 - mse: 2.7996e-04 - val_loss: 8.1358e-04 - val_mae: 0.0124 - val_mse: 8.1358e-04 - 985ms/epoch - 6ms/step
# Epoch 81/100
# 175/175 - 1s - loss: 2.8053e-04 - mae: 0.0091 - mse: 2.8053e-04 - val_loss: 8.7536e-04 - val_mae: 0.0157 - val_mse: 8.7536e-04 - 930ms/epoch - 5ms/step
# Epoch 82/100
# 175/175 - 1s - loss: 2.7993e-04 - mae: 0.0092 - mse: 2.7993e-04 - val_loss: 8.5759e-04 - val_mae: 0.0131 - val_mse: 8.5759e-04 - 1s/epoch - 8ms/step
# Epoch 83/100
# 175/175 - 1s - loss: 2.7999e-04 - mae: 0.0093 - mse: 2.7999e-04 - val_loss: 8.3297e-04 - val_mae: 0.0127 - val_mse: 8.3297e-04 - 1s/epoch - 8ms/step
# Epoch 84/100
# 175/175 - 1s - loss: 2.8779e-04 - mae: 0.0095 - mse: 2.8779e-04 - val_loss: 8.3036e-04 - val_mae: 0.0133 - val_mse: 8.3036e-04 - 920ms/epoch - 5ms/step
# Epoch 85/100
# 175/175 - 1s - loss: 2.7483e-04 - mae: 0.0090 - mse: 2.7483e-04 - val_loss: 8.5790e-04 - val_mae: 0.0142 - val_mse: 8.5790e-04 - 960ms/epoch - 5ms/step
# Epoch 86/100
# 175/175 - 1s - loss: 2.7429e-04 - mae: 0.0092 - mse: 2.7429e-04 - val_loss: 8.4377e-04 - val_mae: 0.0134 - val_mse: 8.4377e-04 - 1s/epoch - 6ms/step
# Epoch 87/100
# 175/175 - 1s - loss: 2.7229e-04 - mae: 0.0089 - mse: 2.7229e-04 - val_loss: 8.2883e-04 - val_mae: 0.0125 - val_mse: 8.2883e-04 - 991ms/epoch - 6ms/step
# Epoch 88/100
# 175/175 - 1s - loss: 2.7057e-04 - mae: 0.0090 - mse: 2.7057e-04 - val_loss: 8.7039e-04 - val_mae: 0.0133 - val_mse: 8.7039e-04 - 951ms/epoch - 5ms/step
# Epoch 89/100
# 175/175 - 1s - loss: 2.7623e-04 - mae: 0.0091 - mse: 2.7623e-04 - val_loss: 8.5793e-04 - val_mae: 0.0138 - val_mse: 8.5793e-04 - 1s/epoch - 6ms/step
# Epoch 90/100
# 175/175 - 1s - loss: 2.7788e-04 - mae: 0.0092 - mse: 2.7788e-04 - val_loss: 8.4988e-04 - val_mae: 0.0134 - val_mse: 8.4988e-04 - 938ms/epoch - 5ms/step
# Epoch 91/100
# 175/175 - 1s - loss: 2.7681e-04 - mae: 0.0092 - mse: 2.7681e-04 - val_loss: 8.5511e-04 - val_mae: 0.0131 - val_mse: 8.5511e-04 - 990ms/epoch - 6ms/step
# Epoch 92/100
# 175/175 - 1s - loss: 2.6730e-04 - mae: 0.0088 - mse: 2.6730e-04 - val_loss: 8.3543e-04 - val_mae: 0.0132 - val_mse: 8.3543e-04 - 1s/epoch - 6ms/step
# Epoch 93/100
# 175/175 - 1s - loss: 2.7158e-04 - mae: 0.0091 - mse: 2.7158e-04 - val_loss: 8.5974e-04 - val_mae: 0.0132 - val_mse: 8.5974e-04 - 1s/epoch - 8ms/step
# Epoch 94/100
# 175/175 - 1s - loss: 2.6850e-04 - mae: 0.0090 - mse: 2.6850e-04 - val_loss: 9.0204e-04 - val_mae: 0.0134 - val_mse: 9.0204e-04 - 1s/epoch - 7ms/step
# Epoch 95/100
# 175/175 - 1s - loss: 2.6709e-04 - mae: 0.0087 - mse: 2.6709e-04 - val_loss: 8.3135e-04 - val_mae: 0.0127 - val_mse: 8.3135e-04 - 955ms/epoch - 5ms/step
# Epoch 96/100
# 175/175 - 1s - loss: 2.7557e-04 - mae: 0.0093 - mse: 2.7557e-04 - val_loss: 9.3370e-04 - val_mae: 0.0163 - val_mse: 9.3370e-04 - 940ms/epoch - 5ms/step
# Epoch 97/100
# 175/175 - 1s - loss: 2.6440e-04 - mae: 0.0088 - mse: 2.6440e-04 - val_loss: 8.5924e-04 - val_mae: 0.0134 - val_mse: 8.5924e-04 - 998ms/epoch - 6ms/step
# Epoch 98/100
# 175/175 - 1s - loss: 2.7101e-04 - mae: 0.0090 - mse: 2.7101e-04 - val_loss: 8.4666e-04 - val_mae: 0.0124 - val_mse: 8.4666e-04 - 979ms/epoch - 6ms/step
# Epoch 99/100
# 175/175 - 1s - loss: 2.6760e-04 - mae: 0.0090 - mse: 2.6760e-04 - val_loss: 8.4234e-04 - val_mae: 0.0126 - val_mse: 8.4234e-04 - 1s/epoch - 6ms/step
# Epoch 100/100
# 175/175 - 1s - loss: 2.6429e-04 - mae: 0.0088 - mse: 2.6429e-04 - val_loss: 8.7526e-04 - val_mae: 0.0134 - val_mse: 8.7526e-04 - 938ms/epoch - 5ms/step

# %% [markdown]
# Prediction using learned model

# %%
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_mae)), train_mae, label="Train MAE")
ax.plot(range(len(val_mae)), val_mae, label="Validation MAE")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("MAE")
ax.set_title("Train and Validation MAE over Training")

# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
# Figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot train and validation MAE over epochs
ax.plot(range(len(train_loss)), train_loss, label="Train loss")
ax.plot(range(len(val_loss)), val_loss, label="Validation loss")

# Customize labels and title
ax.set_xlabel("Epochs")
ax.set_ylabel("loss")
ax.set_title("Train and Validation loss over Training")
plt.xticks(range(0, 101, 10))
# Add legend and grid
ax.legend()
ax.grid(True)

# Show the plot
plt.show()

# %%
min_val_MAE = min(history.history['val_mae'])
min_mae_epoch = np.argmin(history.history['val_mae'])
print(f"Minimum Validation MAE {min_val_MAE}")
print(f"Minimum Validation MAE at epoch {min_mae_epoch}")
min_val_loss = min(history.history['loss'])
min_loss_epoch = np.argmin(history.history['val_loss'])
print(f"Minimum Validation loss {min_val_loss}")
print(f"Minimum Validation loss at epoch {min_loss_epoch}")
# Out:
# Minimum Validation MAE 0.011490990407764912
# Minimum Validation MAE at epoch 85
# Minimum Validation loss 0.00024009321350604296
# Minimum Validation loss at epoch 51

# %%
trainPredict = model3.predict(trainX)
testPredict = model3.predict(testX)
# Out:
# 175/175 [==============================] - 1s 4ms/step
# 94/94 [==============================] - 0s 4ms/step

# %% [markdown]
# From Normalized data to Actual data transformation

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# RMSE Calculation

# %%
import math
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.32 RMSE

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 0.59 RMSE

# %%
# calculate root mean absoulute error
from sklearn.metrics import mean_absolute_error
# Calculate MAE using scikit-learn
mae = mean_absolute_error(trainY[0],trainPredict[:,0])

print(f"Mean Absolute Error: {mae}")

# Calculate MAE using scikit-learn
mae = mean_absolute_error(testY[0],testPredict[:,0])

print(f"Mean Absolute Error on test data: {mae}")
# Out:
# Mean Absolute Error: 0.17644629726422126
# Mean Absolute Error on test data: 0.2684803301196886

# %%
from sklearn.metrics import mean_squared_error
# Calculate MSE
mse = mean_squared_error(trainY[0],trainPredict[:,0])
print(f"Mean Squared Error (MSE) of train: {mse}")
mse = mean_squared_error(testY[0],testPredict[:,0])
print(f"Mean Squared Error (MSE) of test: {mse}")
# Out:
# Mean Squared Error (MSE) of train: 0.10532126938590045
# Mean Squared Error (MSE) of test: 0.35010575552997575

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset.
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
plt.figure()
plt.plot(scaler.inverse_transform(dataset))
plt.show()

# %%
plt.figure()
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure()
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding Index column

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  \
# 0         0      1376314846          2                     5851.998636
# 1         1      1376315146          2                     5851.998636
# 2         2      1376315446          2                     5851.998636
# 3         3      1376315746          2                     5851.998636
# 4         4      1376316046          2                     5851.998636
# ...     ...             ...        ...                             ...
# 8627   8627      1378905598          2                     5851.998944
# 8628   8628      1378905898          2                     5851.998944
# 8629   8629      1378906198          2                     5851.998944
# 8630   8630      1378906498          2                     5851.998944
# 8631   8631      1378906798          2                     5851.998944
#
#       CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0            3.901332       0.066667                         2097152.0
# 1            0.000000       0.000000                         2097152.0
# 2            9.753331       0.166667                         2097152.0
# 3            0.000000       0.000000                         2097152.0
# 4            0.000000       0.000000                         2097152.0
# ...               ...            ...                               ...
# 8627        76.075986       1.300000                         2097152.0
# 8628        54.618657       0.933333                         2097152.0
# 8629        58.519989       1.000000                         2097152.0
# 8630       325.761275       5.566667                         2097152.0
# 8631        76.075986       1.300000                         2097152.0
#
#       Memory usage [KB]  Disk read throughput [KB/s]  \
# 0         106254.133333                     7.933333
# 1          79689.600000                     0.000000
# 2          62912.000000                     0.000000
# 3          97865.333333                     0.000000
# 4         127225.333333                     1.933333
# ...                 ...                          ...
# 8627      329950.133333                     0.333333
# 8628      244665.333333                     1.800000
# 8629      139808.800000                     0.200000
# 8630      325755.733333                  1029.666667
# 8631      721418.400000                     0.200000
#
#       Disk write throughput [KB/s]  Network received throughput [KB/s]  \
# 0                         1.066667                            0.000000
# 1                         1.000000                            0.000000
# 2                         0.066667                            0.000000
# 3                         0.066667                            0.000000
# 4                         0.333333                            0.000000
# ...                            ...                                 ...
# 8627                    561.866667                          581.800000
# 8628                      1.133333                            2.466667
# 8629                      0.866667                            2.400000
# 8630                     55.466667                            2.466667
# 8631                      0.666667                            2.466667
#
#       Network transmitted throughput [KB/s]  Disk I/O
# 0                                  0.000000  0.022571
# 1                                  0.000000  0.002508
# 2                                  0.000000  0.000167
# 3                                  0.000000  0.000167
# 4                                  0.000000  0.005684
# ...                                     ...       ...
# 8627                              18.400000  1.409906
# 8628                               1.066667  0.007356
# 8629                               1.066667  0.002675
# 8630                               1.533333  2.721338
# 8631                               1.000000  0.002173
#
# [8632 rows x 13 columns]

# %%
time_list = df['index'].tolist()

# %%
time_array = np.array(time_list)

# %% [markdown]
# # PLotting the data

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("Disk Usages", fontsize=15)
    plt.grid(True)

# %%
train=scaler.inverse_transform(train)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[0:500],train[:500,0])
plot_series(time_array[30:530],trainPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from train dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.

# %%
test = scaler.inverse_transform(test)

# %%
plt.figure(figsize=(10, 6))
plot_series(time_array[5698:6198],test[:500,0])
plot_series(time_array[5698+30:6198+30],testPredict[:500,0],'r' )
plt.legend(('Actual workloads', 'Predicted Workloads'),fontsize=12)
plt.savefig('3 day disk pred.png', dpi = 1080)

# %% [markdown]
# We have shown 104 hours 4 munits of data distribution from test dataset where prediction curves catches all the trends. we have also forcasted future disk usage of 1 hour 4 min.
